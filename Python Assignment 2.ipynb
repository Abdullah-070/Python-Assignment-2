# %% [markdown]
# # <h2 align="center">**Python 2024 Online Summer Internship**</h2>
# # <h1 align="center">**Make Your Place in Top 20% Pythom Programmers of the World**</h1>

# %% [markdown]
# **Name:**   Muhammad Abdullah Azhar
#
# **Email ID:**  m.abdullahazhar007@gmail.com

# %% [markdown]
# # **Task 1:**

# %% [markdown]
# Write programs for
#
#     • TODO Tasks (given in the Lectures)

# %% [markdown]
# ## **Lecture 14**

# %% [markdown]
# Consider the following two variation of Function Prototype
#
#     o No Return Type, No Arguments / Parameters
#
#     o No Return Type, Arguments / Parameters
# • Write functions for the following Tasks using the above-mentioned variations
#
#     o Write a program to find square of a number
#     o Write a program to add two float number
#     o Write a program to check if it is an even number or odd number?

# %% [markdown]
# ### **Program to find square of a number**

# %% [markdown]
# #### **No Return Type, No Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = Float
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
# • Function Prototype
#     o Return Type
#         ▪ void
#     o Function Name
#         ▪ square_calculation
#     o No. of Arguments / Parameters
#         ▪ 0
# • Function Prototype
#     o void square_calculation()
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate square of a number and
# display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. square_calculation()
#
# # Function Prototypes for User Defined Functions
# # void square_calculation(); # Function Prototype
# def square_calculation():
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - square
#         number = float(input("Enter a Number: "))
# # Processing + Output
#         square = number * number
# # Display Input and Output
#         print("Entered Number is",number)
#         print(f"Square of {number} is {square}")
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
# if __name__ == "__main__": # main() Function
#     square_calculation() # Function Call
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
#
#
#
#
#
# square_calculation()     This  Python  Statement  is  a             -                          -
#                          Function Call. Therefore, Program
#                          Control will move from Calling
#                          Function (main()) to the Called
#                          Function ( square_calculation()).
#
#                     Program Control is with the square_calculation() Function
#
# number = float           Print Message on the              number = 11.0 (In                 Enter a Number: 11
# (input("Enter a          Output Screen and take            square_calculation () Function)
# Number: "))              number as Input from User
#
# square = number *        Squaring a number and             number = 11.0 (In                 Enter a Number: 11
# number                   storing its value in variable     square_calculation () Function)
#                          named square
#
#
# print("Entered            Print  Number  (Input)  on        number = 11.0 (In                 Enter a Number: 11
# Number is: ",number)      the Output Screen.                square_calculation () Function)   Entered Number is 11
#
# print(f"Square of        Print Square (Output) on           number = 11 (In                   Enter a Number: 11
# {number} is {square})    the Output Screen.                 square_calculation () Function)   Entered Number is 11.0
#                                                                                               Square of 11.0 is 121.0
#
# Body of square_calculation() Function is completely executed. Variables declared in the square_calculation() Function will be destroyed
# and Program Control will move back from the Called Function ( square_calculation()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
#
#         -                               -                                   -                  Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                  -                   Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate square of a number and
display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. square_calculation()
'''

# Function Prototypes for User Defined Functions
# void square_calculation(); # Function Prototype
def square_calculation():
    try:
# Input
# Variable to store Input - number
# Variable to store Output - square
        number = float(input("Enter a Number: "))
# Processing + Output
        square = number * number
# Display Input and Output
        print("Entered Number is",number)
        print(f"Square of {number} is {square}")
    except ValueError:
        print("Error! Enter Integer Value")
if __name__ == "__main__": # main() Function
    square_calculation() # Function Call
# Out:
# Enter a Number:  11
# Entered Number is 11.0
# Square of 11.0 is 121.0

# %% [markdown]
# #### **No Return Type, Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = Float
#
# •Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
#
# • Function Prototype
#     o Return Type
#         ▪ void
#     o Function Name
#         ▪ square_calculation
#     o No. of Arguments / Parameters
#         ▪ 1
#
# • Function Prototype
#     o void square_calculation(float)
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate square of a number and display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. square_calculation()
#
# # Function Prototypes for User Defined Functions
# # void square_calculation(number); # Function Prototype
# def square_calculation(number):
#     # Processing + Output
#         square = number * number
# # Display Input and Output
#         print("Entered Number is",number)
#         print(f"Square of {number} is {square}")
#
# if __name__ == "__main__": # main() Function
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - square
#         number = float(input("Enter a Number: "))
#         square_calculation(number) # Function Call
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
#
# number = float(input("Enter  Print Message on the Output        number = 11.0               Enter a Number: 11
# a Number: "))                Screen and take Marks as           (In main() Function)
#                              Input from User
#
#
# square_calculation(number)   This Python Statement is a         number = 11.0               Enter a Number: 11
#                              Function Call. Therefore,          (In main() Function)
#                              Program Control will move from
#                              Calling Function (main()) to the
#                              Called Function ( square_
#                              calculation()).
#
#     Program Control has moved from Calling Function (i.e., main() Function) to the Called Function (i.e., square_calculation(number) Function).
#     Variable number (i.e., 11) has been PASSED as an Argument / Parameter to the Called Function (i.e., square_calculation(number)).
#
#                             Program Control is with the square_calculation() Function
#
#                                     Function Header – square_calculation()
#
# o Function Header
#     ▪    Step 1: Declare an Integer Variable number
#     ▪    Step 2: Store Value (i.e., 11) Passed by Calling Function (i.e., main() Function) in the
#                  Variable number (declared in Step 1)
#
#
#            -                              -                number = 11.0                      Enter a Number: 11
#                                                            (In main() Function)
#
#
# square = number *        Squaring a number and             number = 11.0                      Enter a Number: 11
# number                   storing its value in variable     (In main() Function)
#                          named square
#
#
# print("Entered            Print  Number  (Input)  on            number = 11.0 (In                 Enter a Number: 11
# Number is: ",number)      the Output Screen.                    main() Function)                  Entered Number is 11.0
#
# print(f"Square of        Print Square (Output) on               number = 11.0 (In                 Enter a Number: 11
# {number} is {square})    the Output Screen.                     main() Function)                  Entered Number is 11.0
#                                                                                                   Square of 11.0 is 121.0
#
# Body of square_calculation() Function is completely executed. Variables declared in the square_calculation() Function will be destroyed
# and Program Control will move back from the Called Function ( square_calculation()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
#
#         -                               -                                   -                  Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                  -                   Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate square of a number and display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, Arguments / Parameters
This program comprises of two Functions.
1. main()
2. square_calculation()
'''

# Function Prototypes for User Defined Functions
# void square_calculation(number); # Function Prototype
def square_calculation(number):
    # Processing + Output
        square = number * number
# Display Input and Output
        print("Entered Number is",number)
        print(f"Square of {number} is {square}")
    
if __name__ == "__main__": # main() Function
    try:
# Input
# Variable to store Input - number
# Variable to store Output - square
        number = float(input("Enter a Number: "))
        square_calculation(number) # Function Call
    except ValueError:
        print("Error! Enter Integer/Float Value")
# Out:
# Enter a Number:  11
# Entered Number is 11.0
# Square of 11.0 is 121.0

# %% [markdown]
# ### **Program to add two float number**

# %% [markdown]
# #### **No Return Type, No Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 2
#     o Data Type of Input = Float
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
# • Function Prototype
#     o Return Type
#         ▪ void
#     o Function Name
#         ▪ float_addition
#     o No. of Arguments / Parameters
#         ▪ 0
# • Function Prototype
#     o void float_addition()
#
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
# display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. float_addition()
#
# # Function Prototypes for User Defined Functions
# # void float_addition(); # Function Prototype
# def float_addition():
#     try:
# # Input
# # Variable to store Input - number1, number2
# # Variable to store Output - sum
#         number1 = float(input("Enter First Number: "))
#         number2 = float(input("Enter Second Number: "))
# # Processing + Output
#         sum = number1 + number2
# # Display Input and Output
#         print("First Entered Number is ",number1)
#         print("Second Entered Number is ",number2)
#         print(f"Sum of {number1} and {number2} is {sum} ")
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
# if __name__ == "__main__": # main() Function
#     float_addition() # Function Call
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
# float_addition()         This  Python  Statement  is  a             -                          -
#                          Function Call. Therefore, Program
#                          Control will move from Calling
#                          Function (main()) to the Called
#                          Function ( float_addition()).
#
#                     Program Control is with the float_addition() Function
#
# number1 = float          Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter First      Output Screen and take            float_addition () Function)
# Number: "))              number as Input from User
#
# number2 = float          Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter Second     Output Screen and take            float_addition () Function)
# Number: "))              number as Input from User         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            float_addition () Function)
#
# sum = number1 +          Adding number1 and number2 and    number1 = 3.5 (In                   Enter First Number: 3.5
# number2                  storing its value in variable     float_addition () Function)
#                          named sum                         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            float_addition () Function)
#
# print("First Entered      Print  Number1  (Input)  on      number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number1)      the Output Screen.              float_addition () Function)
#                                                            number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            float_addition () Function)
#                                                                                                First Entered Number is 3.5
#
# print("Second Entered      Print  Number2  (Input)  on     number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number2)      the Output Screen.              float_addition () Function)         Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            float_addition () Function)         Second Entered Number is 6.5
# print(f"Sum of {number1}   Print Square (Output) on        number1 = 3.5 (In                   Enter First Number: 3.5
# and {number2} is {sum})    the Output Screen.              float_addition () Function)         Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            float_addition () Function)         Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
# Body of float_addition() Function is completely executed. Variables declared in the float_addition() Function will be destroyed
# and Program Control will move back from the Called Function ( float_addition()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. float_addition()
'''

# Function Prototypes for User Defined Functions
# void grade_calculation1(); # Function Prototype
def float_addition():
    try:
# Input
# Variable to store Input - number1, number2
# Variable to store Output - sum
        number1 = float(input("Enter First Number: "))
        number2 = float(input("Enter Second Number: "))
# Processing + Output
        sum = number1 + number2
# Display Input and Output
        print("First Entered Number is ",number1)
        print("Second Entered Number is ",number2)
        print(f"Sum of {number1} and {number2} is {sum} ")
    except ValueError:
        print("Error! Enter Integer/Float Value")
if __name__ == "__main__": # main() Function
    float_addition() # Function Call
# Out:
# Enter First Number:  3.5
# Enter Second Number:  3
# First Entered Number is:  3.5
# Second Entered Number is:  3.0
# Sum of 3.5 and 3.0 is 6.5

# %% [markdown]
# #### **No Return Type, Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 2
#     o Data Type of Input = Float
#
# •Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
#
# • Function Prototype
#     o Return Type
#         ▪ void
#     o Function Name
#         ▪ float_addition
#     o No. of Arguments / Parameters
#         ▪ 2
#
# • Function Prototype
#     o void float_addition(int)
#
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
# display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. float_addition()
#
# # Function Prototypes for User Defined Functions
# # void float_addition(); # Function Prototype
# def float_addition(number1,number2):
#     # Processing + Output
#         sum = number1 + number2
# # Display Input and Output
#         print("First Entered Number is ",number1)
#         print("Second Entered Number is ",number2)
#         print(f"Sum of {number1} and {number2} is {sum} ")
#
# if __name__ == "__main__": # main() Function
#     try:
# # Input
# # Variable to store Input - number1, number2
# # Variable to store Output - sum
#         number1 = float(input("Enter First Number: "))
#         number2 = float(input("Enter Second Number: "))
#         float_addition(number1,number2) # Function Call
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
# number1 = float              Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter First          Output Screen and take            main () Function)
# Number: "))                  number as Input from User
#
# number2 = float              Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter Second         Output Screen and take            main () Function)
# Number: "))                  number as Input from User         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                                main () Function)
#
# float_addition(number1,      This Python Statement is a         number1 = 3.5 (In                   Enter First Number: 3.5
# number2)                     Function Call. Therefore,          main () Function)
#                              Program Control will move from     number2 = 6.5 (In                   Enter Second Number: 6.5
#                              Calling Function (main()) to the   main () Function)
#                              Called Function ( float_
#                              addition()).
#
#     Program Control has moved from Calling Function (i.e., main() Function) to the Called Function (i.e., float_addition(number1,number2) Function).
#     Variable number1 and number 2 (i.e., 3.5 and 6.5) has been PASSED as an Argument / Parameter to the Called Function
#     (i.e., float_addition(number1,number2)).
#
#                             Program Control is with the float_addition() Function
#
#                                     Function Header – float_addition()
#
# o Function Header
#     ▪    Step 1: Declare an Integer Variable number1 and number2
#     ▪    Step 2: Store Value (i.e., 3.5 and 6.5) Passed by Calling Function (i.e., main() Function) in the
#                  Variable number1 and number2 (declared in Step 1)
#
#
#         -                               -                  number1 = 3.5 (In                   Enter First Number: 3.5
#                                                            main () Function)
#                                                            number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            main () Function)
#
# sum = number1 +          Adding number1 and number2 and    number1 = 3.5 (In                   Enter First Number: 3.5
# number2                  storing its value in variable     main () Function)
#                          named sum                         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            main () Function)
#
# print("First Entered      Print  Number1  (Input)  on      number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number1)      the Output Screen.              main () Function)
#                                                            number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            main () Function)
#                                                                                                First Entered Number is 3.5
#
# print("Second Entered      Print  Number2  (Input)  on     number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number2)      the Output Screen.              main () Function)                   Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            main () Function)                   Second Entered Number is 6.5
# print(f"Sum of {number1}   Print Square (Output) on        number1 = 3.5 (In                   Enter First Number: 3.5
# and {number2} is {sum})    the Output Screen.              main () Function)                   Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            main () Function)                   Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
# Body of float_addition() Function is completely executed. Variables declared in the float_addition() Function will be destroyed
# and Program Control will move back from the Called Function ( float_addition()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. float_addition()
'''

# Function Prototypes for User Defined Functions
# void grade_calculation1(); # Function Prototype
def float_addition(number1,number2):
    # Processing + Output
        sum = number1 + number2
# Display Input and Output
        print("First Entered Number is ",number1)
        print("Second Entered Number is ",number2)
        print(f"Sum of {number1} and {number2} is {sum} ")

if __name__ == "__main__": # main() Function
    try:
# Input
# Variable to store Input - number1, number2
# Variable to store Output - sum
        number1 = float(input("Enter First Number: "))
        number2 = float(input("Enter Second Number: "))
        float_addition(number1,number2) # Function Call
    except ValueError:
        print("Error! Enter Integer/Float Value")
# Out:
# Enter First Number:  3.5
# Enter Second Number:  6.5
# First Entered Number is  3.5
# Second Entered Number is  6.5
# Sum of 3.5 and 6.5 is 10.0

# %% [markdown]
# ### **Program to check if it is an even number or odd number?**

# %% [markdown]
# #### **No Return Type, No Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = integer
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
# • Function Prototype
#     o Return Type
#         ▪ void
#     o Function Name
#         ▪ even_odd_calculation
#     o No. of Arguments / Parameters
#         ▪ 0
# • Function Prototype
#     o void check_even_odd()
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
# display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. check_even_odd()
#
#
# # Function Prototypes for User Defined Functions
# # void check_even_odd(); # Function Prototype
# def check_even_odd():
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - N/A
#         number = int(input("Enter a Number: "))
# # Processing + Output
#         if number % 2 == 0:
#             print(f"{number} is an Even Number")
#         elif number % 2 != 0:
#             print(f"{number} is an Odd Number")
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
# if __name__ == "__main__": # main() Function
#     check_even_odd() # Function Call
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
#
#
#
#
#
# check_even_odd()         This  Python  Statement  is  a             -                          -
#                          Function Call. Therefore, Program
#                          Control will move from Calling
#                          Function (main()) to the Called
#                          Function ( check_even_odd()).
#
#                     Program Control is with the check_even_odd() Function
#
# number = int             Print Message on the              number = 56 (In                   Enter a Number: 56
# (input("Enter a          Output Screen and take            check_even_odd () Function)
# Number: "))              Number as Input from User
#
# The next Python Statement is a nested Selection Structure. There are two Possible Outcomes of a
# Condition: (1) True or (2) False.
#     • If the Condition is True, Python Statements immediately after the Condition will be executed and
#       Program Control will exit from the nested Selection Structure
#     • If the Condition is False, Python Statements immediately after the Condition will be skipped and
#       Program Control will move to the next Condition in the nested Selection Structure
#
# IF number % 2             Check whether the Condition         number = 56 (In                   Enter a Number: 56
# == 0:                     is True or False                    check_even_odd () Function)
#                               • Preprocessing
#                                   o 56 % 2 == 0
#                                   o True
#
#                          The Condition is True, Python
#                          Statements immediately after the
#                          Condition will be executed and
#                          Program Control will exit from
#                          the nested Selection Structure
#
# print("f"{number} is     Print Output Message on                number = 56 (In                   Enter a Number: 56
# an Even Number ")        the Output Screen.                     check_even_odd () Function)       56 is an Even Number
#
#
# ELIF number % 2           Check whether the Condition          number = 56 (In                   Enter a Number: 56
# != 0:                     is True or False                     check_even_odd () Function)       56 is an Even Number
#                             • Preprocessing
#                                 o 56 % 2 == 0
#                                 o False
#                          The Condition is False, Python
#                          Statements immediately after
#                          the Condition will be skipped
#                          and Program Control will move to
#                          the next Condition in the nested
#                          Selection Structure
#
# print("f"{number} is     The Condition is False, Python          number = 56 (In                   Enter a Number: 56
# an Odd Number ")         Statements immediately after the        check_even_odd () Function)       56 is an Even Number
#                          Condition will be skipped
#
#
# Body of check_even_odd() Function is completely executed. Variables declared in the check_even_odd() Function will be destroyed
# and Program Control will move back from the Called Function ( check_even_odd()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
#
#         -                               -                                   -                  Enter a Number: 56
#                                                                                                56 is an Even Number
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                   -                  Enter a Number: 56
#                                                                                                56 is an Even Number

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. check_even_odd()
'''

# Function Prototypes for User Defined Functions
# void even_odd_calculation(); # Function Prototype
def check_even_odd():
    try:
# Input
# Variable to store Input - number
# Variable to store Output - N/A
        number = int(input("Enter a Number: "))
# Processing + Output
        if number % 2 == 0:
            print(f"{number} is an Even Number")
        elif number % 2 != 0:
            print(f"{number} is an Odd Number")
    except ValueError:
        print("Error! Enter Integer/Float Value")
if __name__ == "__main__": # main() Function
    check_even_odd() # Function Call
# Out:
# Enter a Number:  3
# 3 is an Odd Number

# %% [markdown]
# #### **No Return Type, Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = Integer
#
# •Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
#
# • Function Prototype
#     o Return Type
#         ▪ void
#     o Function Name
#         ▪ check_even_odd
#     o No. of Arguments / Parameters
#         ▪ 1
#
# • Function Prototype
#     o void check_even_odd(int)
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
# display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. check_even_odd()
#
# # Function Prototypes for User Defined Functions
# # void even_odd_calculation(); # Function Prototype
# def check_even_odd(number):
#     # Processing + Output
#         if number % 2 == 0:
#             print(f"{number} is an Even Number")
#         elif number % 2 != 0:
#             print(f"{number} is an Odd Number")
#
# if __name__ == "__main__": # main() Function
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - N/A
#         number = int(input("Enter a Number: "))
#         check_even_odd(number) # Function Call
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
# check_even_odd()         This  Python  Statement  is  a             -                          -
#                          Function Call. Therefore, Program
#                          Control will move from Calling
#                          Function (main()) to the Called
#                          Function ( check_even_odd()).
#
#                     Program Control is with the check_even_odd() Function
#
# number = int             Print Message on the              number = 56 (In                   Enter a Number: 56
# (input("Enter a          Output Screen and take            check_even_odd () Function)
# Number: "))              Number as Input from User
#
# The next Python Statement is a nested Selection Structure. There are two Possible Outcomes of a
# Condition: (1) True or (2) False.
#     • If the Condition is True, Python Statements immediately after the Condition will be executed and
#       Program Control will exit from the nested Selection Structure
#     • If the Condition is False, Python Statements immediately after the Condition will be skipped and
#       Program Control will move to the next Condition in the nested Selection Structure
#
# IF number % 2             Check whether the Condition         number = 56 (In                   Enter a Number: 56
# == 0:                     is True or False                    check_even_odd () Function)
#                               • Preprocessing
#                                   o 56 % 2 == 0
#                                   o True
#
#                          The Condition is True, Python
#                          Statements immediately after the
#                          Condition will be executed and
#                          Program Control will exit from
#                          the nested Selection Structure
#
# print("f"{number} is     Print Output Message on                number = 56 (In                   Enter a Number: 56
# an Even Number ")        the Output Screen.                     check_even_odd () Function)       56 is an Even Number
#
#
# ELIF number % 2           Check whether the Condition          number = 56 (In                   Enter a Number: 56
# != 0:                     is True or False                     check_even_odd () Function)       56 is an Even Number
#                             • Preprocessing
#                                 o 56 % 2 == 0
#                                 o False
#                          The Condition is False, Python
#                          Statements immediately after
#                          the Condition will be skipped
#                          and Program Control will move to
#                          the next Condition in the nested
#                          Selection Structure
#
# print("f"{number} is     The Condition is False, Python          number = 56 (In                   Enter a Number: 56
# an Odd Number ")         Statements immediately after the        check_even_odd () Function)       56 is an Even Number
#                          Condition will be skipped
#
#
# Body of check_even_odd() Function is completely executed. Variables declared in the check_even_odd() Function will be destroyed
# and Program Control will move back from the Called Function ( check_even_odd()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
#
#         -                               -                                   -                  Enter a Number: 56
#                                                                                                56 is an Even Number
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                   -                  Enter a Number: 56
#                                                                                                56 is an Even Number

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. check_even_odd()
'''

# Function Prototypes for User Defined Functions
# void even_odd_calculation(); # Function Prototype
def check_even_odd():
    try:
# Input
# Variable to store Input - number
# Variable to store Output - N/A
        number = int(input("Enter a Number: "))
# Processing + Output
        if number % 2 == 0:
            print(f"{number} is an Even Number")
        elif number % 2 != 0:
            print(f"{number} is an Odd Number")
    except ValueError:
        print("Error! Enter Integer/Float Value")
if __name__ == "__main__": # main() Function
    check_even_odd() # Function Call
# Out:
# Enter a Number:  56
# 56 is an Even Number

# %% [markdown]
# ## **Lecture 15**

# %% [markdown]
# • Consider the following two variation of Function Prototype
#
#     o Return Type, No Arguments / Parameters
#     o Return Type, Arguments / Parameters
#
# • Write functions for the following Tasks using the above-mentioned variations
#
#     o Write a program to find square of a number
#     o Write a program to add two float number
#     o Write a program to check if it is an even number or odd number?

# %% [markdown]
# ### **Program to find square of a number**

# %% [markdown]
# #### **Return Type, No Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = Float
#
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
#
# • Function Prototype
#     o Return Type
#         ▪ string
#     o Function Name
#         ▪ square_calculation
#     o No. of Arguments / Parameters
#         ▪ 0
#
# • Function Prototype
#     o string square_calculation()
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate grade of a student in Math and display it on the Output Screen. Please note that the Function Prototype will be: Return Type, No Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. square_calculation()
#
# # Function Prototypes for User Defined Functions
# # string square_calculation(); # Function Prototype
# def square_calculation():
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - square
#         number = float(input("Enter a Number: "))
# # Processing + Output
#         square = number * number
# # RETRUN result (Output) to the Calling Function
#         return square
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
# if __name__ == "__main__": # main() Function
# # When a function returns a value, use Assignment Statement ot Call Function
#     result = square_calculation() # Function Call
# # Display Input and Output
#     print("Entered Number is",number)
#     print(f"Square of {number} is {result}")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
# result = square_       This Python Statement is an
# calculation()          Assignment Statement and will be
#                        executed in the following Three Steps.
#                        • Step 1: Execute Right Hand Side
#                        (RHS) of the Assignment Statement i.e.,
#                        square_calculation(). Note that square_
#                        calculation() is a Function Call.
#                        • Step 2: Once Function Call (i.e.,
#                        square_calculation()) is complete, it
#                        will return a character on RHS OF THE     result = (In                  ---
#                        Assignment Statement i.e., square_        main() Function)
#                        calculation() will be replaced with
#                        the Returned Value
#                        • Step 3: Store the Returned Value
#                        (Step 2) in the Variable result on the
#                        Left Hand Side (LHS) of the Assignment
#                        Statement
#
#     • result = square_calculation()
#         o Step 1: Execute Right Hand Side (RHS) of the Assignment Statement i.e., square_calculation().
#                   Note that square_calculation() is a Function Call.
#             ▪ This Python Statement is a Function Call. Therefore, Program Control will move from Calling Function (main()) to the Called Function (                     square_calculation()).
#
#                         Program Control is with the square_calculation() Function
#
# number = float           Print Message on the              number = 11.0 (In                 Enter a Number: 11
# (input("Enter a          Output Screen and take            square_calculation () Function)
# Number: "))              number as Input from User
#
# square = number *        Squaring a number and             number = 11.0 (In                 Enter a Number: 11
# number                   storing its value in variable     square_calculation () Function)
#                          named square
#
# Body of square_calculation() Function is completely executed. Variables declared in the square_calculation() Function will be destroyed
# and Program Control will move back from the Called Function ( square_calculation()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
# result = square_calculation()
#     • Step 1: Once Function Call (i.e., square_calculation()) is complete, it will return a Float value on RHS of the Assignment Statement i.e.,                         square_calculation() will be replaced with the Returned Value
#     • result = 121.0
#     • Step 2: Store the Returned Value (Step 2) in the Variable result on the Left Hand Side (LHS) of the Assignment Statement
#
# result = square_         Store the Character (Output)
# calculation()            Returned by square_calculation()     result = 121.0 (In              Enter a Number: 11
#                          in Variable result                   main() Function)
#                             • Calculation
#                             o result = square_calculation()
#                             o result = 121.0
#
# print("Entered            Print  Number  (Input)  on        result = 121.0 (In                Enter a Number: 11
# Number is: ",number)      the Output Screen.                main() Function)                  Entered Number is 11
#
# print(f"Square of        Print Square (Output) on           result = 121.0 (In                Enter a Number: 11
# {number} is {result})    the Output Screen.                 main() Function)                  Entered Number is 11.0
#                                                                                               Square of 11.0 is 121.0
#
#
#         -                               -                                   -                  Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                  -                   Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate grade of a student in Math and display it on the Output Screen. Please note that the Function Prototype will be: Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. square_calculation()
'''

# Function Prototypes for User Defined Functions
# string square_calculation(); # Function Prototype
def square_calculation():
    try:
# Input
# Variable to store Input - number
# Variable to store Output - square
        number = float(input("Enter a Number: "))
# Processing + Output
        square = number * number
# RETRUN result (Output) to the Calling Function
        return square
    except ValueError:
        print("Error! Enter Integer/Float Value")
if __name__ == "__main__": # main() Function
# When a function returns a value, use Assignment Statement ot Call Function
    result = square_calculation() # Function Call
# Display Input and Output
    print("Entered Number is",number)
    print(f"Square of {number} is {result}")
# Out:
# Enter a Number:  11
# Entered Number is 11.0
# Square of 11.0 is 121.0

# %% [markdown]
# #### **Return Type, Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = Float
#
# •Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
#
# • Function Prototype
#     o Return Type
#         ▪ string
#     o Function Name
#         ▪ square_calculation
#     o No. of Arguments / Parameters
#         ▪ 1
#
# • Function Prototype
#     o string square_calculation(float)
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate square of a number and display it on the Output Screen. Please note that the Function Prototype will be: Return Type, Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. square_calculation()
#
# # Function Prototypes for User Defined Functions
# # string square_calculation(number); # Function Prototype
# def square_calculation(number):
#     # Processing + Output
#         square = number * number
# # RETRUN result (Output) to the Calling Function
#         return square
#
# if __name__ == "__main__": # main() Function
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - square
#         number = float(input("Enter a Number: "))
#         result = square_calculation(number) # Function Call
# # Display Input and Output
#         print("Entered Number is",number)
#         print(f"Square of {number} is {result}")
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
#
# number = float(input("Enter  Print Message on the Output        number = 11.0               Enter a Number: 11
# a Number: "))                Screen and take Marks as           (In main() Function)
#                              Input from User
#
# result = square_       This Python Statement is an
# calculation(number)    Assignment Statement and will be
#                        executed in the following Three Steps.
#                        • Step 1: Execute Right Hand Side
#                        (RHS) of the Assignment Statement i.e.,
#                        square_calculation(). Note that square_
#                        calculation() is a Function Call.
#                        • Step 2: Once Function Call (i.e.,
#                        square_calculation()) is complete, it
#                        will return a character on RHS OF THE     result = (In                  ---
#                        Assignment Statement i.e., square_        main() Function)
#                        calculation() will be replaced with
#                        the Returned Value
#                        • Step 3: Store the Returned Value
#                        (Step 2) in the Variable result on the
#                        Left Hand Side (LHS) of the Assignment
#                        Statement
#
#     • result = square_calculation()
#         o Step 1: Execute Right Hand Side (RHS) of the Assignment Statement i.e., square_calculation().
#                   Note that square_calculation() is a Function Call.
#             ▪ This Python Statement is a Function Call. Therefore, Program Control will move from Calling Function (main()) to the Called Function (                     square_calculation()).
#
#                         Program Control is with the square_calculation() Function
#
# square_calculation(number)   This Python Statement is a         number = 11.0               Enter a Number: 11
#                              Function Call. Therefore,          (In main() Function)
#                              Program Control will move from
#                              Calling Function (main()) to the
#                              Called Function ( square_
#                              calculation()).
#
#     Program Control has moved from Calling Function (i.e., main() Function) to the Called Function (i.e., square_calculation(number) Function).
#     Variable number (i.e., 11) has been PASSED as an Argument / Parameter to the Called Function (i.e., square_calculation(number)).
#
#                             Program Control is with the square_calculation() Function
#
#                                     Function Header – square_calculation()
#
# o Function Header
#     ▪    Step 1: Declare an Integer Variable number
#     ▪    Step 2: Store Value (i.e., 11) Passed by Calling Function (i.e., main() Function) in the
#                  Variable number (declared in Step 1)
#
#
#            -                              -                number = 11.0                      Enter a Number: 11
#                                                            (In main() Function)
#
#
# square = number *        Squaring a number and             number = 11.0                      Enter a Number: 11
# number                   storing its value in variable     (In main() Function)
#                          named square
#
# Body of square_calculation() Function is completely executed. Variables declared in the square_calculation() Function will be destroyed
# and Program Control will move back from the Called Function ( square_calculation()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
# result = square_calculation()
#     • Step 1: Once Function Call (i.e., square_calculation()) is complete, it will return a Float value on RHS of the Assignment Statement i.e.,                         square_calculation() will be replaced with the Returned Value
#     • result = 121.0
#     • Step 2: Store the Returned Value (Step 2) in the Variable result on the Left Hand Side (LHS) of the Assignment Statement
#
# result = square_         Store the Character (Output)
# calculation()            Returned by square_calculation()     result = 121.0 (In              Enter a Number: 11
#                          in Variable result                   main() Function)
#                             • Calculation
#                             o result = square_calculation()
#                             o result = 121.0
#
# print("Entered            Print  Number  (Input)  on        result = 121.0 (In                Enter a Number: 11
# Number is: ",number)      the Output Screen.                main() Function)                  Entered Number is 11
#
# print(f"Square of        Print Square (Output) on           result = 121.0 (In                Enter a Number: 11
# {number} is {result})    the Output Screen.                 main() Function)                  Entered Number is 11.0
#                                                                                               Square of 11.0 is 121.0
#
#
#         -                               -                                   -                  Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                  -                   Enter a Number: 11
#                                                                                                Entered Number is 11.0
#                                                                                                Square of 11.0 is 121.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate square of a number and display it on the Output Screen. Please note that the Function Prototype will be: Return Type, Arguments / Parameters
This program comprises of two Functions.
1. main()
2. square_calculation()
'''

# Function Prototypes for User Defined Functions
# string square_calculation(number); # Function Prototype
def square_calculation(number):
    # Processing + Output
        square = number * number
# RETRUN result (Output) to the Calling Function
        return square
    
if __name__ == "__main__": # main() Function
    try:
# Input
# Variable to store Input - number
# Variable to store Output - square
        number = float(input("Enter a Number: "))
        result = square_calculation(number) # Function Call
# Display Input and Output
        print("Entered Number is",number)
        print(f"Square of {number} is {result}")
    except ValueError:
        print("Error! Enter Integer/Float Value")
# Out:
# Enter a Number:  11
# Entered Number is 11.0
# Square of 11.0 is 121.0

# %% [markdown]
# ### **Program to add two float number**

# %% [markdown]
# #### **Return Type, No Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 2
#     o Data Type of Input = Float
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
# • Function Prototype
#     o Return Type
#         ▪ String
#     o Function Name
#         ▪ float_addition
#     o No. of Arguments / Parameters
#         ▪ 0
# • Function Prototype
#     o string float_addition()
#
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
# display it on the Output Screen. Please note that the Function Prototype will be: Return Type, No Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. float_addition()
#
# # Function Prototypes for User Defined Functions
# # string float_addition(); # Function Prototype
# def float_addition():
#     try:
# # Input
# # Variable to store Input - number1, number2
# # Variable to store Output - sum
#         number1 = float(input("Enter First Number: "))
#         number2 = float(input("Enter Second Number: "))
# # Processing + Output
#         sum = number1 + number2
# # RETRUN result (Output) to the Calling Function
#         return sum
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
# if __name__ == "__main__": # main() Function
# # When a function returns a value, use Assignment Statement ot Call Function
#     result = float_addition() # Function Call
#     # Display Input and Output
#         print("First Entered Number is ",number1)
#         print("Second Entered Number is ",number2)
#         print(f"Sum of {number1} and {number2} is {result} ")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
# result = float_        This Python Statement is an
# addition()             Assignment Statement and will be
#                        executed in the following Three Steps.
#                        • Step 1: Execute Right Hand Side
#                        (RHS) of the Assignment Statement i.e.,
#                        float_addition(). Note that float_
#                        addition() is a Function Call.
#                        • Step 2: Once Function Call (i.e.,
#                        float_addition()) is complete, it
#                        will return a character on RHS OF THE     result = (In                  ---
#                        Assignment Statement i.e., float_         main() Function)
#                        addition() will be replaced with
#                        the Returned Value
#                        • Step 3: Store the Returned Value
#                        (Step 2) in the Variable result on the
#                        Left Hand Side (LHS) of the Assignment
#                        Statement
#
#     • result = float_addition()
#         o Step 1: Execute Right Hand Side (RHS) of the Assignment Statement i.e., float_addition().
#                   Note that float_addition() is a Function Call.
#             ▪ This Python Statement is a Function Call. Therefore, Program Control will move from Calling Function (main()) to the Called Function (                     float_addition()).
#
#                     Program Control is with the float_addition() Function
#
# number1 = float          Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter First      Output Screen and take            float_addition () Function)
# Number: "))              number as Input from User
#
# number2 = float          Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter Second     Output Screen and take            float_addition () Function)
# Number: "))              number as Input from User         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            float_addition () Function)
#
# sum = number1 +          Adding number1 and number2 and    number1 = 3.5 (In                   Enter First Number: 3.5
# number2                  storing its value in variable     float_addition () Function)
#                          named sum                         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            float_addition () Function)
#
# Body of float_addition() Function is completely executed. Variables declared in the float_addition() Function will be destroyed
# and Program Control will move back from the Called Function ( float_addition()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
# result = float_addition()
#     • Step 1: Once Function Call (i.e., float_addition()) is complete, it will return a Float value on RHS of the Assignment Statement i.e.,                         float_addition() will be replaced with the Returned Value
#     • result = 10.0
#     • Step 2: Store the Returned Value (Step 2) in the Variable result on the Left Hand Side (LHS) of the Assignment Statement
#
# result = float_          Store the Character (Output)
# addition()               Returned by float_addition()         result = 10.0 (In              Enter First Number: 3.5
#                          in Variable result                   main() Function)               Enter Second Number: 6.5
#                             • Calculation
#                             o result = float_addition()
#                             o result = 10.0
#
# print("First Entered      Print  Number1  (Input)  on      number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number1)      the Output Screen.              float_addition () Function)
#                                                            number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            float_addition () Function)
#                                                                                                First Entered Number is 3.5
#
# print("Second Entered      Print  Number2  (Input)  on     number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number2)      the Output Screen.              float_addition () Function)         Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            float_addition () Function)         Second Entered Number is 6.5
# print(f"Sum of {number1}     Print Square (Output) on      number1 = 3.5 (In                   Enter First Number: 3.5
# and {number2} is {result})   the Output Screen.            float_addition () Function)         Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            float_addition () Function)         Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
#
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
display it on the Output Screen. Please note that the Function Prototype will be: Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. float_addition()
'''

# Function Prototypes for User Defined Functions
# string float_addition(); # Function Prototype
def float_addition():
    try:
# Input
# Variable to store Input - number1, number2
# Variable to store Output - sum
        number1 = float(input("Enter First Number: "))
        number2 = float(input("Enter Second Number: "))
# Processing + Output
        sum = number1 + number2
# RETRUN result (Output) to the Calling Function
        return sum
    except ValueError:
        print("Error! Enter Integer/Float Value")
if __name__ == "__main__": # main() Function
# When a function returns a value, use Assignment Statement ot Call Function
    result = float_addition() # Function Call
    # Display Input and Output
    print("First Entered Number is ",number1)
    print("Second Entered Number is ",number2)
    print(f"Sum of {number1} and {number2} is {result} ")
# Out:
# Enter First Number:  3.5
# Enter Second Number:  6.5
# First Entered Number is  3.5
# Second Entered Number is  6.5
# Sum of 3.5 and 6.5 is 10.0

# %% [markdown]
# #### **Return Type, Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 2
#     o Data Type of Input = Float
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
# • Function Prototype
#     o Return Type
#         ▪ String
#     o Function Name
#         ▪ float_addition
#     o No. of Arguments / Parameters
#         ▪ 2
# • Function Prototype
#     o string float_addition(int,int)
#
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
# display it on the Output Screen. Please note that the Function Prototype will be: Return Type, Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. float_addition()
#
# # Function Prototypes for User Defined Functions
# # string float_addition(number1,number2); # Function Prototype
# def float_addition(number1,number2):
#     # Processing + Output
#         sum = number1 + number2
# # RETRUN result (Output) to the Calling Function
#         return sum
#
#
# if __name__ == "__main__": # main() Function
#     try:
# # Input
# # Variable to store Input - number1, number2
# # Variable to store Output - sum
#         number1 = float(input("Enter First Number: "))
#         number2 = float(input("Enter Second Number: "))
#         result = float_addition(number1,number2) # Function Call
# # Display Input and Output
#         print("First Entered Number is ",number1)
#         print("Second Entered Number is ",number2)
#         print(f"Sum of {number1} and {number2} is {result} ")
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
# number1 = float          Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter First      Output Screen and take            main () Function)
# Number: "))              number as Input from User
#
# number2 = float          Print Message on the              number1 = 3.5 (In                   Enter First Number: 3.5
# (input("Enter Second     Output Screen and take            main () Function)
# Number: "))              number as Input from User         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            main () Function)
#
# result = float_        This Python Statement is an
# addition(number1,      Assignment Statement and will be
# number2)               executed in the following Three Steps.
#                        • Step 1: Execute Right Hand Side
#                        (RHS) of the Assignment Statement i.e.,
#                        float_addition(). Note that float_
#                        addition() is a Function Call.
#                        • Step 2: Once Function Call (i.e.,
#                        float_addition()) is complete, it
#                        will return a character on RHS OF THE     result = (In                  ---
#                        Assignment Statement i.e., float_         main() Function)
#                        addition() will be replaced with
#                        the Returned Value
#                        • Step 3: Store the Returned Value
#                        (Step 2) in the Variable result on the
#                        Left Hand Side (LHS) of the Assignment
#                        Statement
#
#     • result = float_addition()
#         o Step 1: Execute Right Hand Side (RHS) of the Assignment Statement i.e., float_addition().
#                   Note that float_addition() is a Function Call.
#             ▪ This Python Statement is a Function Call. Therefore, Program Control will move from Calling Function (main()) to the Called Function (                     float_addition()).
#
#                     Program Control is with the float_addition() Function
#
# float_addition(number1,      This Python Statement is a         number1 = 3.5 (In                   Enter First Number: 3.5
# number2)                     Function Call. Therefore,          main () Function)
#                              Program Control will move from     number2 = 6.5 (In                   Enter Second Number: 6.5
#                              Calling Function (main()) to the   main () Function)
#                              Called Function ( float_
#                              addition()).
#
#     Program Control has moved from Calling Function (i.e., main() Function) to the Called Function (i.e., float_addition(number1,number2) Function).
#     Variable number1 and number 2 (i.e., 3.5 and 6.5) has been PASSED as an Argument / Parameter to the Called Function
#     (i.e., float_addition(number1,number2)).
#
#                             Program Control is with the float_addition() Function
#
#                                     Function Header – float_addition()
#
# o Function Header
#     ▪    Step 1: Declare an Integer Variable number1 and number2
#     ▪    Step 2: Store Value (i.e., 3.5 and 6.5) Passed by Calling Function (i.e., main() Function) in the
#                  Variable number1 and number2 (declared in Step 1)
#
#
#         -                               -                  number1 = 3.5 (In                   Enter First Number: 3.5
#                                                            main () Function)
#                                                            number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            main () Function)
#
# sum = number1 +          Adding number1 and number2 and    number1 = 3.5 (In                   Enter First Number: 3.5
# number2                  storing its value in variable     main () Function)
#                          named sum                         number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            main () Function)
#
# Body of float_addition() Function is completely executed. Variables declared in the float_addition() Function will be destroyed
# and Program Control will move back from the Called Function ( float_addition()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
# result = float_addition()
#     • Step 1: Once Function Call (i.e., float_addition()) is complete, it will return a Float value on RHS of the Assignment Statement i.e.,                         float_addition() will be replaced with the Returned Value
#     • result = 10.0
#     • Step 2: Store the Returned Value (Step 2) in the Variable result on the Left Hand Side (LHS) of the Assignment Statement
#
# result = float_          Store the Character (Output)
# addition()               Returned by float_addition()         result = 10.0 (In              Enter First Number: 3.5
#                          in Variable result                   main() Function)               Enter Second Number: 6.5
#                             • Calculation
#                             o result = float_addition()
#                             o result = 10.0
#
# print("First Entered      Print  Number1  (Input)  on      number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number1)      the Output Screen.              main () Function)
#                                                            number2 = 6.5 (In                   Enter Second Number: 6.5
#                                                            main () Function)
#                                                                                                First Entered Number is 3.5
#
# print("Second Entered      Print  Number2  (Input)  on     number1 = 3.5 (In                   Enter First Number: 3.5
# Number is: ",number2)      the Output Screen.              main () Function)                   Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            main () Function)                   Second Entered Number is 6.5
# print(f"Sum of {number1}     Print Square (Output) on      number1 = 3.5 (In                   Enter First Number: 3.5
# and {number2} is {result})   the Output Screen.            main () Function)                   Enter Second Number: 6.5
#                                                            number2 = 6.5 (In                   First Entered Number is 3.5
#                                                            main () Function)                   Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
#
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#
#         -                               -                                   -                  Enter First Number: 3.5
#                                                                                                Enter Second Number: 6.5
#                                                                                                First Entered Number is 3.5
#                                                                                                Second Entered Number is 6.5
#                                                                                                Sum of 3.5 and 6.5 is 10.0

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate sum of two float numbers and
display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, Arguments / Parameters
This program comprises of two Functions.
1. main()
2. float_addition()
'''

# Function Prototypes for User Defined Functions
# void float_addition(); # Function Prototype
def float_addition(number1,number2):
    # Processing + Output
        sum = number1 + number2
# RETRUN result (Output) to the Calling Function
        return sum


if __name__ == "__main__": # main() Function
    try:
# Input
# Variable to store Input - number1, number2
# Variable to store Output - sum
        number1 = float(input("Enter First Number: "))
        number2 = float(input("Enter Second Number: "))
        result = float_addition(number1,number2) # Function Call
# Display Input and Output
        print("First Entered Number is ",number1)
        print("Second Entered Number is ",number2)
        print(f"Sum of {number1} and {number2} is {result} ")
    except ValueError:
        print("Error! Enter Integer/Float Value")
# Out:
# Enter First Number:  3.5
# Enter Second Number:  6.5
# First Entered Number is  3.5
# Second Entered Number is  6.5
# Sum of 3.5 and 6.5 is 10.0

# %% [markdown]
# ### **Program to check if it is an even number or odd number?**

# %% [markdown]
# #### **Return Type, No Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = integer
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
# • Function Prototype
#     o Return Type
#         ▪ String
#     o Function Name
#         ▪ even_odd_calculation
#     o No. of Arguments / Parameters
#         ▪ 0
# • Function Prototype
#     o string check_even_odd()
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
# display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. check_even_odd()
#
# # Function Prototypes for User Defined Functions
# # string check_even_odd(); # Function Prototype
# def check_even_odd():
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - result
#         number = int(input("Enter a Number: "))
# # Processing + Output
#         if number % 2 == 0:
#             num = 'even'
#         elif number % 2 != 0:
#             num = 'odd'
# # RETRUN result (Output) to the Calling Function
#         return num
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
# if __name__ == "__main__": # main() Function
# # When a function returns a value, use Assignment Statement ot Call Function
#     result = check_even_odd() # Function Call
# # Printing Output
#     if result == 'even':
#         print("It is an Even Number")
#     elif result == 'odd':
#         print("It is an Odd Number")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
#
# result = check_        This Python Statement is an
# even_odd()             Assignment Statement and will be
#                        executed in the following Three Steps.
#                        • Step 1: Execute Right Hand Side
#                        (RHS) of the Assignment Statement i.e.,
#                        check_even_odd(). Note that check_
#                        even_odd() is a Function Call.
#                        • Step 2: Once Function Call (i.e.,
#                        check_even_odd()) is complete, it
#                        will return a character on RHS OF THE     result = (In                  ---
#                        Assignment Statement i.e., check_         main() Function)
#                        even_odd() will be replaced with
#                        the Returned Value
#                        • Step 3: Store the Returned Value
#                        (Step 2) in the Variable result on the
#                        Left Hand Side (LHS) of the Assignment
#                        Statement
#
#     • result = check_even_odd()
#         o Step 1: Execute Right Hand Side (RHS) of the Assignment Statement i.e., check_even_odd().
#                   Note that check_even_odd() is a Function Call.
#             ▪ This Python Statement is a Function Call. Therefore, Program Control will move from Calling Function (main()) to the Called Function (                     check_even_odd()).
#
#                     Program Control is with the check_even_odd() Function
#
# number = int             Print Message on the              number = 56 (In                   Enter a Number: 56
# (input("Enter a          Output Screen and take            check_even_odd () Function)
# Number: "))              Number as Input from User
#
# The next Python Statement is a nested Selection Structure. There are two Possible Outcomes of a
# Condition: (1) True or (2) False.
#     • If the Condition is True, Python Statements immediately after the Condition will be executed and
#       Program Control will exit from the nested Selection Structure
#     • If the Condition is False, Python Statements immediately after the Condition will be skipped and
#       Program Control will move to the next Condition in the nested Selection Structure
#
# IF number % 2             Check whether the Condition         number = 56 (In                   Enter a Number: 56
# == 0:                     is True or False                    check_even_odd () Function)
#                               • Preprocessing
#                                   o 56 % 2 == 0
#                                   o True
#
#                          The Condition is True, Python
#                          Statements immediately after the
#                          Condition will be executed and
#                          Program Control will exit from
#                          the nested Selection Structure
#
# num = 'even'             Store even string in                   number = 56 (In                   Enter a Number: 56
#                          num variable.                          check_even_odd () Function)
#
#
# ELIF number % 2           Check whether the Condition          number = 56 (In                   Enter a Number: 56
# != 0:                     is True or False                     check_even_odd () Function)
#                             • Preprocessing
#                                 o 56 % 2 == 0
#                                 o False
#                          The Condition is False, Python
#                          Statements immediately after
#                          the Condition will be skipped
#                          and Program Control will move to
#                          the next Condition in the nested
#                          Selection Structure
#
# num = 'odd'              Store even string in                   number = 56 (In                   Enter a Number: 56
#                          num variable.                          check_even_odd () Function)
#
#
# Body of check_even_odd() Function is completely executed. Variables declared in the check_even_odd() Function will be destroyed
# and Program Control will move back from the Called Function ( check_even_odd()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
# result = check_even_odd()
#     • Step 1: Once Function Call (i.e., check_even_odd()) is complete, it will return a Float value on RHS of the Assignment Statement i.e.,                         check_even_odd() will be replaced with the Returned Value
#     • result = 'even'
#     • Step 2: Store the Returned Value (Step 2) in the Variable result on the Left Hand Side (LHS) of the Assignment Statement
#
# result = check_          Store the Character (Output)
# even_odd()               Returned by check_even_odd()         result = 'even' (In            Enter a Number: 56
#                          in Variable result                   main() Function)
#                             • Calculation
#                             o result = check_even_odd()
#                             o result = 'even'
#
# IF result ==             Check whether the Condition         result = 'even' (In                   Enter a Number: 56
# 'even':                  is True or False                    check_even_odd () Function)
#                               • Preprocessing
#                                   o 'even' == 'even'
#                                   o True
#
#                          The Condition is True, Python
#                          Statements immediately after the
#                          Condition will be executed and
#                          Program Control will exit from
#                          the nested Selection Structure
#
# print("f"{number} is     Print Output Message on                result = 'even'(In                Enter a Number: 56
# an Even Number ")        the Output Screen.                     check_even_odd () Function)       56 is an Even Number
#
# ELIF number % 2           Check whether the Condition          result = 'even' (In                Enter a Number: 56
# != 0:                     is True or False                     check_even_odd () Function)        56 is an Even Number
#                             • Preprocessing
#                                 o 56 % 2 == 0
#                                 o False
#                          The Condition is False, Python
#                          Statements immediately after
#                          the Condition will be skipped
#                          and Program Control will move to
#                          the next Condition in the nested
#                          Selection Structure
#
# print("f"{number} is     The Condition is False, Python          result = 'even' (In                Enter a Number: 56
# an Odd Number ")         Statements immediately after the        check_even_odd () Function)        56 is an Even Number
#                          Condition will be skipped
#
#         -                               -                                   -                      Enter a Number: 56
#                                                                                                    56 is an Even Number
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                   -                  Enter a Number: 56
#                                                                                                56 is an Even Number

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
display it on the Output Screen. Please note that the Function Prototype will be: No Return Type, No Arguments / Parameters
This program comprises of two Functions.
1. main()
2. check_even_odd()
'''

# Function Prototypes for User Defined Functions
# void check_even_odd(); # Function Prototype
def check_even_odd():
    try:
# Input
# Variable to store Input - number
# Variable to store Output - N/A
        number = int(input("Enter a Number: "))
# Processing + Output
        if number % 2 == 0:
            num = 'even'
        elif number % 2 != 0:
            num = 'odd'
# RETRUN result (Output) to the Calling Function
        return num
    except ValueError:
        print("Error! Enter Integer/Float Value")
if __name__ == "__main__": # main() Function
# When a function returns a value, use Assignment Statement ot Call Function
    result = check_even_odd() # Function Call
    # Printing Output
    if result == 'even':
        print("It is an Even Number")
    elif result == 'odd':
        print("It is an Odd Number")
# Out:
# Enter a Number:  45
# It is an Odd Number

# %% [markdown]
# #### **Return Type, Arguments / Parameters**

# %% [raw]
# Input, Output, and Function Prototype
#
# • Input
#     o Number of Input(s) = 1
#     o Data Type of Input = integer
# • Output
#     o Number of Output(s) = 1
#     o Data Type of Output = String
# • Function Prototype
#     o Return Type
#         ▪ String
#     o Function Name
#         ▪ even_odd_calculation
#     o No. of Arguments / Parameters
#         ▪ 1
# • Function Prototype
#     o string check_even_odd()
#
# Purpose of Program
# The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
# display it on the Output Screen. Please note that the Function Prototype will be: Return Type, Arguments / Parameters
# This program comprises of two Functions.
# 1. main()
# 2. check_even_odd()
#
# # Function Prototypes for User Defined Functions
# # string check_even_odd(number); # Function Prototype
# def check_even_odd(number):
# # Processing + Output
#         if number % 2 == 0:
#             num = 'even'
#         elif number % 2 != 0:
#             num = 'odd'
# # RETRUN result (Output) to the Calling Function
#         return num
#
# if __name__ == "__main__": # main() Function
#     try:
# # Input
# # Variable to store Input - number
# # Variable to store Output - result
#         number = int(input("Enter a Number: "))
# # When a function returns a value, use Assignment Statement ot Call Function
#         result = check_even_odd(number) # Function Call
# # Printing Output
#         if result == 'even':
#             print("It is an Even Number")
#         elif result == 'odd':
#             print("It is an Odd Number")
#     except ValueError:
#         print("Error! Enter Integer/Float Value")
#
# DRY RUN
#
# Python Statement             Processing                          Memory                    Output Screen
#
# Start (Program Execution) - Execution of Python Program starts from the main() Function. Therefore, Program
# Control will be with the main() Function 😊
#
#                     Program Control is with the main() Function
# number = int             Print Message on the              number = 56 (In                   Enter a Number: 56
# (input("Enter a          Output Screen and take            main () Function)
# Number: "))              Number as Input from User
#
# result = check_        This Python Statement is an
# even_odd(number)       Assignment Statement and will be
#                        executed in the following Three Steps.
#                        • Step 1: Execute Right Hand Side
#                        (RHS) of the Assignment Statement i.e.,
#                        check_even_odd(). Note that check_
#                        even_odd() is a Function Call.
#                        • Step 2: Once Function Call (i.e.,
#                        check_even_odd()) is complete, it
#                        will return a character on RHS OF THE     result = (In                  ---
#                        Assignment Statement i.e., check_         main() Function)
#                        even_odd() will be replaced with
#                        the Returned Value
#                        • Step 3: Store the Returned Value
#                        (Step 2) in the Variable result on the
#                        Left Hand Side (LHS) of the Assignment
#                        Statement
#
#     • result = check_even_odd(number)
#         o Step 1: Execute Right Hand Side (RHS) of the Assignment Statement i.e., check_even_odd().
#                   Note that check_even_odd() is a Function Call.
#             ▪ This Python Statement is a Function Call. Therefore, Program Control will move from Calling Function (main()) to the Called Function (                     check_even_odd()).
#
#     Variable number (i.e., 56) has been PASSED as an Argument / Parameter to the Called Function (i.e., check_even_odd(number)).
#
#                             Program Control is with the check_even_odd() Function
#
#                                     Function Header – check_even_odd()
#
# o Function Header
#     ▪    Step 1: Declare an Integer Variable number
#     ▪    Step 2: Store Value (i.e., 56) Passed by Calling Function (i.e., main() Function) in the
#                  Variable number (declared in Step 1)
#
#
#         -                               -                  number = 56 (In                   Enter a Number: 56
#                                                            main () Function)
#
#
# The next Python Statement is a nested Selection Structure. There are two Possible Outcomes of a
# Condition: (1) True or (2) False.
#     • If the Condition is True, Python Statements immediately after the Condition will be executed and
#       Program Control will exit from the nested Selection Structure
#     • If the Condition is False, Python Statements immediately after the Condition will be skipped and
#       Program Control will move to the next Condition in the nested Selection Structure
#
# IF number % 2             Check whether the Condition         number = 56 (In                   Enter a Number: 56
# == 0:                     is True or False                    main () Function)
#                               • Preprocessing
#                                   o 56 % 2 == 0
#                                   o True
#
#                          The Condition is True, Python
#                          Statements immediately after the
#                          Condition will be executed and
#                          Program Control will exit from
#                          the nested Selection Structure
#
# num = 'even'             Store even string in                   number = 56 (In                   Enter a Number: 56
#                          num variable.                          main () Function)
#
#
# ELIF number % 2           Check whether the Condition          number = 56 (In                   Enter a Number: 56
# != 0:                     is True or False                     main () Function)
#                             • Preprocessing
#                                 o 56 % 2 == 0
#                                 o False
#                          The Condition is False, Python
#                          Statements immediately after
#                          the Condition will be skipped
#                          and Program Control will move to
#                          the next Condition in the nested
#                          Selection Structure
#
# num = 'odd'              Store even string in                   number = 56 (In                   Enter a Number: 56
#                          num variable.                          check_even_odd () Function)
#
#
# Body of check_even_odd() Function is completely executed. Variables declared in the check_even_odd() Function will be destroyed
# and Program Control will move back from the Called Function ( check_even_odd()) to the Calling Function (main())
#
#                     Program Control is with the main() Function
#
# result = check_even_odd(number)
#     • Step 1: Once Function Call (i.e., check_even_odd()) is complete, it will return a string value on RHS of the Assignment Statement i.e.,                            check_even_odd() will be replaced with the Returned Value
#     • result = 'even'
#     • Step 2: Store the Returned Value (Step 2) in the Variable result on the Left Hand Side (LHS) of the Assignment Statement
#
# result = check_          Store the Character (Output)
# even_odd(number)         Returned by check_even_odd()         result = 'even' (In            Enter a Number: 56
#                          in Variable result                   main() Function)
#                             • Calculation
#                             o result = check_even_odd()
#                             o result = 'even'
#
# IF result ==             Check whether the Condition         result = 'even' (In             Enter a Number: 56
# 'even':                  is True or False                    main () Function)
#                               • Preprocessing
#                                   o 'even' == 'even'
#                                   o True
#
#                          The Condition is True, Python
#                          Statements immediately after the
#                          Condition will be executed and
#                          Program Control will exit from
#                          the nested Selection Structure
#
# print("f"{number} is     Print Output Message on                result = 'even'(In                Enter a Number: 56
# an Even Number ")        the Output Screen.                     main () Function)                 56 is an Even Number
#
# ELIF number % 2           Check whether the Condition          result = 'even' (In                Enter a Number: 56
# != 0:                     is True or False                     main () Function)                  56 is an Even Number
#                             • Preprocessing
#                                 o 56 % 2 == 0
#                                 o False
#                          The Condition is False, Python
#                          Statements immediately after
#                          the Condition will be skipped
#                          and Program Control will move to
#                          the next Condition in the nested
#                          Selection Structure
#
# print("f"{number} is     The Condition is False, Python          result = 'even' (In                Enter a Number: 56
# an Odd Number ")         Statements immediately after the        main () Function)                  56 is an Even Number
#                          Condition will be skipped
#
#         -                               -                                   -                      Enter a Number: 56
#                                                                                                    56 is an Even Number
#
# End (Program Execution): Python Program will terminate when all the Python Statements in the main() Function are executed.
#
# As can be noted, all the Python Statements in the main() Function are executed.  Variables declared in the main() Function
# will be destroyed and Python Program will be Terminated 😊
#
#         -                               -                                   -                  Enter a Number: 56
#                                                                                                56 is an Even Number

# %% [markdown]
# ##### **CODE**

# %%
'''
Purpose of Program
The main purpose of this Python Program is to demonstrate how we can use Functions to calculate if a number is even or odd and
display it on the Output Screen. Please note that the Function Prototype will be: Return Type, Arguments / Parameters
This program comprises of two Functions.
1. main()
2. check_even_odd()
'''

# Function Prototypes for User Defined Functions
# string check_even_odd(number); # Function Prototype
def check_even_odd(number):
# Processing + Output
        if number % 2 == 0:
            num = 'even'
        elif number % 2 != 0:
            num = 'odd'
# RETRUN result (Output) to the Calling Function
        return num
    
if __name__ == "__main__": # main() Function
    try:
# Input
# Variable to store Input - number
# Variable to store Output - result
        number = int(input("Enter a Number: "))
# When a function returns a value, use Assignment Statement ot Call Function
        result = check_even_odd(number) # Function Call
# Printing Output
        if result == 'even':
            print("It is an Even Number")
        elif result == 'odd':
            print("It is an Odd Number")
    except ValueError:
        print("Error! Enter Integer/Float Value")
# Out:
# Enter a Number:  a
# Error! Enter Integer/Float Value

# %% [markdown]
# ## **Lecture 16**

# %% [markdown]
# ● Write down at least 2 Linear and 2 Non-linear Data Structures not mentioned in this Lecture?

# %% [markdown]
# #### **Answer:**

# %% [markdown]
# ● Linear Data Structures
#
#     ● Vector
#     ● ArrayList
#     ● Circular Queue
#
# ● Non Linear Data Structures
#
#     ● Heap
#     ● Trie
#     ● Hash Table

# %% [markdown]
# ### **TODO Task 2**

# %% [markdown]
# ● Consider the following Float Array and perform all the Tasks that I have performed in this Lecture on Integer Array ages, to access array elements and store values in an array. Assume that Float takes 8 Bytes in the Memory
#
#     o marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# %%
# author = Abdullah

# The main purpose of this program is to Initialize an Array
marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# Accessing Array Elements

# Accessing First Array Element
print ("Accessing First Array Element: ",marks[0])

# Accessing Second Array Element
print ("Accessing Second Array Element: ",marks[1])

# Accessing Third Array Element
print ("Accessing Third Array Element: ",marks[2])

# Accessing Fourth Array Element
print ("Accessing Fourth Array Element: ",marks[3])

# Accessing Fifth Array Element
print ("Accessing Fifth Array Element: ",marks[4])

# Storing Values 

marks1 = [0] * 5
marks1 [0] = 88.5
marks1 [1] = 60.2
marks1 [2] = 70.8
marks1 [3] = 90.3
marks1 [4] = 20.6

print("\n")
print(marks1)


# Dry Run
# Execute marks = [0] * 5

# Index            0                1                2               3               4
# Value           0                0                0               0               0
# Address        DD20            DD28              DD36            DD44            DD52



#  Execute marks[0] = 88.5

# Index            0                1                2               3               4
# Value          88.5              0                0               0               0
# Address        DD20            DD28              DD36            DD44            DD52



#  Execute marks[1] = 60.2

# Index            0                1                2               3               4
# Value           88.5            60.2               0              10              0
# Address        DD20            DD28              DD36            DD44            DD52




#  Execute marks[2] = 70.8

# Index            0                1                2               3               4
# Value           88.5            60.2             70.8             10              0
# Address        DD20            DD28              DD36            DD44            DD52




#  Execute marks[3] = 90.3


# Index            0                1                2               3               4
# Value           88.5            60.2             70.8            90.3              0
# Address        DD20            DD28              DD36            DD44            DD52



#  Execute marks[4] = 20.6

# Index            0                1                2               3               4
# Value           88.5            60.2             70.8            90.3            20.6
# Address        DD20            DD28              DD36            DD44            DD52
# Out:
# Accessing First Array Element:  88.5
# Accessing Second Array Element:  60.2
# Accessing Third Array Element:  70.8
# Accessing Fourth Array Element:  90.3
# Accessing Fifth Array Element:  20.6
#
#
# [88.5, 60.2, 70.8, 90.3, 20.6]

# %% [markdown]
# ### **TODO Task 3**

# %% [markdown]
# ● Consider the following Float Array and perform all the Tasks that I have performed in this Lecture the Integer Array ages, to display array elements on the Output Screen. Assume that Float takes 8 Bytes in the Memory
#
#     o marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# %%
# author = Abdullah

# The main purpose of this program is to Initialize an Array
marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# Printing Array Elements

# Printing First Array Element
print ("Accessing First Array Element: ",marks[0])

# Printing Second Array Element
print ("Accessing Second Array Element: ",marks[1])

# Printing Third Array Element
print ("Accessing Third Array Element: ",marks[2])

# Printing Fourth Array Element
print ("Accessing Fourth Array Element: ",marks[3])

# Printing Fifth Array Element
print ("Accessing Fifth Array Element: ",marks[4])

# %% [markdown]
# ## **Lecture 17**

# %% [markdown]
# ### **TODO Task 1**

# %% [markdown]
# • Consider the following Strings and answer the questions given below
#
#     String 1
#         Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#     String 2
#         Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life.
#     String 3
#         Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#         He’s (PBUH) role model for us in all fields of life.
#         One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim.
#
# Questions
#
# • Print String 1 using Single Quotes, String 2 using Double Quotes and String 3 using Triple Quotes
#
# • Print lengths of String 1, String 2, and String 3 using len() Function

# %%
'''
Purpose of Program
The main purpose of the program is to create a string using single, double, and triple quotes and measure their lengths
'''

# Input + Processing + Output

try:
    
# Using Single Quotes
    print('---Message with Single Quotes---') 
    print('Hazrat Muhammad (PBUH) is the last Messenger of Allah.')

# Using Double Quotes
    print("")
    print('---Message with Double Quotes---')
    print("Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life.")

# Using Triple Quotes
    print("")
    print('---Message with Triple Quotes---') 
    print('''Hazrat Muhammad (PBUH) is the last Messenger of Allah.
        He’s (PBUH) role model for us in all fields of life.
        One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim.''')
    print("")

# Calculating Length of String with Single Quotes using len() Function
    print('---Length of String with Single Quotes---')
    print('Length of "Hazrat Muhammad (PBUH) is the last Messenger of Allah." is: ', len("Hazrat Muhammad (PBUH) is the last Messenger of Allah."))
    print("")

# Calculating Length of String with Double Quotes using len() Function
    print('---Length of String with Double Quotes---')
    print("Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life.' is: ", len("Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life."))
    print("")
                                                                                   
# Calculating Length of String with Triple Quotes using len() Function
    print('---Length of String with Triple Quotes---') 
    print('''Length of 'Hazrat Muhammad (PBUH) is the last Messenger of Allah.
        He’s (PBUH) role model for us in all fields of life.
        One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim.' is: ''', len("Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life. One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim."))
                                                                                   
except:
    print('Error Occurred')
# Out:
# ---Message with Single Quotes---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#
# ---Message with Double Quotes---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life.
#
# ---Message with Triple Quotes---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#         He’s (PBUH) role model for us in all fields of life.
#         One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim.
#
# ---Length of String with Single Quotes---
# Length of "Hazrat Muhammad (PBUH) is the last Messenger of Allah." is:  54
#
# ---Length of String with Double Quotes---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life.' is:  107
#
# ---Length of String with Triple Quotes---
# Length of 'Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#         He’s (PBUH) role model for us in all fields of life.
# ...

# %% [markdown]
# ### **TODO Task 2**

# %% [markdown]
# • Consider the following Strings and answer the questions given below
#
#     String 1
#         Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#     String 2
#         Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life.
#     String 3
#         Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#         He’s (PBUH) role model for us in all fields of life.
#         One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim.
# ● Questions
#
#     o Print String 1 using Single Quotes, String 2 using Double Quotes and String 3 using Triple Quotes
#     o Print lengths and types of String 1, String 2, and String 3 using len() Function

# %%
'''
Purpose of Program
The main purpose of the program is to create a string using single, double, and triple quotes and measure their lengths
'''

# Input + Processing + Output

try:
    
# Using Single Quotes
    print('---Message with Single Quotes---') 
    message_1 = 'Hazrat Muhammad (PBUH) is the last Messenger of Allah.'
    print("message_1 = "+ message_1) 
    print("Length of message_1 =", len(message_1)) 
    print("Data Type of message_1 =", type(message_1)) 
    print("")

# Using Double Quotes
    print('---Message with Double Quotes---')
    message_2 = "Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life."
    print("message_2 = "+ message_2) 
    print("Length of message_2 =", len(message_2)) 
    print("Data Type of message_2 =", type(message_2)) 
    print("")

# Using Triple Quotes
    print('---Message with Triple Quotes---') 
    message_3 = '''Hazrat Muhammad (PBUH) is the last Messenger of Allah.
        He’s (PBUH) role model for us in all fields of life.
        One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim.'''
    print("message_3 = "+ message_3) 
    print("Length of message_3 =", len(message_3)) 
    print("Data Type of message_3 =", type(message_3)) 
    print("")

except:
    print('Error Occurred')
# Out:
# ---Message with Single Quotes---
# message_1 = Hazrat Muhammad (PBUH) is the last Messenger of Allah.
# Length of message_1 = 54
# Data Type of message_1 = <class 'str'>
#
# ---Message with Double Quotes---
# message_2 = Hazrat Muhammad (PBUH) is the last Messenger of Allah. He’s (PBUH) role model for us in all fields of life.
# Length of message_2 = 107
# Data Type of message_2 = <class 'str'>
#
# ---Message with Triple Quotes---
# message_3 = Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#         He’s (PBUH) role model for us in all fields of life.
#         One who doesn’t accept Hazrat Muhammad (PBUH) as the last Messenger of Allah is a non-Muslim.
# Length of message_3 = 217
# Data Type of message_3 = <class 'str'>

# %% [markdown]
# ### **TODO Task 3**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1: Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#
# ● Questions
#
#     o Apply following functions on String 1 and print the original and new string on the Output Screen?
#         ▪ title()
#         ▪ capitalize()
#         ▪ upper()
#         ▪ lower()
#         ▪ center()

# %%
'''
Purpose of Program
The main purpose of the program is to format string using following built-in Functions i.e., 
title(), capitalize(), upper(), lower() and center()
'''

# Input + Processing + Output
try:

# Initialize a Message
    message = 'Hazrat Muhammad (PBUH) is the last Messenger of Allah.'

# Using title() Function
    print('---Original String before using title() Function---')
    print(message)
    print("")

    print('---New String after using title() Function---')
    print(message.title())

# Using capitalize() Function
    print("")
    print('---Original String before using capitalize() Function---') 
    print(message)
    print("")

    print('---New String after using capitalize() Function---') 
    print(message.capitalize())

# Using upper() Function
    print("")
    print('---Original String before using upper() Function---') 
    print(message)
    print("")

    print('---New String after using upper() Function---') 
    print(message.upper())

# Using lower() Function
    print("")
    print('---Original String before using lower() Function---') 
    print(message)
    print("")

    print('---New String after using lower() Function---') 
    print(message.lower())

# Using center() Function
    print("")
    print('---Original String before using center() Function---') 
    print("Original Message: "+ message)
    print("")

    print('---New String after using center() Function---') 
    print(message.center(100))

except:
    print('Error Occurred')
# Out:
# ---Original String before using title() Function---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#
# ---New String after using title() Function---
# Hazrat Muhammad (Pbuh) Is The Last Messenger Of Allah.
#
# ---Original String before using capitalize() Function---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#
# ---New String after using capitalize() Function---
# Hazrat muhammad (pbuh) is the last messenger of allah.
#
# ---Original String before using upper() Function---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#
# ---New String after using upper() Function---
# HAZRAT MUHAMMAD (PBUH) IS THE LAST MESSENGER OF ALLAH.
#
# ---Original String before using lower() Function---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
#
# ---New String after using lower() Function---
# hazrat muhammad (pbuh) is the last messenger of allah.
#
# ---Original String before using center() Function---
# ...

# %% [markdown]
# ### **TODO Task 4**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1: Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ● Questions
#
#     o Apply following techniques to access elements of a String (as shown in this Chapter) on String 1 and print the original and new string on the Output Screen?
#         ▪ Indexing
#         ▪ Slicing
#         ▪ Splitting

# %%
''' Purpose of Program
The main purpose of the program is to access elements from a string using indexing,
slicing and split() function '''

# Input + Processing + Output

try:
    
# Initialize a Message
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.'

# Accessing Elements of a String using Indexing
    print("")
    print('---Original String before Indexing---') 
    print(message)
    print("")
    print('---New String after Indexing---')

# Access First Element of String
    print("Access Element at First Index i.e., message[0] is: "+ message[0])

# Access 14th Element of String
    print("Access Element at 14th Index i.e., message[14] is: "+ message[14])

# Access Last Element of String
    print("Access Element at last Index i.e., message[-1] is: "+ message[-1])

# Using Slicing
    print("")
    print('---Original String before Slicing---') 
    print(message)
    print("")
    print('---New String after Slicing---')

# Access First Sentence of String with stop value only i.e., [:13]
    print("Access First Sentence of String with stop value only i.e., [:13]: "+ message[:13])

# Access First Sentence of String with both start and stop value i.e., [0:13] 
    print("Access First Sentence of String with both start and stop value i.e.,[0:13]: "+ message[0:13])

# Access Middle Sentence of String
    print("Access Element from Middle Sentence i.e., message[14:53]: "+ message[14:53])

# Access Last Sentence of String with start value only i.e., message[55:]
    print("Access Last Sentence of String with start value only i.e., message[55:]: "+ message[55:])
    
# Access Last Sentence of String with both start and stop value i.e., [55:91] 
    print("Access Element from Last Sentence i.e.,message[55:91]: "+ message[55:91])

# Split String on basis of full stop (.) using split() Function
    print("")
    print('---Original String before using split() Function---') 
    print(message)
    print("")
    print('---New String after using split() Function---')
    print(message.split('.'))

# Split String on basis of spaces using split() Function 
    print("")
    print('---Original String before using split() Function---') 
    print(message)
    print("")
    print('---New String after using split() Function---') 
    print(message.split(' '))

except:
    print('Error Occurred')
# Out:
# ---Original String before Indexing---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after Indexing---
# Access Element at First Index i.e., message[0] is: H
# Access Element at 14th Index i.e., message[14] is: d
# Access Element at last Index i.e., message[-1] is: .
#
# ---Original String before Slicing---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after Slicing---
# Access First Sentence of String with stop value only i.e., [:13]: Hazrat Muhamm
# Access First Sentence of String with both start and stop value i.e.,[0:13]: Hazrat Muhamm
# Access Element from Middle Sentence i.e., message[14:53]: d (PBUH) is role model for us in all fi
# Access Last Sentence of String with start value only i.e., message[55:]: ds of life.
# Access Element from Last Sentence i.e.,message[55:91]: ds of life.
#
# ---Original String before using split() Function---
# ...

# %% [markdown]
# ### **TODO Task 5**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1 “ Hazrat Muhammad (PBUH) is the last Messenger of Allah. “
#
# ● Questions
#
#     o Apply following functions on String 1 and print the original and new string on the Output Sreen?
#         ▪ strip()
#         ▪ rstrip()
#         ▪ lstrip()

# %%
'''
Purpose of Program
The main purpose of the program is to remove Whitespaces from a String using strip(), rstrip(), lstrip() Functions
'''

# Input + Processing + Output 
try:

# Initialize a Message
    message = ' Hazrat Muhammad (PBUH) is the last Messenger of Allah. '

# Using strip() Function on message 
    print("")
    print('---Original String before using strip() Function---') 
    print(message)
    print("Length of Original String i.e., message: ",len(message))
    
    print("")
    print('---New String after using strip() Function---')
    print(message.strip())
    print("Length of New String i.e., message: ",len(message.strip()))
    
# Using rstrip() Function on message 
    print("") 
    print('---Original String i.e., message_1 before using rstrip() Function---') 
    print(message) 
    print("Length of Original Message i.e., message_1: ",len(message)) 
    
    print("") 
    print('---New String i.e., message_1 after using rstrip() Function---') 
    print(message.rstrip()) 
    print("Length of New Message: ",len(message.rstrip()))
    
# Using lstrip() Function on message_1
    print("")
    print('---Original String i.e., message_1 before using lstrip() Function---') 
    print(message)
    print("Length of Original Message i.e., message_1: ",len(message))
    
    print("") 
    print('---New String i.e., message_1 after using lrip() Function---') 
    print(message.lstrip())
    print("Length of New Message: ",len(message.lstrip()))

except: 
    print('Error Occurred')
# Out:
# ---Original String before using strip() Function---
#  Hazrat Muhammad (PBUH) is the last Messenger of Allah.
# Length of Original String i.e., message:  56
#
# ---New String after using strip() Function---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
# Length of New String i.e., message:  54
#
# ---Original String i.e., message_1 before using rstrip() Function---
#  Hazrat Muhammad (PBUH) is the last Messenger of Allah.
# Length of Original Message i.e., message_1:  56
#
# ---New String i.e., message_1 after using rstrip() Function---
#  Hazrat Muhammad (PBUH) is the last Messenger of Allah.
# Length of New Message:  55
#
# ---Original String i.e., message_1 before using lstrip() Function---
#  Hazrat Muhammad (PBUH) is the last Messenger of Allah.
# Length of Original Message i.e., message_1:  56
#
# ---New String i.e., message_1 after using lrip() Function---
# Hazrat Muhammad (PBUH) is the last Messenger of Allah.
# Length of New Message:  55

# %% [markdown]
# ### **TODO Task 6**

# %% [markdown]
# ● Consider the following data values and answer the questions given below
#
#     String 1: “125”
#
#     Integer 1: 428
#
# ● Questions
#
#     o Apply str() function on Integer 1 and print the original Integer and new String on the Output Screen?
#
#     o Apply int() function on String 1 and print the original String and new Integer on the Output Screen?

# %%
'''
Purpose of Program
The main purpose of the program is to convert a string from data type string to numbers and from 
numbers to string
'''

# Input + Processing + Output
try:
    
# Initialize Variable
    number = 428
    string_number = '125'
    
# Using str() Function
    print("")
    print('---Original Number before Conversion into String---') 
    print(number)
    print('Data Type of Number before Converting into String:') 
    print(type(number))
    print("")
    
    print('---New Number after Conversion into String---') 
    print(str(number))
    print('Data Type of Number after Converting into String') 
    print(type(str(number)))
    print("")
    
# Using int() Function
    print("")
    print('---Original String before Conversion into Number---') 
    print(string_number)
    print('Data Type of String before Converting into Number:')
    print(type(string_number))
    print("")
    
    print('---New String after Conversion into Number---')
    print(int(string_number))
    print('Data Type of String after Converting into Number:')
    print(type(int(string_number)))
    print("")
except: 
    print('Error Occurred')
# Out:
# ---Original Number before Conversion into String---
# 428
# Data Type of Number before Converting into String:
# <class 'int'>
#
# ---New Number after Conversion into String---
# 428
# Data Type of Number after Converting into String
# <class 'str'>
#
#
# ---Original String before Conversion into Number---
# 125
# Data Type of String before Converting into Number:
# <class 'str'>
#
# ---New String after Conversion into Number---
# 125
# Data Type of String after Converting into Number:
# <class 'int'>

# %% [markdown]
# ### **TODO Task 7**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1: Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ● Questions
#
#     o Apply following operators and functions to insert characters at: (1) start, (2) specific position, and (3) end of String 1 (as shown in this Chapter) and print the original and new string on the Output Screen?
#
#         ▪ Concatenation Operator (+)
#         ▪ join() Function
#         ▪ Formatting Operator (%)
#         ▪ format() Function
#         ▪ F-String Prefix
#         ▪ find() Function

# %% [markdown]
# #### **1. Start**

# %%
''' Purpose of Program
The main purpose of the program is to insert character at start of a string and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.'
    print('---Original String before using + Operator---')
    print(message)
    print("")

# Using + Operator to insert Element at First Index of a String 
    new_message = "*" + message[0:]
    print('---New String after using + Operator ---') 
    print(new_message)
    print("")

# Using join() Function to insert Element at First Index of a String
    print('---Original String before using join() Function---') 
    print(message)
    print("")
    newmessage = ''.join(("*",message))
    print('---New String after using join() Function---') 
    print(newmessage)
    print("")
    
# Using % Operator to insert Element at First Index of a String
    print('---Original String before using % Operator---') 
    print(message)
    print("")
    new_message = "%sHazrat Muhammad (PBUH) is role model for us in all fields of life." %'*'
    print('---New String after using % Operator---')
    print(new_message)
    print("")
    
# Using format() Function to insert Element at First Index of a String
    print('---Original String before using format() Function---') 
    print(message)
    print("")
    new_message = "{}Hazrat Muhammad (PBUH) is role model for us in all fields of life.".format('*')
    print('---New String after using format() Function---')
    print(new_message)
    print("")
    
# Using f Prefix to insert Element at First Index of a String
    print('---Original String before using f Prefix---') 
    print(message)
    print("")
    new_message = f"{'*'}Hazrat Muhammad (PBUH) is role model for us in all fields of life."
    print('---New String after using f Prefix---') 
    print(new_message)
    print("")
    
# Using find() Function to insert Element at First Index of a String
    print('---Original String before using find() Function---') 
    print(message)
    print("")
    index = message.find('Hazrat')
    final_string = '*' + message[index:]
    print('---New String after using find() Function---') 
    print(final_string)
    print("")
# Using split(), join() and insert() Functions to insert Element at First Index of a String 
    print('---Original String before using split() Function---') 
    print(message)
    split_strings = message.split()
    split_strings.insert(0, '*') 
    updated_string = ' '.join(split_strings)
    print('---New String after using split() Function---') 
    print(updated_string)
except:
    print('Error Occurred')
# Out:
# ---Original String before using + Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using + Operator ---
# *Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---Original String before using join() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using join() Function---
# *Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---Original String before using % Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using % Operator---
# *Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---Original String before using format() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using format() Function---
# *Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ...

# %% [markdown]
# #### **2. Specific Position**

# %%
''' Purpose of Program
The main purpose of the program is to insert character at a specific position in a string and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.'
    print('---Original String before using + Operator---')
    print(message)
    print("")

# Using + Operator to insert Element at Last Index of a String 
    new_message = message[:0] + "*"
    print('---New String after using + Operator ---') 
    print(new_message)
    print("")
    
# Using join() Function to insert Element at Last Index of a String
    print("")
    print('---Original String before using join() Function---') 
    print(message)
    newmessage = ''.join((message,"*"))
    print('---New String after using join() Function---') 
    print(newmessage)
    print("")
    
# Using % Operator to insert Element at Last Index of a String
    print("")
    print('---Original String before using % Operator---') 
    print(message)
    new_message = "Hazrat Muhammad (PBUH) is role model for us in all fields of life.%s" %'*'
    print('---New String after using % Operator---') 
    print(new_message)
    print("")
    
# Using format() Function to insert Element at Last Index of a String
    print("")
    print('---Original String before using format() Function---')
    print(message)
    new_message = "Hazrat Muhammad (PBUH) is role model for us in all fields of life.{}".format('*')
    print('---New String after using format() Function---') 
    print(new_message)
    print("")
    
# Using f Prefix to insert Element at Last Index of a String
    print("")
    print('---Original String before using f Prefix---') 
    print(message)
    new_message = f"Hazrat Muhammad (PBUH) is role model for us in all fields of life.{'*'}"
    print('---New String after using f Prefix---') 
    print(new_message)
    print("")
    
# Using find() Function to insert Element at Last Index of a String
    print("")
    print('---Original String before using find() Function---')
    print(message)
    index = message.find('.')
    final_string = message[:index+1] + '*'
    print('---New String after using find() Function---') 
    print(final_string)
    print("")
    
# Using split(), join() and insert() Functions to insert Element at Last Index of a String 
    print('---Original String before using split() Function---') 
    print(message)
    split_strings = message.split()
    split_strings.insert((len(message) + 1), '*') 
    updated_string = ' '.join(split_strings)
    print('---New String after using split() Function---')
    print(updated_string)
    
except:
    print('Error Occurred')
# Out:
# ---Original String before using + Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using + Operator ---
# *
#
#
# ---Original String before using join() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
# ---New String after using join() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.*
#
#
# ---Original String before using % Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
# ---New String after using % Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.*
#
#
# ---Original String before using format() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
# ---New String after using format() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.*
#
#
# ---Original String before using f Prefix---
# ...

# %% [markdown]
# #### **3. End**

# %%
'''
Purpose of Program
The main purpose of the program is to insert character at end of a string and display the result on 
the Output Screen
'''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.'
    print('---Original String before using + Operator---')
    print(message)
    print("")

# Using + Operator to insert Element at Last Index of a String 
    new_message = message[:0] + "*"
    print('---New String after using + Operator---') 
    print(new_message)
    print("")
    
# Using join() Function to insert Element at Last Index of a String
    print('---Original String before using join() Function---') 
    print(message)
    new_message = ''.join((message,"*"))
    print('---New String after using join() Function---') 
    print(new_message)
    print("")
    
# Using % Operator to insert Element at Last Index of a String
    print('---Original String before using % Operator---') 
    print(message)
    print("")
    new_message = "Hazrat Muhammad (PBUH) is role model for us in all fields of life.%s" %'*'
    print('---New String after using % Operator---') 
    print(new_message)
    print("")
# Using format() Function to insert Element at Last Index of a String 
    print('---Original String before using format() Function---') 
    print(message) 
    print("")
    new_message = "Hazrat Muhammad (PBUH) is role model for us in all fields of life.{}".format('*') 
    print('---New String after using format() Function---') 
    print(new_message) 
    print("") 
    
# Using f Prefix to insert Element at Last Index of a String 
    print('---Original String before using f Prefix---') 
    print(message)
    print("")
    new_message = f"Hazrat Muhammad (PBUH) is role model for us in all fields of life.{'*'}" 
    print('---New String after using f Prefix---') 
    print(new_message) 
    print("") 
    
# Using find() Function to insert Element at Last Index of a String 
    
    print('---Original String before using find() Function---') 
    print(message) 
    print("")
    index = message.find('.') 
    final_string = message[:index+1] + '*' 
    print('---New String after using find() Function---') 
    print(final_string) 
    print("") 
    
# Using split(), join() and insert() Functions to insert Element at Last Index of a String 
    print('---Original String before using split() Function---') 
    print(message) 
    print("")
    split_strings = message.split() 
    split_strings.insert((len(message) + 1), '*') 
    updated_string = ' '.join(split_strings) 
    print('---New String after using split() Function---')
    print(updated_string) 
except:
    print('Error Occurred')
# Out:
# ---Original String before using + Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using + Operator---
# *
#
# ---Original String before using join() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
# ---New String after using join() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.*
#
# ---Original String before using % Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using % Operator---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.*
#
# ---Original String before using format() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using format() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.*
#
# ---Original String before using f Prefix---
# ...

# %% [markdown]
# ### **TODO Task 8**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1: Muhammad
#
# ● Questions
#
#     o Traverse String 1 using the methods presented in this Chapter?

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to traverse an entire string and display the result on the Output Screen '''

# Input + Processing + Output
try: 
# Initialize Variable 
    message = 'Muhammad' 
# Traverse an entire String
    print(message) 
except: 
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse a string (element by element) and display the result 
on the Output Screen
'''

# Input + Processing + Output
try:
    
# ---Approach I - Iterate over a string (element by element) using for loop---
# Initialize Variable 
    message_1 = 'Muhammad'
# Iterate over a string (element by element) using for loop
    print(" ---Approach I - Iterate over a string (element by element) using for loop---")
    print("---Traverse a String (Element by Element) using for Loop---")
    for character in message_1:
        print(character)
# ---Approach II - Iterate over a string (element by element) using Indexing---

# Initialize Variable 
    message_2 = 'Muhammad'

# Iterate over a string (element by element) using for loop with Indexing
    print(" ---Approach II - Iterate over a string (element by element) using Indexing---")
    print("---Traverse a String (Element by Element) using for Loop with Indexing---")
    for element in range(0, len(message_2)):
        print("message_2[",element,"]: " + message_2[element])
        
# ---Approach III - Iterate over a string (element by element) using Slicing---
# Initialize Variable
    message_3 = 'Muhammad' 
    counter = 0
    print("---Approach III - Iterate over a string (element by element) using Slicing---")

# Iterate over a string (element by element) using for loop with Slicing
    print("---Traverse a String (Element by Element) using for Loop with Slicing--- ")
    
# Slicing Operator => string[starting index : ending index : step value] 
    for element in message_3[0 : len(message_3): 1]:
        counter = counter + 1 
        print("message_3[",counter,"]: " + element)
except:
    print('Error Occurred')
# Out:
#  ---Approach I - Iterate over a string (element by element) using for loop---
# ---Traverse a String (Element by Element) using for Loop---
# M
# u
# h
# a
# m
# m
# a
# d
#  ---Approach II - Iterate over a string (element by element) using Indexing---
# ---Traverse a String (Element by Element) using for Loop with Indexing---
# message_2[ 0 ]: M
# message_2[ 1 ]: u
# message_2[ 2 ]: h
# message_2[ 3 ]: a
# message_2[ 4 ]: m
# message_2[ 5 ]: m
# message_2[ 6 ]: a
# message_2[ 7 ]: d
# ---Approach III - Iterate over a string (element by element) using Slicing---
# ---Traverse a String (Element by Element) using for Loop with Slicing---
# message_3[ 1 ]: M
# message_3[ 2 ]: u
# message_3[ 3 ]: h
# message_3[ 4 ]: a
# message_3[ 5 ]: m
# message_3[ 6 ]: m
# message_3[ 7 ]: a
# message_3[ 8 ]: d

# %% [markdown]
# ### **TODO Task 9**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1: Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ● Questions
#
#     o Apply methods presented in this Chapter to search the following elements in String 1
#
#         ▪ z
#         ▪ PBUH

# %%
'''
Purpose of Program
The main purpose of the program is to search specific character from a string and display the 
result on the Output Screen
'''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.' 
    print('---Original String before using find() Function---') 
    print(message)
    print("")
    
# Using find() Function to Search a Word from a String 
    index_of_character = message.find('PBUH') 
    print('---Index of Searched Term (PBUH) returned by Search Function---') 
    print(index_of_character) 
    print("") 

# Using find() Function to Search a Character from a String 
    print('---Original String before using find() Function---') 
    print(message) 
    print("")
    index_of_character = message.find('z') 
    print('Searching all instances of a Search Term (z)') 
    print(index_of_character) 
    print("") 

# Using split() and find() Function to Search a String using for Loop 
    split_message = message.split() 
    for elem in split_message: 
        index = elem.find("Muhammad") 
        if index != -1: 
            print(elem) 
except: 
    print('Error Occurred')
# Out:
# ---Original String before using find() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---Index of Searched Term (PBUH) returned by Search Function---
# 17
#
# ---Original String before using find() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# Searching all instances of a Search Term (z)
# 2
#
# Muhammad

# %% [markdown]
# ### **TODO Task 10**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1: Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ● Questions
#
#     o Apply method presented in this Chapter to sort String 1

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to sort the string in ascending order and display the result on 
the Output Screen
'''

# Input + Processing + Output
try:
    
# Approach I - sorted() Function to arrange string in Ascending Order
    
# Initialize Variable 
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.'
    print('---Approach I - sorted() Function to arrange string in Ascending Order---') 
    print('')
    print('---Original String before using sorted() Function---')
    print(message)
    print('')
    
# Using sorted() Function to arrange string in Ascending Order
    messages = sorted(message, reverse=False)
    print('---New String after using sorted() Function---') 
    print(messages)
    print('')
# Approach II – sorted() and split() Function to arrange string in Ascending Order
    print('---Approach II - sorted() and split() Function to arrange string in Ascending Order---')
    print('')
# Using sorted() and split() Function to arrange string in Ascending Order messages = 
    sorted(message.split(' '),reverse = False)
    print('---New String after using sorted() Function---') 
    print(messages)
except:
    print('Error Occurred')
# Out:
# ---Approach I - sorted() Function to arrange string in Ascending Order---
#
# ---Original String before using sorted() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using sorted() Function---
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '(', ')', '.', 'B', 'H', 'H', 'M', 'P', 'U', 'a', 'a', 'a', 'a', 'a', 'd', 'd', 'd', 'e', 'e', 'e', 'e', 'f', 'f', 'f', 'f', 'h', 'i', 'i', 'i', 'i', 'l', 'l', 'l', 'l', 'l', 'l', 'm', 'm', 'm', 'n', 'o', 'o', 'o', 'o', 'r', 'r', 'r', 's', 's', 's', 't', 'u', 'u', 'z']
#
# ---Approach II - sorted() and split() Function to arrange string in Ascending Order---
#
# ---New String after using sorted() Function---
# ...

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to sort the string in descending order and display the result on 
the Output Screen
'''
# Input + Processing + Output
try:
    
# Approach I - sorted() Function to arrange string in Descending Order
    
# Initialize Variable 
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.'
    print('---Approach I - sorted() Function to arrange string in Descending Order---')
    print('')
    print('---Original String before using sorted() Function---') 
    print(message)
    print('')
# Using sorted() Function to arrange string in Descending Order
    messages = sorted(message, reverse=True)
    print('---New String after using sorted() Function---')
    print('')
    print(messages)
    print('')

# Approach II – sorted() and split() Function to arrange string in Descending Order 
    print('---Approach II - sorted() and split() Function to arrange string in Descending Order---')
    print('')
    
# Using sorted() and split() Function to arrange string in Descending Order
    messages = sorted(message.split(' '),reverse = True)
    print('---New String after using sorted() Function---')
    print('')
    print(messages)
except:
    print('Error Occurred')
# Out:
# ---Approach I - sorted() Function to arrange string in Descending Order---
#
# ---Original String before using sorted() Function---
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using sorted() Function---
#
# ['z', 'u', 'u', 't', 's', 's', 's', 'r', 'r', 'r', 'o', 'o', 'o', 'o', 'n', 'm', 'm', 'm', 'l', 'l', 'l', 'l', 'l', 'l', 'i', 'i', 'i', 'i', 'h', 'f', 'f', 'f', 'f', 'e', 'e', 'e', 'e', 'd', 'd', 'd', 'a', 'a', 'a', 'a', 'a', 'U', 'P', 'M', 'H', 'H', 'B', '.', ')', '(', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# ---Approach II - sorted() and split() Function to arrange string in Descending Order---
#
# ---New String after using sorted() Function---
#
# ['us', 'role', 'of', 'model', 'life.', 'is', 'in', 'for', 'fields', 'all', 'Muhammad', 'Hazrat', '(PBUH)']

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to sort the string in alphabetically and display the result on the Output Screen '''

# Input + Processing + Output 
try: 
# Initialize Variable 
    message = 'Hazrat Muhammad (PBUH) is role model for us in all fields of life.'
    print('---Original String before using sorted() Function---')
    print ("")
    print(message)
    print ("")
    
# Using join() and sorted() Function to sort the String Alphabetically 
    message = ' '.join(sorted(message))
    print('---New String after using sorted() Function---') 
    print ("")
    print(message)
except:
    print('Error Occurred')
# Out:
# ---Original String before using sorted() Function---
#
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.
#
# ---New String after using sorted() Function---
#
#                         ( ) . B H H M P U a a a a a d d d e e e e f f f f h i i i i l l l l l l m m m n o o o o r r r s s s t u u z

# %% [markdown]
# ### **TODO Task 11**

# %% [markdown]
# ● Consider the following String and answer the questions given below
#
#     String 1: Hazrat Muhammad (PBUH) is role model
#
#     String 2: for us in all fields of life.
#
# ● Questions
#
#     o Apply method presented in this Chapter to merge String 1 and String 2

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program
The main purpose of the program is to concatenate a string using + operator and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable 
    message_1 = 'Hazrat Muhammad (PBUH) is role model '
    message_2 = 'for us in all fields of life.'
    print('---Original Message i.e., message_1---') 
    print("")
    print(message_1)
    print("")
    print('---Original Message i.e., message_2---') 
    print("")
    print(message_2)
    print("")
    
# Using + Operator Concatenate Two Strings 
    join_message = message_1 + message_2
    print('---New String after using + Operator---') 
    print("")
    print(join_message)
except:
    print('Error Occurred')
# Out:
# ---Original Message i.e., message_1---
#
# Hazrat Muhammad (PBUH) is role model
#
# ---Original Message i.e., message_2---
#
# for us in all fields of life.
# ---New String after using + Operator---
#
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to merge a string and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable
    message_1 = 'Hazrat Muhammad (PBUH) is role model'
    message_2 = 'for us in all fields of life.'
    print('---Original Message i.e., message_1---') 
    print("")
    print(message_1)
    print("")
    print('---Original Message i.e., message_2 ---')
    print("")
    print(message_2)
    print("")
    
# Using join() Function to Concatenate Two Strings 
    join_message = ' '.join([message_1,message_2]) 
    print('---New String after using join() Function---') 
    print("")
    print(join_message)
except:
    print('Error Occurred')
# Out:
# ---Original Message i.e., message_1---
#
# Hazrat Muhammad (PBUH) is role model
#
# ---Original Message i.e., message_2 ---
#
# for us in all fields of life.
#
# ---New String after using join() Function---
#
# Hazrat Muhammad (PBUH) is role model for us in all fields of life.

# %% [markdown]
# ### **TODO Task 12**

# %% [markdown]
# ● Consider the following Data Values and answer the questions given below
#
#     Data Values
#
#         String: CNIC No.
#         String: Address
#         String: Country
#
# ● Questions
#
#     o Take Input from User his / her CNIC No, Address and Country. Pass these three attributes to a Function and print the values on the Output Screen.

# %%
'''
Purpose of Program
The main purpose of the program is to pass strings to a function and display the result on the 
Output Screen
'''

def displayUserInformation(cnic_no, address, country): 
    print("CNIC NO.: ", cnic_no)
    print("Address: ",address)
    print("Country: ",country) 

if __name__ == "__main__": # main() Function
    try:
# Input
        cnic_no = input("Enter your CNIC NO.:") 
        address = input("Enter your Address: ")
        country = input("Enter your Country:")
        print("")
    
# Processing + Output
        displayUserInformation(cnic_no, address, country) 

    except ValueError:
        print("Error! Enter Valid Values")
# Out:
# Enter your CNIC NO. 34523
# Enter your Address:  dsfgafss
# Enter your Country aeeeaew
# CNIC NO.:  34523
# Address:  dsfgafss
# Country:  aeeeaew

# %% [markdown]
# ## **Lecture 18**

# %% [markdown]
# ### **TODO Task 1**

# %% [markdown]
# ● Declare and Initialize a List called ghazwa_in_Islam using the [] and list() Function?
#
# ● Note
#
#     o The elements of ghazwa_in_Islam are as follows
#         ▪ Badr
#         ▪ Uhud
#         ▪ Khandaq
#         ▪ Banu Qurayza
#         ▪ Banu l-Mustaliq
#         ▪ Khaybar
#         ▪ Conquest of Mecca
#         ▪ Hunayn
#         ▪ Al-Ta'if

# %%
'''
Purpose of Program
The main purpose of the program is to initialize a list and display its content (data values) on 
the Output Screen
'''
# List Declaration and Initialization - Method 1: Use []
try:
    print("---List Initialization - Use []---")
    print ("")
    
# List Initialization
    ghazwa_in_Islam = ['Badr','Uhud','Khandaq','Banu Qurayza','Banu l-Mustaliq','Khaybar','Conquest of Mecca','Hunayn',"Al-Ta'if"]
    
# Display Data Values of a List
    print("Data Values of ghazwa_in_Islam List:", ghazwa_in_Islam) 
    print ("")
    
# Display Length of a List using len() Function 
    print("Length of ghazwa_in_Islam List:", len(ghazwa_in_Islam))
    print ("")
    
# Display Type of a List using type() Function 
    print("Data-Type of ghazwa_in_Islam List:", type(ghazwa_in_Islam)) 
    print ("")
except: 
    print("Error Occurred")

print("---------------------------------------------------------") 


# List Declaration and Initialization - Method 2: Use list() Function

try:
    print("---List Initialization - Use list() Function---")
    print ("")
    
# List Initialization
    ghazwa_in_Islam_1 = ['Badr','Uhud','Khandaq','Banu Qurayza','Banu l-Mustaliq','Khaybar','Conquest of Mecca','Hunayn',"Al-Ta'if"]

# Display Data Values of a List
    print("Data Values of ghazwa_in_Islam_1 List:", ghazwa_in_Islam_1)
    print ("")

# Display Length of a List using len() Function
    print("Length of ghazwa_in_Islam_1 List:", len(ghazwa_in_Islam_1))
    print ("")
    
# Display Type of a List using type() Function
    print("Data-Type of ghazwa_in_Islam_1 List:", type(ghazwa_in_Islam_1)) 
    print ("")
    
except:
    print("Error Occurred")
# Out:
# ---List Initialization - Use []---
#
# Data Values of ghazwa_in_Islam List: ['Badr', 'Uhud', 'Khandaq', 'Banu Qurayza', 'Banu l-Mustaliq', 'Khaybar', 'Conquest of Mecca', 'Hunayn', "Al-Ta'if"]
#
# Length of ghazwa_in_Islam List: 9
#
# Data-Type of ghazwa_in_Islam List: <class 'list'>
#
# ---------------------------------------------------------
# ---List Initialization - Use list() Function---
#
# Data Values of ghazwa_in_Islam_1 List: ['Badr', 'Uhud', 'Khandaq', 'Banu Qurayza', 'Banu l-Mustaliq', 'Khaybar', 'Conquest of Mecca', 'Hunayn', "Al-Ta'if"]
#
# Length of ghazwa_in_Islam_1 List: 9
#
# Data-Type of ghazwa_in_Islam_1 List: <class 'list'>

# %% [markdown]
# ### **TODO Task 2**

# %% [markdown]
# ● Consider the following two Lists and answer the questions given below
#
#     o prophets = [‘Hazrat Muhammad (PBUH)’, ‘Hazrat Ibrahim (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ● Questions
#
#     o Access Elements of the prophets and ages lists suing
#         ▪ Indexing
#         ▪ Negative Indexing
#         ▪ Slicing

# %% [markdown]
# #### **Indexing**

# %%
'''
Purpose of Program
The main purpose of the program is to access element(s) of a list using indexing and display the 
result on the output screen
'''
try:
# Initialize List 
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
                                                                                 
# Access Element(s) of First List using Indexing
    print("---Access Element(s) of First List using Indexing---")
    print("")
    print("prophets[0]:",prophets[0])
    print("prophets[1]:",prophets[1])
    print("prophets[2]:",prophets[2])
    print("prophets[3]:",prophets[3]) 
    print("prophets[4]:",prophets[4])
    print("") 
                                                                                 
# Access Element(s) of Second List using Indexing                                                                                 
    print("---Access Element(s) of Second List using Indexing---")
    print("")
    print("ages[0]:",ages[0])
    print("ages[1]:",ages[1])
    print("ages[2]:",ages[2])
    print("ages[3]:",ages[3]) 
    print("ages[4]:",ages[4])
    print("ages[5]:",ages[5])
    print("")                        
except:
    print("Error Occurred")
# Out:
# ---Access Element(s) of First List using Indexing---
#
# prophets[0]: Hazrat Muhammad (PBUH)
# prophets[1]: Hazrat Ibrahim (A.S.)
# prophets[2]: Hazrat Mosa (A.S.)
# prophets[3]: Hazrat Isa (A.S.)
# prophets[4]: Hazrat Adam (A.S.)
#
# ---Access Element(s) of Second List using Indexing---
#
# ages[0]: 25
# ages[1]: 30
# ages[2]: 15
# ages[3]: 20
# ages[4]: 22
# ages[5]: 33

# %% [markdown]
# #### **Negative Indexing**

# %%
'''
Purpose of Program
The main purpose of the program is to access element(s) of a list using negative indexing and 
display the result on the output screen
'''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]

# Access Element(s) of First List using Negative Indexing
    print("---Access Element(s) of First List using Negative Indexing---")
    print("")
    print("prophets[-1]:",prophets[-1])
    print("prophets[-2]:",prophets[-2]) 
    print("prophets[-3]:",prophets[-3]) 
    print("prophets[-4]:",prophets[-4])
    print("prophets[-5]:",prophets[-5])
    print("") 
                                                                                 
# Access Element(s) of Second List using Negative Indexing                                                                                 
    print("---Access Element(s) of Second List using Negative Indexing---")
    print("")
    print("ages[-1]:",ages[-1])
    print("ages[-2]:",ages[-2]) 
    print("ages[-3]:",ages[-3]) 
    print("ages[-4]:",ages[-4])
    print("ages[-5]:",ages[-5])
    print("ages[-6]:",ages[-6])
    print("") 
except:
    print("Error Occurred")
# Out:
# ---Access Element(s) of First List using Negative Indexing---
#
# prophets[-1]: Hazrat Adam (A.S.)
# prophets[-2]: Hazrat Isa (A.S.)
# prophets[-3]: Hazrat Mosa (A.S.)
# prophets[-4]: Hazrat Ibrahim (A.S.)
# prophets[-5]: Hazrat Muhammad (PBUH)
#
# ---Access Element(s) of Second List using Negative Indexing---
#
# ages[-1]: 33
# ages[-2]: 22
# ages[-3]: 20
# ages[-4]: 15
# ages[-5]: 30
# ages[-6]: 25

# %% [markdown]
# #### **Slicing**

# %%
'''
Purpose of Program
The main purpose of the program is to access element(s) of a list using slicing and display the 
result on the output screen
'''
try:
# Initialize List 
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
# Access Element(s) of First List using Slicing
    print("---Access Element(s) of First List using Slicing---")
    print("")
    print("prophets[2:4]:",prophets[2:4])
    print("")

# Access from 2nd element till 4th element
    print("prophets[1:4]:", prophets[1:4])
    print("")

# Access from start till 3rd element 
    print("prophets[:3]:", prophets[:3])
    print("")

# Access from 2nd element till end
    print("prophets[1:]:", prophets[1:])
    print("")

# Access from start till 3rd last element 
    print("prophets[:-2]:", prophets[:-2]) 
    print("")

# Access from 3rd last element till 1st last element 
    print("prophets[-3:-1]:", prophets[-3:-1]) 
    print("")

# Access from 2nd element till 2nd last element
    print("prophets[1:-1]:", prophets[1:-1])
    print("")

# Access all elements 
    print("prophets[:]:",prophets[:]) 
    print("")
    
# Access Element(s) of Second List using Slicing
    print("---Access Element(s) of Second List using Slicing---")
    print("")
    print("ages[2:4]:",ages[2:4])
    print("")

# Access from 2nd element till 4th element
    print("ages[1:4]:", ages[1:4])
    print("")

# Access from start till 3rd element 
    print("ages[:3]:", ages[:3])
    print("")

# Access from 2nd element till end
    print("ages[1:]:", ages[1:])
    print("")

# Access from start till 3rd last element 
    print("ages[:-2]:", ages[:-2]) 
    print("")

# Access from 3rd last element till 1st last element 
    print("ages[-3:-1]:", ages[-3:-1]) 
    print("")

# Access from 2nd element till 2nd last element
    print("ages[1:-1]:", ages[1:-1])
    print("")

# Access all elements 
    print("ages[:]:",ages[:]) 
    print("")

except: 
    print("Error Occurred")
# Out:
# ---Access Element(s) of First List using Slicing---
#
# prophets[2:4]: ['Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)']
#
# prophets[1:4]: ['Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)']
#
# prophets[:3]: ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)']
#
# prophets[1:]: ['Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# prophets[:-2]: ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)']
#
# prophets[-3:-1]: ['Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)']
#
# prophets[1:-1]: ['Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)']
#
# prophets[:]: ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---Access Element(s) of Second List using Slicing---
#
# ages[2:4]: [15, 20]
#
# ages[1:4]: [30, 15, 20]
#
# ages[:3]: [25, 30, 15]
#
# ages[1:]: [30, 15, 20, 22, 33]
#
# ages[:-2]: [25, 30, 15, 20]
#
# ...

# %% [markdown]
# ### **TODO Task 3**

# %% [markdown]
# ● Consider the following two Lists and answer the questions given below
#
#     o prophets = [‘Hazrat Muhammad (PBUH)’, ‘Hazrat Ibrahim (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ● Questions
#
#     o Insert Elements to prophets and ages lists using following methods (as shown in this Chapter)
#         ▪ Method 1 - Add a New Element at the Start of a List
#         ▪ Method 2 - Add a New Element at the End of a List
#         ▪ Method 3 - Add a New Element at a Desired Location of a List

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to add a new element at the start of a list '''

try:
    print("---Add a Single Element at Start of First List---")

# List Initialization
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    print("---Original List before Adding Element at Start of First List---") 
    print("")
    print(prophets)
    print("")
# Add Data Value at Start of a List using insert() Function
    prophets.insert(0,"Hazrat Yousaf (A.S.)")
    print("")
                                                                                                      
# Display Updated List after Adding Element at Start of First List
    print("---Updated List after Adding Element at Start of First List---") 
    print("")
    print(prophets)
    print("")
except:
    print("Error Occurred")

print("-------------------------------------------------------------")



try:
    print("---Add a Single Element at Start of Second List---")

# List Initialization
    ages = [25, 30, 15, 20, 22, 33]
    print("---Original List before Adding Element at Start of Second List---") 
    print("")
    print(ages)
    print("")
# Add Data Value at Start of a List using insert() Function
    ages.insert(0,18)
    print("")
                                                                                                      
# Display Updated List after Adding Element at Start of a List
    print("---Updated List after Adding Element at Start of a List---") 
    print("")
    print(ages)
    print("")
except:
    print("Error Occurred")
# Out:
# ---Add a Single Element at Start of First List---
# ---Original List before Adding Element at Start of First List---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
#
# ---Updated List after Adding Element at Start of First List---
#
# ['Hazrat Yousaf (A.S.)', 'Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# -------------------------------------------------------------
# ---Add a Single Element at Start of Second List---
# ---Original List before Adding Element at Start of Second List---
#
# [25, 30, 15, 20, 22, 33]
#
#
# ---Updated List after Adding Element at Start of a List---
#
# [18, 25, 30, 15, 20, 22, 33]

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program The main purpose of the program is to add a new element at the end of a list '''

try:
    print("---Add a Single Element at End of First List---")

# List Initialization
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    print("---Original List before Adding Element at End of First List---") 
    print("")
    print(prophets)
    print("")
# Add Data Value at End of a List using insert() Function
    prophets.append("Hazrat Yousaf (A.S.)")
    print("")
                                                                                                      
# Display Updated List after Adding Element at End of First List
    print("---Updated List after Adding Element at End of First List---") 
    print("")
    print(prophets)
    print("")
except:
    print("Error Occurred")

print("-------------------------------------------------------------")



try:
    print("---Add a Single Element at End of Second List---")

# List Initialization
    ages = [25, 30, 15, 20, 22, 33]
    print("---Original List before Adding Element at End of Second List---") 
    print("")
    print(ages)
    print("")
# Add Data Value at End of a List using insert() Function
    ages.append(18)
    print("")
                                                                                                      
# Display Updated List after Adding Element at End of a List
    print("---Updated List after Adding Element at Start of a List---") 
    print("")
    print(ages)
    print("")
except:
    print("Error Occurred")
# Out:
# ---Add a Single Element at Start of First List---
# ---Original List before Adding Element at Start of First List---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
#
# ---Updated List after Adding Element at Start of First List---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)', 'Hazrat Yousaf (A.S.)']
#
# -------------------------------------------------------------
# ---Add a Single Element at Start of Second List---
# ---Original List before Adding Element at Start of Second List---
#
# [25, 30, 15, 20, 22, 33]
#
#
# ---Updated List after Adding Element at Start of a List---
#
# [25, 30, 15, 20, 22, 33, 18]

# %% [markdown]
# #### **Method 3**

# %%
'''
Purpose of Program
The main purpose of the program is to add new element(s) at a desired location of a list'''

try:
    print("---Add a Single Element at Desired Location of First List---")

# List Initialization
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    print("---Original List before Adding Element at Desired Location of First List---") 
    print("")
    print(prophets)
    print("")
# Add Data Value at Desired Location of a List using insert() Function
    prophets.insert(1,"Hazrat Yousaf (A.S.)")
    print("")
                                                                                                      
# Display Updated List after Adding Element at Desired Location of First List
    print("---Updated List after Adding Element at Desired Location of First List---") 
    print("")
    print(prophets)
    print("")
except:
    print("Error Occurred")

print("-------------------------------------------------------------")



try:
    print("---Add a Single Element at Desired Location of Second List---")

# List Initialization
    ages = [25, 30, 15, 20, 22, 33]
    print("---Original List before Adding Element at Desired Location of Second List---") 
    print("")
    print(ages)
    print("")
# Add Data Value at Desired Location of a List using insert() Function
    ages.insert(2,18)
    print("")
                                                                                                      
# Display Updated List after Adding Element at Desired Location of a List
    print("---Updated List after Adding Element at Desired Location of a List---") 
    print("")
    print(ages)
    print("")
except:
    print("Error Occurred")
# Out:
# ---Add a Single Element at Desired Location of First List---
# ---Original List before Adding Element at Desired Location of First List---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
#
# ---Updated List after Adding Element at Desired Location of First List---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Yousaf (A.S.)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# -------------------------------------------------------------
# ---Add a Single Element at Desired Location of Second List---
# ---Original List before Adding Element at Desired Location of Second List---
#
# [25, 30, 15, 20, 22, 33]
#
#
# ---Updated List after Adding Element at Desired Location of a List---
#
# [25, 30, 18, 15, 20, 22, 33]

# %% [markdown]
# ### **TODO Task 4**

# %% [markdown]
# ● Consider the following two Lists and answer the questions given below
#
#     o prophets = [‘Hazrat Muhammad (PBUH)’, ‘Hazrat Ibrahim (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ● Questions
#
#     o Traverse selected lists using following methods (as shown in this Chapter)
#         ▪ Method 1: Traversing an Entire List
#         ▪ Method 2: Traversing a List (Element by Element)

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse an entire list and display the result on the Output 
Screen
'''

try:
    
# List Initialization
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]

# Traverse an entire list
    print(prophets) 
    print("")
    print(ages)
except:
    print('Error Occurred')
# Out:
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# [25, 30, 15, 20, 22, 33]

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse a list (element by element) and display the result 
on the Output Screen
'''

try:
# Iterate over First List (element by element) using for loop---

# List Initialization
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]

# Iterate over First List (element by element) using for loop
    print("Iterate over First List (element by element) using for loop---")
    print("")
    print("---Traverse First List (Element by Element) using for Loop---")
    print("")
    for element in prophets:
        print (element)
    print("")
    
# Iterate over Second List (element by element) using for loop
    print("Iterate over Second List (element by element) using for loop---")
    print("")
    print("---Traverse Second List (Element by Element) using for Loop---")
    print("")
    for element in ages:
        print (element)
except:
    print('Error Occurred')
# Out:
# Iterate over First List (element by element) using for loop---
#
# ---Traverse First List (Element by Element) using for Loop---
#
# Hazrat Muhammad (PBUH)
# Hazrat Ibrahim (A.S.)
# Hazrat Mosa (A.S.)
# Hazrat Isa (A.S.)
# Hazrat Adam (A.S.)
#
# Iterate over Second List (element by element) using for loop---
#
# ---Traverse Second List (Element by Element) using for Loop---
#
# 25
# 30
# 15
# 20
# 22
# 33

# %% [markdown]
# ### **TODO Task 5**

# %% [markdown]
# ● Consider the following two Lists and answer the questions given below
#
#     o prophets = [‘Hazrat Muhammad (PBUH)’, ‘Hazrat Ibrahim (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ● Questions
#
#     o Search from selected lists using following methods (as shown in this Chapter)
#         ▪ Method 1: Search Specific Character from a List

# %%
'''
Purpose of Program
the main purpose of the program is to search a specific element from a list '''

# Approach I – Using in Operator to Search Element in First List

try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]

    print("Using in Operator to Search Element in First List")
    print("")
    element = 'Hazrat Ibrahim (A.S.)'

# Using in operator to Search Element in First List 
    if element in prophets:
        print(element + " is in List") 
        print("")
    else:
        print(element + " is not in List")
        print("")
        
    print("Using in Operator to Search Element in Second List")
    print("")
    element = 15

# Using in operator to Search Element in Second List 
    if element in ages:
        print(element, "is in List") 
        print("")
    else:
        print(element, "is not in List")
        print("")
except:
    print('Error Occurred')
# Out:
# Using in Operator to Search Element in First List
#
# Hazrat Ibrahim (A.S.) is in List
#
# Using in Operator to Search Element in Second List
#
# 15 is in List

# %% [markdown]
# ### **TODO Task 6**

# %% [markdown]
# ●  Consider the following two Lists and answer the questions given below
#
#     o prophets  =  [‘Hazrat Muhammad (PBUH)’,  ‘Hazrat  Ibrahim  (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ●  Questions
#
#     o Sort Elements of the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Sort a List Alphabetically
#         ▪   Method 2: Sort a List in Ascending Order
#         ▪   Method 3: Sort a List in Descending Order

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to sort a list alphabetically '''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original First List before using sort() Function---')
    print("")
    print(prophets)
    print("")
    
# Using sort() Function to sort First List Alphabetically 
    prophets.sort()
    print('---New First List after using sort() Function---') 
    print("")
    print(prophets)
    print("")
    
    print('---Original Second List before using sort() Function---')
    print("")
    print(ages)
    print("")
    
# Using sort() Function to sort Second List Alphabetically 
    ages.sort()
    print('---New Second List after using sort() Function---') 
    print("")
    print(ages)
    print("")    
except:
    print('Error Occurred')
# Out:
# ---Original First List before using sort() Function---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---New First List after using sort() Function---
#
# ['Hazrat Adam (A.S.)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Muhammad (PBUH)']
#
# ---Original Second List before using sort() Function---
#
# [25, 30, 15, 20, 22, 33]
#
# ---New Second List after using sort() Function---
#
# [15, 20, 22, 25, 30, 33]

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to sort a list alphabetically '''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original First List before using sort() Function---')
    print("")
    print(prophets)
    print("")
    
# Using sort() Function to sort First List Alphabetically 
    prophets.sort(reverse = False)
    print('---New First List after using sort() Function---') 
    print("")
    print(prophets)
    print("")
    
    print('---Original Second List before using sort() Function---')
    print("")
    print(ages)
    print("")
    
# Using sort() Function to sort Second List Alphabetically 
    ages.sort(reverse = False)
    print('---New Second List after using sort() Function---') 
    print("")
    print(ages)
    print("")    
except:
    print('Error Occurred')
# Out:
# ---Original First List before using sort() Function---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---New First List after using sort() Function---
#
# ['Hazrat Adam (A.S.)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Muhammad (PBUH)']
#
# ---Original Second List before using sort() Function---
#
# [25, 30, 15, 20, 22, 33]
#
# ---New Second List after using sort() Function---
#
# [15, 20, 22, 25, 30, 33]

# %% [markdown]
# #### **Method 3**

# %%
'''
Purpose of Program
The main purpose of the program is to sort a list alphabetically '''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original First List before using sort() Function---')
    print("")
    print(prophets)
    print("")
    
# Using sort() Function to sort First List Alphabetically 
    prophets.sort(reverse = True)
    print('---New First List after using sort() Function---') 
    print("")
    print(prophets)
    print("")
    
    print('---Original Second List before using sort() Function---')
    print("")
    print(ages)
    print("")
    
# Using sort() Function to sort Second List Alphabetically 
    ages.sort(reverse = True)
    print('---New Second List after using sort() Function---') 
    print("")
    print(ages)
    print("")    
except:
    print('Error Occurred')
# Out:
# ---Original First List before using sort() Function---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---New First List after using sort() Function---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---Original Second List before using sort() Function---
#
# [25, 30, 15, 20, 22, 33]
#
# ---New Second List after using sort() Function---
#
# [33, 30, 25, 22, 20, 15]

# %% [markdown]
# ### **TODO Task 7**

# %% [markdown]
# ●  Consider the following two Lists and answer the questions given below
#
#     o prophets  =  [‘Hazrat Muhammad (PBUH)’,  ‘Hazrat  Ibrahim  (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ●  Questions
#
#     o Merge Elements of the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Concatenate Lists using + Operator
#         ▪   Method 2: Concatenate Lists using * Operator
#         ▪   Method 3: Merge Lists using append() Function
#         ▪   Method 4: Merge Lists using extend() Function

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using + operator '''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Merging---')
    print("")
    print(prophets)
    print("")
    print(ages)
    print("")
    
# Using + Operator to Concatenate Lists 
    print('---New List after Merging---') 
    for count in range(len(prophets)):
        Merge_prophets_ages = prophets[count] + " - " + str(ages[count]) 
        print(Merge_prophets_ages)    

except:
    print('Error Occurred')
# Out:
# ---Original Lists before Merging---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after Merging---
# Hazrat Muhammad (PBUH) - 25
# Hazrat Ibrahim (A.S.) - 30
# Hazrat Mosa (A.S.) - 15
# Hazrat Isa (A.S.) - 20
# Hazrat Adam (A.S.) - 22

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using * operator '''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Merging---')
    print("")
    print(prophets)
    print("")
    print(ages)
    print("")
    
# Using * Operator to Concatenate Lists 
    print('---New List after Merging---') 
    for count in range(len(prophets)):
        Merge_prophets_ages = [*(prophets[count],ages[count] )] 
        print(Merge_prophets_ages)    

except:
    print('Error Occurred')
# Out:
# ---Original Lists before Merging---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after Merging---
# ['Hazrat Muhammad (PBUH)', 25]
# ['Hazrat Ibrahim (A.S.)', 30]
# ['Hazrat Mosa (A.S.)', 15]
# ['Hazrat Isa (A.S.)', 20]
# ['Hazrat Adam (A.S.)', 22]

# %% [markdown]
# #### **Method 3**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using append () Function '''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Merging---')
    print("")
    print(prophets)
    print("")
    print(ages)
    print("")
    
# Using append () Function to Concatenate Lists 
    print('---New List after Merging---') 
    for element in ages:
        prophets.append(element) 
    print(prophets)    

except:
    print('Error Occurred')
# Out:
# ---Original Lists before Merging---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after Merging---
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)', 25, 30, 15, 20, 22, 33]

# %% [markdown]
# #### **Method 4**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using extend () Function '''
try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Merging---')
    print("")
    print(prophets)
    print("")
    print(ages)
    print("")
    
# Using extend () Function to Concatenate Lists 
    print('---New List after Merging---') 
    print("")
    prophets.extend(ages)
    print(prophets)    

except:
    print('Error Occurred')
# Out:
# ---Original Lists before Merging---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after Merging---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)', 25, 30, 15, 20, 22, 33]

# %% [markdown]
# ### **TODO Task 8**

# %% [markdown]
# ●  Consider the following two Lists and answer the questions given below
#
#     o prophets  =  [‘Hazrat Muhammad (PBUH)’,  ‘Hazrat  Ibrahim  (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ●  Questions
#
#     o Update Elements of the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Update Entire List using Slicing
#         ▪   Method 2: Update List Element by Element using Indexing

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to update entire list using Slicing '''

try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Updating---')
    print("")
    print(prophets)
    print("")
    print(ages)
    print("")
    
# Update Entire List using Slicing
    print('---New List after Updating---') 
    print("")
    prophets[0:5] = ['Hazrat Muhammad (PBUH) – 25','Hazrat Ibrahim (A.S.) - 30','Hazrat Mosa (A.S.) - 15','Hazrat Isa (A.S.) - 20','Hazrat Adam (A.S.) - 22'] 
    print(prophets)    

except:
    print('Error Occurred')
# Out:
# ---Original Lists before Merging---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after Updating---
#
# ['Hazrat Muhammad (PBUH) – 25', 'Hazrat Ibrahim (A.S.) - 30', 'Hazrat Mosa (A.S.) - 15', 'Hazrat Isa (A.S.) - 20', 'Hazrat Adam (A.S.) - 22']

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to update entire list using Indexing '''

try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Updating---')
    print("")
    print(prophets)
    print("")
    print(ages)
    print("")
    
# Update List Element by Element using Indexing
    print('---New List after Updating---') 
    print("")
    prophets[2] = 'Hazrat Yousaf (A.S.)'
    print(prophets)    

except:
    print('Error Occurred')
# Out:
# ---Original Lists before Updating---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after Updating---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Yousaf (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']

# %% [markdown]
# ### **TODO Task 9**

# %% [markdown]
# ●  Consider the following two Lists and answer the questions given below
#
#     o prophets  =  [‘Hazrat Muhammad (PBUH)’,  ‘Hazrat  Ibrahim  (A.S.)’, ‘Hazrat Mosa (A.S.)’, ‘Hazrat Isa (A.S.)’, ‘Hazrat Adam (A.S.)’]
#     o ages = [25, 30, 15, 20, 22, 33]
#
# ●  Questions
#
#     o Remove Elements from the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Remove Entire / Element(s) from List using del
#         ▪   Method 2: Remove Entire List using clear() Function
#         ▪   Method 3: Remove Specific Element from a List using remove() Function
#         ▪   Method 4:  Remove  Last  Element  from  a  List  using  pop()Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using del '''

# Approach I – Delete an Entire List using del Function

try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']  
    print('---Original List before Updating---')
    print("")
    print(prophets)
    print("")
    
# Delete Entire List using del Function 
    print('---New List after using del Function---') 
    print("")
    del prophets 
    print(prophets) 
    
except Exception as ex: 
    print(ex)    
    
# Approach II – Delete a Single Element from a List using del Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using del Function 
    print('---New List after using del Function---') 
    print("")
    del ages[1]
    print(ages) 
except:
    print('Error Occurred')
# Out:
# ---Original List before Updating---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---New List after using del Function---
#
# name 'prophets' is not defined
#
# ---Original List before Updating---
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after using del Function---
#
# [25, 15, 20, 22, 33]

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using clear() Function '''

# Approach I – Delete an Entire List using clear() Function

try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']  
    print('---Original List before Updating---')
    print("")
    print(prophets)
    print("")
    
# Delete Entire List using clear() Function 
    print('---New List after using clear() Function---') 
    print("")
    prophets.clear() 
    print(prophets) 
    
except:
    print('Error Occurred')   
    
# Approach II – Delete a Single Element from a List using clear() Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using clear() Function 
    print('---New List after using clear() Function---') 
    print("")
    ages.clear()
    print(ages) 
except:
    print('Error Occurred')
# Out:
# ---Original List before Updating---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---New List after using clear() Function---
#
# []
#
# ---Original List before Updating---
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after using clear() Function---
#
# []

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using remove() Function '''

# Approach I – Delete an Entire List using remove() Function

try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']  
    print('---Original List before Updating---')
    print("")
    print(prophets)
    print("")
    
# Delete Entire List using remove() Function 
    print('---New List after using remove() Function---') 
    print("")
    prophets.remove('Hazrat Isa (A.S.)') 
    print(prophets) 
    
except:
    print('Error Occurred')   
    
# Approach II – Delete a Single Element from a List using remove() Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using remove() Function 
    print('---New List after using remove() Function---') 
    print("")
    ages.remove(33)
    print(ages) 
except:
    print('Error Occurred')
# Out:
# ---Original List before Updating---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---New List after using remove() Function---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---Original List before Updating---
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after using remove() Function---
#
# [25, 30, 15, 20, 22]

# %% [markdown]
# #### **Method 4**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using pop() Function '''

# Approach I – Delete an Entire List using pop() Function

try:
# Initialize List
    prophets = ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']  
    print('---Original List before Updating---')
    print("")
    print(prophets)
    print("")
    
# Delete Entire List using pop() Function 
    print('---New List after using pop() Function---') 
    print("")
    prophets.pop(4) 
    print(prophets) 
    
except:
    print('Error Occurred')   
    
# Approach II – Delete a Single Element from a List using pop() Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using pop() Function 
    print('---New List after using pop() Function---') 
    print("")
    ages.pop(3)
    print(ages) 
except:
    print('Error Occurred')
# Out:
# ---Original List before Updating---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)', 'Hazrat Adam (A.S.)']
#
# ---New List after using pop() Function---
#
# ['Hazrat Muhammad (PBUH)', 'Hazrat Ibrahim (A.S.)', 'Hazrat Mosa (A.S.)', 'Hazrat Isa (A.S.)']
#
# ---Original List before Updating---
#
# [25, 30, 15, 20, 22, 33]
#
# ---New List after using pop() Function---
#
# [25, 30, 15, 22, 33]

# %% [markdown]
# ### **TODO Task 10**

# %% [markdown]
# ●  Consider the following Lists and answer the questions given below
#
#     o list_of_cars = ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
#     o prime_numbers = [2, 3, 5, 7, 11, 13, 17, 19]
#
# ●  Questions
#
#     o Use list_of_cars to create a new list which contains names of cars starting with character M?
#     o Use prime_numbers to create a new list which contains number less than 10?

# %%
''' Purpose of Program 
The main purpose of the program is to create a new list based on values of an existing list ''' 
try: 
# List Initialization 
    list_of_cars = ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
# Create a new list with element of previous List i.e., qul_shareef 
    list_comprehension = [element for element in list_of_cars if "M" in element]
    print("New List containing alphabet 'M':",list_comprehension)
    print("")
except:
    print("Error Occurred")

try: 
# List Initialization 
    prime_numbers = [2, 3, 5, 7, 11, 13, 17, 19]
# Create a new list with element of previous List i.e., qul_shareef 
    list_comprehension = [element for element in prime_numbers if (element < 10)]
    print("New List containing prime numbers less than 10:",list_comprehension) 
except:
    print("Error Occurred")
# Out:
# New List containing alphabet 'M': ['Mehran', 'Mercedes']
#
# New List containing prime numbers less than 10: [2, 3, 5, 7]

# %% [markdown]
# ### **TODO Task 11**

# %% [markdown]
# ●  Consider the following Lists and answer the questions given below
#
# ●  student_information = [
#
#     [‘Registration No.’, ‘Name’, ‘Degree Program’, ‘Course’]
#     1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'],
#     2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
#     3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
#     4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
#     5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
# ]
#
# ●  Questions
#
#     o Apply following operations on the given Nested List (as shown in this Chapter)?
#         ▪   Operation 1: Create a Nested List
#         ▪   Operation 2: Access Elements of a Nested List
#         ▪   Operation 3: Add New Element in a Nested List
#         ▪   Operation 4: Traverse a Nested List
#         ▪   Operation 5: Update Elements of a Nested List
#         ▪   Operation 6: Remove Elements of a Nested List

# %% [markdown]
# #### **Operation 1**

# %%
''' Purpose of Program 
The main purpose of the program is to create a nested list '''
# Initializing a Nested List i.e., Student 
try: 
    students = [ 
    ['Registration No.', 'Name', 'Degree Program', 'Course'],
    1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'], 
    2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
    3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
    4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
    5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
    ] 
    print("List of Students for Introduction to Python:")
    print("")
    print(students) 
    
# Data-Type of List i.e., students 
    print("")
    print("Data-Type of students:", type(students)) 
    
# Length of List i.e., students 
    print("")
    print("Length of students:", len(students)) 
except:
    print("Error Occurred")
# Out:
# List of Students for Introduction to Python:
#
# [['Registration No.', 'Name', 'Degree Program', 'Course'], 1, ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python'], 2, ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]
#
# Data-Type of students: <class 'list'>
#
# Length of students: 11

# %% [markdown]
# #### **Operation 2**

# %%
''' Purpose of Program 
The main purpose of the program is to access elements of a nested list using indexing '''
try: 
    students = [ 
    ['Registration No.', 'Name', 'Degree Program', 'Course'],
    1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'], 
    2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
    3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
    4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
    5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
    ] 
# Access Elements of Nested List using Indexing 
    print("Element at index students[0]:",students[0])
    print("Element at index students[1]:",students[1])
    print("Element at index students[2]:",students[2])
    print("Element at index students[3]:",students[3])
    print("Element at index students[4]:",students[4]) 
    print("Element at index students[5]:",students[5])
    print("Element at index students[6]:",students[6]) 
    print("Element at index students[7]:",students[7])
    print("Element at index students[8]:",students[8])
    print("Element at index students[9]:",students[9])
    print("Element at index students[10]:",students[10])
except:
    print("Error Occurred")
# Out:
# Element at index students[0]: ['Registration No.', 'Name', 'Degree Program', 'Course']
# Element at index students[1]: 1
# Element at index students[2]: ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python']
# Element at index students[3]: 2
# Element at index students[4]: ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning']
# Element at index students[5]: 3
# Element at index students[6]: ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning']
# Element at index students[7]: 4
# Element at index students[8]: ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP']
# Element at index students[9]: 5
# Element at index students[10]: ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']

# %% [markdown]
# #### **Operation 3**

# %%
'''
Purpose of Program
The main purpose of the program is to add elements in a nested list
'''
try: 
    students = [ 
    ['Registration No.', 'Name', 'Degree Program', 'Course'],
    1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'], 
    2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
    3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
    4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
    5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
    ] 
# Display Original List 
    print("---Original Nested List---") 
    print("")
    print(students) 
    print("------------------------------------------------") 
    
# Display List after Adding a New Element at the Start of a List 
    print("")
    print("---New List after using insert() Function---") 
    print("")
    
# Adding Element at the Start of a List using insert() Function 
    students.insert(0,'List of Students of Introduction to Python') 
    print(students)
except:
    print("Error Occurred")
# Out:
# ---Original Nested List---
#
# [['Registration No.', 'Name', 'Degree Program', 'Course'], 1, ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python'], 2, ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]
# ------------------------------------------------
#
# ---New List after using insert() Function---
#
# ['List of Students of Introduction to Python', ['Registration No.', 'Name', 'Degree Program', 'Course'], 1, ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python'], 2, ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]

# %% [markdown]
# #### **Operation 4**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse a nested list
'''
try: 
    students = [ 
    ['Registration No.', 'Name', 'Degree Program', 'Course'],
    1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'], 
    2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
    3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
    4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
    5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
    ] 
    
# Traverse an Entire List 
    print(students)

except Exception as ex: 
    print(ex)
# Out:
# [['Registration No.', 'Name', 'Degree Program', 'Course'], 1, ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python'], 2, ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]

# %% [markdown]
# #### **Operation 5**

# %%
''' Purpose of Program 
The main purpose of the program is to update elements of a nested list '''
'''
Purpose of Program
The main purpose of the program is to add elements in a nested list
'''
try: 
    students = [ 
    ['Registration No.', 'Name', 'Degree Program', 'Course'],
    1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'], 
    2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
    3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
    4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
    5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
    ] 
# Display Original List 
    print("---Original Nested List---") 
    print("")
    print(students) 
    print("------------------------------------------------") 
    
# Display List after Updating Elements 
    print("")
    print("---New List after Updating Elements ---") 
    print("")
    
# Adding Element at the Start of a List using insert() Function 
    students[1] = 0 
    students[2][0] = 'FA15-BCS-111' 
    students[2][1] = 'Mahnoor' 
    students[2][2] = 'BSCS' 
    students[3] = 1 
    students[4][0] = 'FA15-BCS-115' 
    students[4][1] = 'Ibrahim'
    students[4][2] = 'BSCS' 
    print(students)
except:
    print("Error Occurred")
# Out:
# ---Original Nested List---
#
# [['Registration No.', 'Name', 'Degree Program', 'Course'], 1, ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python'], 2, ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]
# ------------------------------------------------
#
# ---New List after Updating Elements ---
#
# [['Registration No.', 'Name', 'Degree Program', 'Course'], 0, ['FA15-BCS-111', 'Mahnoor', 'BSCS', 'Introduction to Python'], 1, ['FA15-BCS-115', 'Ibrahim', 'BSCS', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]

# %% [markdown]
# #### **Operation 6**

# %%
''' Purpose of Program 
The main purpose of the program is to remove elements from a nested list '''

try: 
    students = [ 
    ['Registration No.', 'Name', 'Degree Program', 'Course'],
    1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'], 
    2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
    3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
    4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
    5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
    ] 
# Display Original List 
    print("---Original Nested List---") 
    print("")
    print(students) 
    print("") 
    
# Display List after Removing an Element from the Start of a List
    print("---New List after Removing Element from Start using pop() Function---")
    print("")


# Removing Element from the Start of a List using pop() Function 
    students.pop(2)
    print(students)
except Exception as ex: 
    print(ex)
# Out:
# ---Original Nested List---
#
# [['Registration No.', 'Name', 'Degree Program', 'Course'], 1, ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python'], 2, ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]
#
# ---New List after Removing Element from Start using pop() Function---
#
# [['Registration No.', 'Name', 'Degree Program', 'Course'], 1, 2, ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning'], 3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'], 4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'], 5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']]

# %% [markdown]
# ### **TODO Task 12**

# %% [markdown]
# ●  Consider the following Lists and answer the questions given below
#
#     o list_of_cars = ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
#     o prime_numbers = [2, 3, 5, 7, 11, 13, 17, 19]
#
# ●  Questions
#
#     o Implement  the  concept  of  Lambda Function  using  the  following methods dicussed in this Chapter
#         ▪   Method 1: Use filter() Function
#         ▪   Method 2: Use map() Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of program is to filter only the cars with 'M' letter from the List and prime numbers less than 10'''

try: 
# List Initiazation 
    list_of_cars = ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
    prime_numbers = [2, 3, 5, 7, 11, 13, 17, 19]
    print("---Origninal Lists before using filter() Function---")
    print("")
    print(list_of_cars)
    print("")
    print(prime_numbers)
    
# Lists after using filter() Function 
    print("")
    cars_with_m = list(filter(lambda car: 'M' in car, list_of_cars))
    print("---New Lists after using filter() Function---") 
    print('')
    print(cars_with_m)
    print('')
    
    updated_prime_numbers = list(filter(lambda number: number < 10, prime_numbers))
    print("---New List after using filter() Function---") 
    print('')
    print(updated_prime_numbers)
except: 
    print("Error Occurred")
# Out:
# ---Origninal Lists before using filter() Function---
#
# ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
#
# [2, 3, 5, 7, 11, 13, 17, 19]
#
# ---New Lists after using filter() Function---
#
# ['Mehran', 'Mercedes']
#
# ---New List after using filter() Function---
#
# [2, 3, 5, 7]

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of program is to add a specific number each item in a list using map() '''

try: 
# List Initiazation 
    list_of_cars = ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
    prime_numbers = [2, 3, 5, 7, 11, 13, 17, 19]
    print("---Origninal Lists before using map() Function---")
    print("")
    print(list_of_cars)
    print("")
    print(prime_numbers)
    
# Lists after using filter() Function 
    print("")
    cars_with_m = list(map(lambda car: car.upper(), list_of_cars))
    print("---New Lists after using map() Function---") 
    print('')
    print(cars_with_m)
    print('')
    
    updated_prime_numbers = list(map(lambda number: number + 10, prime_numbers))
    print("---New List after using map() Function---") 
    print('')
    print(updated_prime_numbers)
except: 
    print("Error Occurred")
# Out:
# ---Origninal Lists before using map() Function---
#
# ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
#
# [2, 3, 5, 7, 11, 13, 17, 19]
#
# ---New Lists after using map() Function---
#
# ['MEHRAN', 'MERCEDES', 'CULTUS', 'WAGONR']
#
# ---New List after using map() Function---
#
# [12, 13, 15, 17, 21, 23, 27, 29]

# %% [markdown]
# ### **TODO Task 13**

# %% [markdown]
# ●  Consider the following Lists
#
#     o list_of_cars = ['Mehran', 'Mercedes', 'Cultus', 'WagonR']
#     o student_information = [
#
#     [‘Registration No.’, ‘Name’, ‘Degree Program’, ‘Course’]
#     1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'],
#     2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
#     3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
#     4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
#     5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
# ]
#
# ●  Questions
#
#     o Pass the above List / Nested List to the Function, Iterate through the Nested List and Display all the elements on the Output Screen (as shown in this Chapter)?

# %%
''' Purpose of Program 
The main purpose of the program is to pass lists to a function and display the result on the Output Screen '''
def list_function(list): 
    for element in list:
        print(element) 
        
if __name__ == "__main__": # main() Function 
    try: # Initializing a List 
        list_of_cars = ['Mehran', 'Mercedes', 'Cultus', 'WagonR'] # Function Call 
        print("---Available Cars are---")
        print("")
        list_function(list_of_cars) 
        print("")
        # Initializing a Nested List 
        student_information = [

    ['Registration No.', 'Name', 'Degree Program', 'Course'],
    1, ['FA15-BSE-101', 'Ms. Samavi','BSE', 'Introduction to Python'], 
    2, ['FA15-BSE-103', 'Ms. Ayesha','BSE', '23','Machine Learning'],
    3, ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning'],
    4, ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP'],
    5, ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']
]
        print("---Studends Enrolled---")
        list_function(student_information) 
    
    except ValueError: 
        print("Error! Enter Valid Values")
# Out:
# ---Available Cars are---
#
# Mehran
# Mercedes
# Cultus
# WagonR
#
# ---Studends Enrolled---
# ['Registration No.', 'Name', 'Degree Program', 'Course']
# 1
# ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python']
# 2
# ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning']
# 3
# ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning']
# 4
# ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP']
# 5
# ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']

# %% [markdown]
# ## **Lecture 19**

# %% [markdown]
# ### **TODO Task 1**

# %% [markdown]
# ●  Declare and Initialize a Dictionary called phone_dir using the {} and dict() Function?
#
# ●  Note
#
#     o The key-value pair of a Dictionary are as follows
#         ▪    phone_directory     =     {'0348-6642185': 'Adeeb',
#                                         '0321-4971961':'Saaliha',
#                                         '0321-5865463': 'Kamaal',
#                                         '0321-4582322': 'Naaila',
#                                         '0345-8071517': 'Zuhra',
#                                         '0323-7654151':'Wajeeha'}
#
#         ▪    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                         'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                         'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}

# %%
''' Purpose of Program 
The main purpose of the program is to initialize a complete dictionary and display its content (data values) on the Output Screen '''
try:
# Dictionary Initialization - Method 1: Use {} 
    print("---Dictionary Initialization - Use {}---")
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Display Data Values of a Dictionary
    print ("")
    print("Data Values of phone_directory:", phone_directory)
    
# Display Length of a Dictionary using len() Function
    print ("")
    print("Length of phone_directory:", len(phone_directory))
    
# Display Type of a Dictionary using type() Function
    print ("")
    print("Data-Type of phone_directory:", type(phone_directory)) 


# Dictionary Initialization - Method 2: Use dict() Function 
    print ("")
    print("---Dictionary Initialization – Use dict() Function---")
    print ("")
    courses = dict({ 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']})
    
# Display Data Values of a Dictionary
    print ("")
    print("Data Values of courses:", courses)

# Display Length of a Dictionary using len() Function
    print ("")
    print("Length of tomb_of_sahaba_2:",len(courses))

# Display Type of a Dictionary using type() Function 
    print ("")
    print("Data-Type of tomb_of_sahaba_2:",type(courses))


except: 
    print("Error Occurred")
# Out:
# ---Dictionary Initialization - Use {}---
#
#
# Data Values of phone_directory: {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# Length of phone_directory: 6
#
# Data-Type of phone_directory: <class 'dict'>
#
# ---Dictionary Initialization – Use dict() Function---
#
#
# Data Values of courses: {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# Length of tomb_of_sahaba_2: 3
#
# Data-Type of tomb_of_sahaba_2: <class 'dict'>

# %% [markdown]
# ### **TODO Task 2**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb'
#                          , '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
# ●  Questions
#
#     o Access Elements of the phone_dir and courses Dictionaries using
#
#         ▪   Access value of an Individual Dictionary Item
#             ●  Method 1 - Access Element(s) of a Dictionary using key Name inside []
#             ●  Method 2 - Access Element(s) of a Dictionary using get() built-in Functions
#
#         ▪   Access List of keys in a Dictionary using key() built-in Function
#             ●  Method 3 - Access List of keys in a Dictionary using key() built-in Function
#
#         ▪   Access List of values in a Dictionary
#             ●  Method 4 - Access List of values in a Dictionary using values() built-in Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to access element(s) of a dictionary using key name '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Access Element(s) of a Dictionary using Keys 
    print("---Access Element(s) of a Dictionary using Keys---") 
    print("phone_directory['0348-6642185']:",phone_directory['0348-6642185']) 
    print("phone_directory['0321-4971961']:",phone_directory['0321-4971961']) 
    print("phone_directory['0321-5865463']:",phone_directory['0321-5865463']) 
    print("phone_directory['0321-4582322']:",phone_directory['0321-4582322']) 
    print("phone_directory['0345-8071517']:",phone_directory['0345-8071517']) 
    print("phone_directory['0323-7654151']:",phone_directory['0323-7654151']) 


# Dictionary Initialization
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Access Element(s) of a Dictionary using Keys 
    print("---Access Element(s) of a Dictionary using Keys---") 
    print("courses['Python']:",courses['Python']) 
    print("courses['Human Engineering']:",courses['Human Engineering']) 
    print("courses['Spiritual Training Courses']:",courses['Spiritual Training Courses']) 

except: 
    print("Error Occurred")
# Out:
# ---Access Element(s) of a Dictionary using Keys---
# phone_directory['0348-6642185']: Adeeb
# phone_directory['0321-4971961']: Saaliha
# phone_directory['0321-5865463']: Kamaal
# phone_directory['0321-4582322']: Naaila
# phone_directory['0345-8071517']: Zuhra
# phone_directory['0323-7654151']: Wajeeha
#
# ---Access Element(s) of a Dictionary using Keys---
# courses['Python']: ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# courses['Human Engineering']: ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# courses['Spiritual Training Courses']: ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to access element(s) of a dictionary using get() Function '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Access Element(s) of a Dictionary using get() Function 
    print("---Access Element(s) of a Dictionary using get() Function---") 
    print(phone_directory.get('0348-6642185')) 
    print(phone_directory.get('0321-4971961')) 
    print(phone_directory.get('0321-5865463')) 
    print(phone_directory.get('0321-4582322')) 
    print(phone_directory.get('0345-8071517')) 
    print(phone_directory.get('0323-7654151'))

# Dictionary Initialization
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Access Element(s) of a Dictionary using get() Function 
    print("---Access Element(s) of a Dictionary using get() Function---") 
    print(courses.get('Python')) 
    print(courses.get('Human Engineering')) 
    print(courses.get('Spiritual Training Courses')) 

except: 
    print("Error Occurred")
# Out:
# ---Access Element(s) of a Dictionary using get() Function---
# Adeeb
# Saaliha
# Kamaal
# Naaila
# Zuhra
# Wajeeha
#
# ---Access Element(s) of a Dictionary using get() Function---
# ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to access list of keys in a dictionary using key() function '''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(phone_directory.keys())

# Dictionary Initialization
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(courses.keys())

except: 
    print("Error Occurred")
# Out:
# ---Access Element(s) of a Dictionary using key() Function---
# dict_keys(['0348-6642185', '0321-4971961', '0321-5865463', '0321-4582322', '0345-8071517', '0323-7654151'])
#
# ---Access Element(s) of a Dictionary using key() Function---
# dict_keys(['Python', 'Human Engineering', 'Spiritual Training Courses'])

# %% [markdown]
# #### **Method 4**

# %%
''' Purpose of Program 
The main purpose of the program is to access element(s) of a dictionary using values() function'''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(phone_directory.values())

# Dictionary Initialization
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(courses.values())

except: 
    print("Error Occurred")
# Out:
# ---Access Element(s) of a Dictionary using key() Function---
# dict_values(['Adeeb', 'Saaliha', 'Kamaal', 'Naaila', 'Zuhra', 'Wajeeha'])
#
# ---Access Element(s) of a Dictionary using key() Function---
# dict_values([['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']])

# %% [markdown]
# ### **TODO Task 3**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
# ●  Questions
#
#     o Insert Elements to prophets and ages Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1 - Add a New Element at the Start of a Dictionary
#         ▪   Method 2 - Add a New Element at the End of a Dictionary
#         ▪   Method 3 - Add a New Element at a Desired Location of a Dictionary

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to add a new element at the start of a Dictionary on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Adding Element at Start of a Dictionary---") 
    print("")
    print(phone_directory)
    
# Data Type of i.e., phone_directory before converting to List
    print("")
    print("---Data Type of i.e., phone_directory before converting to List---") 
    print("")
    print(type(phone_directory)) 
    
# Converting a Dictionary into a List and store list in "list_phone_directory" 
    print("")
    list_phone_directory = list(phone_directory.items()) 
    
# Data Type of i.e., phone_directory after converting to List 
    print("")
    print("---Data Type of i.e., phone_directory after converting to List---") 
    print("")
    print(type(list_phone_directory))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_phone_directory.insert(0, ('0321-1234567','Ahmed')) 

# Display Updated Dictionary after Adding Element at Start of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Start of a Dictionary---") 
    print("")
    print(list_phone_directory) 

    
# Dictionary Initialization
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
    print("---Original Dictionary before Adding Element at Start of a Dictionary---") 
    print("")
    print(courses)
    
# Data Type of i.e., courses before converting to List
    print("")
    print("---Data Type of i.e., courses before converting to List---") 
    print("")
    print(type(courses)) 
    
# Converting a Dictionary into a List and store list in "list_courses" 
    print("")
    list_courses = list(courses.items()) 
    
# Data Type of i.e., courses after converting to List 
    print("")
    print("---Data Type of i.e., courses after converting to List---") 
    print("")
    print(type(list_courses))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_courses.insert(0, ('Data Science','Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira')) 

# Display Updated Dictionary after Adding Element at Start of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Start of a Dictionary---") 
    print("")
    print(list_courses)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Adding Element at Start of a Dictionary---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---Data Type of i.e., phone_directory before converting to List---
#
# <class 'dict'>
#
#
# ---Data Type of i.e., phone_directory after converting to List---
#
# <class 'list'>
#
#
# ---Updated Dictionary after Adding Element at Start of a Dictionary---
#
# [('0321-1234567', 'Ahmed'), ('0348-6642185', 'Adeeb'), ('0321-4971961', 'Saaliha'), ('0321-5865463', 'Kamaal'), ('0321-4582322', 'Naaila'), ('0345-8071517', 'Zuhra'), ('0323-7654151', 'Wajeeha')]
#
# ---Original Dictionary before Adding Element at Start of a Dictionary---
#
# ...

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to add a new element at the end of a dictionary '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Adding Element at End of a Dictionary---") 
    print("")
    print(phone_directory)
    
# Data Type of i.e., phone_directory before converting to List
    print("")
    print("---Data Type of i.e., phone_directory before converting to List---") 
    print("")
    print(type(phone_directory)) 
    
# Converting a Dictionary into a List and store list in "list_phone_directory" 
    print("")
    list_phone_directory = list(phone_directory.items()) 
    
# Data Type of i.e., phone_directory after converting to List 
    print("")
    print("---Data Type of i.e., phone_directory after converting to List---") 
    print("")
    print(type(list_phone_directory))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_phone_directory.append(('0321-1234567','Ahmed')) 

# Display Updated Dictionary after Adding Element at End of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at End of a Dictionary---") 
    print("")
    print(list_phone_directory) 

    
# Dictionary Initialization
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
    print("---Original Dictionary before Adding Element at End of a Dictionary---") 
    print("")
    print(courses)
    
# Data Type of i.e., courses before converting to List
    print("")
    print("---Data Type of i.e., courses before converting to List---") 
    print("")
    print(type(courses)) 
    
# Converting a Dictionary into a List and store list in "list_courses" 
    print("")
    list_courses = list(courses.items()) 
    
# Data Type of i.e., courses after converting to List 
    print("")
    print("---Data Type of i.e., courses after converting to List---") 
    print("")
    print(type(list_courses))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_courses.append(('Data Science',['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']))

# Display Updated Dictionary after Adding Element at End of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at End of a Dictionary---") 
    print("")
    print(list_courses)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Adding Element at Start of a Dictionary---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---Data Type of i.e., phone_directory before converting to List---
#
# <class 'dict'>
#
#
# ---Data Type of i.e., phone_directory after converting to List---
#
# <class 'list'>
#
#
# ---Updated Dictionary after Adding Element at Start of a Dictionary---
#
# [('0348-6642185', 'Adeeb'), ('0321-4971961', 'Saaliha'), ('0321-5865463', 'Kamaal'), ('0321-4582322', 'Naaila'), ('0345-8071517', 'Zuhra'), ('0323-7654151', 'Wajeeha'), ('0321-1234567', 'Ahmed')]
#
# ---Original Dictionary before Adding Element at Start of a Dictionary---
#
# ...

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to add a new element at a desired location of a Dictionary on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(phone_directory)
    
# Data Type of i.e., phone_directory before converting to List
    print("")
    print("---Data Type of i.e., phone_directory before converting to List---") 
    print("")
    print(type(phone_directory)) 
    
# Converting a Dictionary into a List and store list in "list_phone_directory" 
    print("")
    list_phone_directory = list(phone_directory.items()) 
    
# Data Type of i.e., phone_directory after converting to List 
    print("")
    print("---Data Type of i.e., phone_directory after converting to List---") 
    print("")
    print(type(list_phone_directory))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_phone_directory.insert(3,('0321-1234567','Ahmed')) 

# Display Updated Dictionary after Adding Element at Desired Location of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(list_phone_directory) 

    
# Dictionary Initialization
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
    print("---Original Dictionary before Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(courses)
    
# Data Type of i.e., courses before converting to List
    print("")
    print("---Data Type of i.e., courses before converting to List---") 
    print("")
    print(type(courses)) 
    
# Converting a Dictionary into a List and store list in "list_courses" 
    print("")
    list_courses = list(courses.items()) 
    
# Data Type of i.e., courses after converting to List 
    print("")
    print("---Data Type of i.e., courses after converting to List---") 
    print("")
    print(type(list_courses))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_courses.insert(2,('Data Science',['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']))

# Display Updated Dictionary after Adding Element at Desired Location of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(list_courses)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Adding Element at Desired Location of a Dictionary---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---Data Type of i.e., phone_directory before converting to List---
#
# <class 'dict'>
#
#
# ---Data Type of i.e., phone_directory after converting to List---
#
# <class 'list'>
#
#
# ---Updated Dictionary after Adding Element at Desired Location of a Dictionary---
#
# [('0348-6642185', 'Adeeb'), ('0321-4971961', 'Saaliha'), ('0321-5865463', 'Kamaal'), ('0321-1234567', 'Ahmed'), ('0321-4582322', 'Naaila'), ('0345-8071517', 'Zuhra'), ('0323-7654151', 'Wajeeha')]
#
# ---Original Dictionary before Adding Element at Desired Location of a Dictionary---
#
# ...

# %% [markdown]
# ### **TODO Task 4**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
# ●  Questions
#
#     o Traverse selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Traversing an Entire Dictionary
#         ▪   Method 2: Traversing a Dictionary (Element by Element)

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to traverse through an entire dictionary and display the result on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Traverse through all key, value pairs 
    print("---Traverse through all key, value pairs---") 
    print ("")
    for elements in phone_directory.items(): 
        print(elements)
        
# Dictionary Initialization 
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Traverse through all key, value pairs 
    print("---Traverse through all key, value pairs---") 
    print ("")
    for elements in courses.items(): 
        print(elements)        
except: 
    print("Error Occurred")
# Out:
# ---Traverse through all key, value pairs---
#
# ('0348-6642185', 'Adeeb')
# ('0321-4971961', 'Saaliha')
# ('0321-5865463', 'Kamaal')
# ('0321-4582322', 'Naaila')
# ('0345-8071517', 'Zuhra')
# ('0323-7654151', 'Wajeeha')
#
# ---Traverse through all key, value pairs---
#
# ('Python', ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'])
# ('Human Engineering', ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'])
# ('Spiritual Training Courses', ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira'])

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to traverse through a dictionary and display the result on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Traverse through all key, value pairs 
    print("---Traverse through all keys of First Dictionary---") 
    print ("")
    for elements in phone_directory.keys(): 
        print(elements)
    print ("")
    print("---Traverse through all values of First Dictionary---") 
    print ("")
    for elements in phone_directory.values(): 
        print(elements)    
# Dictionary Initialization 
    print ("")
    courses = { 'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Traverse through all key, value pairs 
    print("---Traverse through all keys of Second Dictionary---") 
    print ("")
    for elements in courses.keys(): 
        print(elements)
    print ("") 
    print("---Traverse through all values of Second Dictionary---") 
    print ("")
    for elements in courses.values(): 
        print(elements) 
except: 
    print("Error Occurred")
# Out:
# ---Traverse through all keys of First Dictionary---
#
# 0348-6642185
# 0321-4971961
# 0321-5865463
# 0321-4582322
# 0345-8071517
# 0323-7654151
#
# ---Traverse through all values of First Dictionary---
#
# Adeeb
# Saaliha
# Kamaal
# Naaila
# Zuhra
# Wajeeha
#
# ---Traverse through all keys of Second Dictionary---
#
# Python
# Human Engineering
# Spiritual Training Courses
#
# ---Traverse through all values of Second Dictionary---
#
# ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']

# %% [markdown]
# ### **TODO Task 5**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
# ●  Questions
#
#     o Search from selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Search Element(s) from a Dictionary using key
#         ▪   Method 2: Search Element(s) from a Dictionary using value

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to search element(s) using key '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Search Value using Key from a Dictionary 
    print ("Value against '0348-6642185' : "+ phone_directory.get('0348-6642185'))
        
# Dictionary Initialization 
    print ("")
    courses =  {'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Search Value using Key from a Dictionary 
    print ("Value against 'Python' : " , courses.get('Python'))
except: 
    print("Error Occurred")
# Out:
# Value against '0348-6642185' : Adeeb
#
# Value against 'Python' :  ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to search element(s) using value '''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    

    print("---Using Keys(), Values() and index()---")
    print("")

# Store all Keys from the Dictionary in the Variable i.e., key_list 
    key_list = list(phone_directory.keys())
    print("Keys in the Dictionary:", key_list)
    print("")

# Store all Values from the Dictionary in the Variable i.e., val_list 
    val_list = list(phone_directory.values())
    print("Values in the Dictionary:", val_list)
    print("")

    print("---------------------------------------------------------")
    print("")
# Store Index of Value 'Kamaal' in a Variable i.e., position 
    position_Kamaal = val_list.index('Kamaal')
# Display the Key with Value 'Kamaal'
    print("Key against Value 'Kamaal':",key_list[position_Kamaal])
    print("")

# Dictionary Initialization 
    print ("")
    courses =  {'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
    print("---Using Keys(), Values() and index()---")
    print("")

# Store all Keys from the Dictionary in the Variable i.e., key_list 
    key_list = list(courses.keys())
    print("Keys in the Dictionary:", key_list)
    print("")

# Store all Values from the Dictionary in the Variable i.e., val_list 
    val_list = list(courses.values())
    print("Values in the Dictionary:", val_list)
    print("")

    print("---------------------------------------------------------")
    print("")
# Store Index of Value ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'] in a Variable i.e., position 
    position = val_list.index(['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'])
# Display the Key with Value ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan']
    print("Key against Value ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan']:",key_list[position])
    print("")
except: 
    print("Error Occurred")
# Out:
# ---Using Keys(), Values() and index()---
#
# Keys in the Dictionary: ['0348-6642185', '0321-4971961', '0321-5865463', '0321-4582322', '0345-8071517', '0323-7654151']
#
# Values in the Dictionary: ['Adeeb', 'Saaliha', 'Kamaal', 'Naaila', 'Zuhra', 'Wajeeha']
#
# ---------------------------------------------------------
#
# Key against Value 'Kamaal': 0321-5865463
#
#
# ---Using Keys(), Values() and index()---
#
# Keys in the Dictionary: ['Python', 'Human Engineering', 'Spiritual Training Courses']
#
# Values in the Dictionary: [['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']]
#
# ---------------------------------------------------------
#
# Key against Value ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan']: Python

# %% [markdown]
# ### **TODO Task 6**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
#
# ●  Questions
#
#     o Sort the selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Sorting a Dictionary by key-value pair
#         ▪   Method 2: Sorting a Dictionary by key
#             ●  Method 2.1: Sorting a Dictionary by key in Ascending Order
#             ●  Method 2.2: Sorting a Dictionary by key in Descending Order
#         ▪   Method 3: Sorting a Dictionary by value
#             ●  Method 3.1: Sorting a Dictionary by value in Ascending Order
#             ●  Method 3.2: Sorting a Dictionary by value in Descending Order

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to sort a dictionary by key-value pair '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(phone_directory)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_phone_directory" 
    dict_phone_directory = phone_directory.items()
    
# Sort Dictionary based on keys using sorted() Function
    sorted_dictionary_1 = sorted(dict_phone_directory) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_1)

        
# Dictionary Initialization 
    print ("")
    courses =  {'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(courses)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_courses" 
    dict_courses = courses.items()
    
# Sort Dictionary based on keys using sorted() Function
    sorted_dictionary_2 = sorted(dict_courses) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_2)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Sorting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Sorting---
#
# [('0321-4582322', 'Naaila'), ('0321-4971961', 'Saaliha'), ('0321-5865463', 'Kamaal'), ('0323-7654151', 'Wajeeha'), ('0345-8071517', 'Zuhra'), ('0348-6642185', 'Adeeb')]
#
# ---Original Dictionary before Sorting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Sorting---
#
# ...

# %% [markdown]
# #### **Method 2.1**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by key in ascending order '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(phone_directory)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_phone_directory" 
    dict_phone_directory = phone_directory.items()
    
# Sort Dictionary in ascending order using sorted() Function
    sorted_dictionary_1 = sorted(dict_phone_directory,reverse = False) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_1)

        
# Dictionary Initialization 
    print ("")
    courses =  {'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(courses)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_courses" 
    dict_courses = courses.items()
    
# Sort Dictionary in ascending order using sorted() Function
    sorted_dictionary_2 = sorted(dict_courses,reverse = False) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_2)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Sorting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Sorting---
#
# [('0321-4582322', 'Naaila'), ('0321-4971961', 'Saaliha'), ('0321-5865463', 'Kamaal'), ('0323-7654151', 'Wajeeha'), ('0345-8071517', 'Zuhra'), ('0348-6642185', 'Adeeb')]
#
# ---Original Dictionary before Sorting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Sorting---
#
# ...

# %% [markdown]
# #### **Method 2.2**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by key in descending order '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(phone_directory)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_phone_directory" 
    dict_phone_directory = phone_directory.items()
    
# Sort Dictionary in descending order using sorted() Function
    sorted_dictionary_1 = sorted(dict_phone_directory,reverse = True) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_1)

        
# Dictionary Initialization 
    print ("")
    courses =  {'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(courses)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_courses" 
    dict_courses = courses.items()
    
# Sort Dictionary in descending order using sorted() Function
    sorted_dictionary_2 = sorted(dict_courses,reverse = True) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_2)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Sorting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Sorting---
#
# [('0348-6642185', 'Adeeb'), ('0345-8071517', 'Zuhra'), ('0323-7654151', 'Wajeeha'), ('0321-5865463', 'Kamaal'), ('0321-4971961', 'Saaliha'), ('0321-4582322', 'Naaila')]
#
# ---Original Dictionary before Sorting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Sorting---
#
# ...

# %% [markdown]
# #### **Method 3.1**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by value in descending order '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(phone_directory)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(phone_directory, key = phone_directory.get, reverse = False):
        print(elements, phone_directory[elements])
     
# Dictionary Initialization 
    print ("")
    courses =  {'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(courses)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(courses, key = courses.get, reverse = False):
        print(elements, courses[elements])

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 3.2**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by value in descending order '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(phone_directory)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(phone_directory, key = phone_directory.get, reverse = True):
        print(elements, phone_directory[elements])
     
# Dictionary Initialization 
    print ("")
    courses =  {'Python':['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'], 
                'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor','Maira']}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(courses)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(courses, key = courses.get, reverse = True):
        print(elements, courses[elements])

except: 
    print("Error Occurred")
# Out:
# ---Sort Dictionary using 'get'---
#
# ---Original Dictionary before Sorting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Sorting---
#
# 0345-8071517 Zuhra
# 0323-7654151 Wajeeha
# 0321-4971961 Saaliha
# 0321-4582322 Naaila
# 0321-5865463 Kamaal
# 0348-6642185 Adeeb
#
# ---Sort Dictionary using 'get'---
#
# ---Original Dictionary before Sorting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Sorting---
#
# Python ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# Human Engineering ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']
# ...

# %% [markdown]
# ### **TODO Task 7**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
#
# ●  Questions
#
#     o Merge the selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Concatenate Dictionaries using update() Function
#         ▪   Method 2: Concatenate Dictionaries using ** Operators

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to concatenate dictionaries using update() function '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
    
    print("---Original Dictionary before Merge---")
    print ("\nDictionary 1\n")
    print(phone_directory)
    print ("\nDictionary 2\n")
    print(courses)
    print ("")

# Use update() Function to merge two Dictionaries
    phone_directory.update(courses) 
    print("---New Dictionary after Merge---") 
    print ("")
    print(phone_directory)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Merge---
#
# Dictionary 1
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# Dictionary 2
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Merge---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha', 'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to concatenate dictionaries using ** operator '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
    
    print("---Original Dictionary before Merge---")
    print ("\nDictionary 1\n")
    print(phone_directory)
    print ("\nDictionary 2\n")
    print(courses)
    print ("")

# Use ** operator to merge two Dictionaries
    dict3_phone_directory = dict(phone_directory,** courses) 
    print("---New Dictionary after Merge---") 
    print ("")
    print(dict3_phone_directory)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Merge---
#
# Dictionary 1
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# Dictionary 2
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Merge---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha', 'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}

# %% [markdown]
# ### **TODO Task 8**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
# ●  Questions
#
#     o Update the selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Update the key of a Dictionary using pop() Function
#         ▪   Method 2: Update the value of a Dictionary
#         ▪   Method 3: Update the value of a Dictionary using update() Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to update the key of a dictionary using pop() function '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Updatation---")
    print ("")
    print(phone_directory)
    print ("")
    
# Use pop() Function to update old_key_value with new_key_value 
    new_key = "0321-1234567" 
    old_key = "0321-5865463" 
    phone_directory[new_key] = phone_directory.pop(old_key)
    print("---New Dictionary after Updatation---") 
    print(phone_directory)

    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
    print("---Original Dictionary before Updatation---")
    print ("")
    print(courses)
    print ("")
    
# Use pop() Function to update old_key_value with new_key_value 
    new_key = "Data Science" 
    old_key = "Spiritual Training Courses" 
    courses[new_key] = courses.pop(old_key)
    print("---New Dictionary after Updatation---") 
    print(courses)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Updatation---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Updatation---
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha', '0321-1234567': 'Kamaal'}
# ---Original Dictionary before Updatation---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Updatation---
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Data Science': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to update the value of a dictionary '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Updatation---")
    print ("")
    print(phone_directory)
    print ("")
    
# Use key for updating value in a Dictionary 
    phone_directory["0321-5865463"] = "Ahmed"
    print("---New Dictionary after Updatation---") 
    print ("")
    print(phone_directory)
    print ("")
    
    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
    print("---Original Dictionary before Updatation---")
    print ("")
    print(courses)
    print ("")
    
# Use key for updating value in a Dictionary 
    courses["Spiritual Training Courses"] = "['Rehan','Awais','Ahmed','Ali','Hira','Noor','Umar', 'Usman']"
    print("---New Dictionary after Updatation---") 
    print ("")
    print(courses)
    print ("")

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Updatation---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Updatation---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Ahmed', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---Original Dictionary before Updatation---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Updatation---
#
# ...

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program
The main purpose of the program is to update the value of a dictionary using update() function '''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Updatation---")
    print ("")
    print(phone_directory)
    print ("")
    
# Use update() Function for updating value of a Dictionay
    phone_directory.update({'0321-5865463': 'Ahmed'})
    print("---New Dictionary after Updatation---") 
    print ("")
    print(phone_directory)
    print ("")
    
    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
    print("---Original Dictionary before Updatation---")
    print ("")
    print(courses)
    print ("")
    
# Use update() Function for updating value of a Dictionay
    courses.update({'Human Engineering': ['Rehan','Awais','Ahmed','Ali','Hira','Noor','Umar', 'Usman']})
    print("---New Dictionary after Updatation---") 
    print ("")
    print(courses)
    print ("")

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Updatation---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Updatation---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Ahmed', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---Original Dictionary before Updatation---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Updatation---
#
# ...

# %% [markdown]
# ### **TODO Task 9**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
#     o courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
#                  'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}
#
# ●  Questions
#
#     o Remove  from  selected  Dictionaries  using  following  methods  (as shown in this Chapter)
#         ▪   Method 1: Delete Entire / Element(s) from a Dictionary using del
#         ▪   Method 2: Remove Element(s) of a Dictionary using clear() Function
#         ▪   Method 3: Remove Specific Element(s) from a Dictionary using pop() Function
#         ▪   Method 4: Remove Last Element(s) from a Dictionary using popitem() Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to Delete Entire / Element(s) from a Dictionary using del '''
try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
# Approach I - Delete Specific Element from Dictionary 
    print("---Approach I - Delete Specific Element from Dictionary---") 
    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(phone_directory) 

# Use del to delete specific key-value pair from a Dictionary 
    del phone_directory['0345-8071517'] 
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(phone_directory)

    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}

# Approach II - Delete Entire Dictionary 
    print ("")
    print("---Approach II - Delete Entire Dictionary---") 
    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(courses) 

# Use del to delete specific key-value pair from a Dictionary
    del courses 
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(courses)

except Exception as ex:
    print(ex)
# Out:
# ---Approach I - Delete Specific Element from Dictionary---
#
# ---Original Dictionary before Deleting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Deleting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0323-7654151': 'Wajeeha'}
#
# ---Approach II - Delete Entire Dictionary---
#
# ---Original Dictionary before Deleting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Deleting---
#
# name 'courses' is not defined

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to remove elements of a dictionary using clear() function '''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Deleting---")
    print ("")
    print(phone_directory) 

# Use clear() Function to delete all elements of a Dictionary
    phone_directory.clear()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(phone_directory)

    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}

    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(courses) 

# Use clear() Function to delete all elements of a Dictionary
    courses.clear()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(courses)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Deleting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Deleting---
#
# {}
#
# ---Original Dictionary before Deleting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Deleting---
#
# {}

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to remove specific element(s) of a dictionary using pop() function '''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Deleting---")
    print ("")
    print(phone_directory) 

# Use pop() Function to remove specific element(s) of a Dictionary
    phone_directory.pop('0321-4582322')
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(phone_directory)

    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}

    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(courses) 

# Use pop() Function to remove specific element(s) of a Dictionary
    courses.pop('Human Engineering')
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(courses)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Deleting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Deleting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---Original Dictionary before Deleting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Deleting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}

# %% [markdown]
# #### **Method 4**

# %%
''' Purpose of Program 
The main purpose of the program is to remove last element(s) of a dictionary using popitem() function '''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}
    
    print("---Original Dictionary before Deleting---")
    print ("")
    print(phone_directory) 

# Use popitem() Function to remove last element(s) of a Dictionary
    phone_directory.popitem()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(phone_directory)

    courses = {'Python': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Human Engineering': ['Samavi','Narmeen','Awais','Rehan','Hassan','Hassan'],
                 'Spiritual Training Courses': ['Rehan','Awais','Ali','Ahmed','Sara','Zara','Mahnoor', 'Maira']}

    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(courses) 

# Use pop() Function to remove specific element(s) of a Dictionary
    courses.popitem()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(courses)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Deleting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary after Deleting---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra'}
#
# ---Original Dictionary before Deleting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Spiritual Training Courses': ['Rehan', 'Awais', 'Ali', 'Ahmed', 'Sara', 'Zara', 'Mahnoor', 'Maira']}
#
# ---New Dictionary after Deleting---
#
# {'Python': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan'], 'Human Engineering': ['Samavi', 'Narmeen', 'Awais', 'Rehan', 'Hassan', 'Hassan']}

# %% [markdown]
# ### **TODO Task 10**

# %% [markdown]
# ●  Consider the following two Dictionaries and answer the questions given below
#
#     o phone_directory = {'0348-6642185': 'Adeeb',
#                          '0321-4971961':'Saaliha',
#                          '0321-5865463': 'Kamaal',
#                          '0321-4582322': 'Naaila',
#                          '0345-8071517': 'Zuhra',
#                          '0323-7654151':'Wajeeha'}
#
# ●  Questions
#
#     o Use  phone_directory  to  create  a  new  dictionary  which  contains numbers starting with 0321?

# %%
''' Purpose of Program 
The main purpose of the program is to create a new dictionary based on key-value pairs of an existing dictionary '''

try:
# Dictionary Initialization 
    print ("")
    phone_directory = {'0348-6642185': 'Adeeb', 
                        '0321-4971961':'Saaliha',
                        '0321-5865463': 'Kamaal', 
                        '0321-4582322': 'Naaila', 
                        '0345-8071517': 'Zuhra', 
                        '0323-7654151':'Wajeeha'}

    print("---Original Dictionary before Comprehension---")
    print ("")
    print(phone_directory) 

# Create a new dictionary with element of previous dictionary
    print ("")
    print("---New Dictionary After Comprehension---")
    print ("")
    new_phone_directory = {number: name for number, name in phone_directory.items() if number.startswith('0321')} 
    print(new_phone_directory)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Comprehension---
#
# {'0348-6642185': 'Adeeb', '0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila', '0345-8071517': 'Zuhra', '0323-7654151': 'Wajeeha'}
#
# ---New Dictionary After Comprehension---
#
# {'0321-4971961': 'Saaliha', '0321-5865463': 'Kamaal', '0321-4582322': 'Naaila'}

# %% [markdown]
# ### **TODO Task 11**

# %% [markdown]
# ●  Consider the following Nested Dictionary and answer the questions given below
#
#     student_courses = { 'FA15-BCS-01':
#                    {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
#                    'FA15-BCS-03':
#                    {'Program':'BS(CE)','Degree':'Bachelors in Computer Science'},
#                    'FA15-BCS-05':
#                    {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}}
#
# ●  Questions
#
#     o Apply following operations on the given Nested Dictionary (as shown in this Chapter)?
#         ▪   Operation 1: Create a Nested Dictionary
#         ▪   Operation 2: Access Elements of a Nested Dictionary
#         ▪   Operation 3: Add New Element in a Nested Dictionary
#         ▪   Operation 4: Traverse a Nested Dictionary
#         ▪   Operation 5: Remove Elements of a Nested Dictionary

# %% [markdown]
# #### **Operation 1**

# %%
''' Purpose of Program 
The main purpose of the program is to create a nested dictionary '''
# Initializing a Nested Dictionary i.e., student_courses

try:
    student_courses = { 'FA15-BCS-01': 
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-03':
                   {'Program':'BS(CE)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-05':
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}}

    print("Dictionary of Students for Courses:\n\n", student_courses)
    print("")

# Data-Type of Dictionary i.e., student_courses
    print("Data-Type of students:", type(student_courses))
    print("")
    
# Length of Dictionary i.e., student_courses 
    print("Length of students:", len(student_courses))
    print("")
    
except:
    print("Error Occurred")
# Out:
# Dictionary of Students for Courses:
#
#  {'FA15-BCS-01': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-03': {'Program': 'BS(CE)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-05': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}}
#
# Data-Type of students: <class 'dict'>
#
# Length of students: 3

# %% [markdown]
# #### **Operation 2**

# %%
''' Purpose of Program 
The main purpose of the program is to access elements of a nested dictionary '''
# Initializing a Nested Dictionary i.e., student_courses

try:
    student_courses = { 'FA15-BCS-01': 
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-03':
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-05':
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}}

# Access Elements of Nested Dictionary using Indexing 
    print("Element at index student_courses[FA15-BCS-01] with Key 'Program':", student_courses['FA15-BCS-01']['Program'])
    print("")
    print("Element at index student_courses[FA15-BCS-01] with Key 'Degree':", student_courses['FA15-BCS-01']['Degree']) 
    print("")
   
except:
    print("Error Occurred")
# Out:
# Element at index student_courses[FA15-BCS-01] with Key 'Program': BS(CS)
#
# Element at index student_courses[FA15-BCS-01] with Key 'Degree': Bachelors in Computer Science

# %% [markdown]
# #### **Operation 3**

# %%
''' Purpose of Program 
The main purpose of the program is to add elements in a nested dictionary ''' 
# Initializing a Nested Dictionary i.e., student_courses

try:
    student_courses = { 'FA15-BCS-01': 
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-03':
                   {'Program':'BS(CE)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-05':
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}}

# Display Original Dictionary
    print("---Original Nested Dictionary---")
    print("")
    print(student_courses)
    print("")

# Display Dictionary after Adding a New Dictionary inside a Nested Dictionary
    print("---New Dictionary adding a Dictionary---")
    print("")
    
# Create a Key-Value Pair i.e., another Dictionary inside a Dictionary
    student_courses['FA15-BCS-07'] = {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}
    print(student_courses)
    print("")
    
except:
    print("Error Occurred")
# Out:
# ---Original Nested Dictionary---
#
# {'FA15-BCS-01': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-03': {'Program': 'BS(CE)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-05': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}}
#
# ---New Dictionary adding a Dictionary---
#
# {'FA15-BCS-01': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-03': {'Program': 'BS(CE)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-05': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-07': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}}

# %% [markdown]
# #### **Operation 4**

# %%
''' Purpose of Program 
The main purpose of the program is to traversing a dictionary ''' 
# Initializing a Nested Dictionary i.e., student_courses

try:
    student_courses = { 'FA15-BCS-01': 
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-03':
                   {'Program':'BS(CE)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-05':
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}}

# Traverse a Dictionary 
    for student_roll_no, program_details in student_courses.items(): 
        print("\nStudent_ID:", student_roll_no) 
        for key in program_details: 
            print(key + ':', program_details[key])

except:
    print("Error Occurred")
# Out:
# Student_ID: FA15-BCS-01
# Program: BS(CS)
# Degree: Bachelors in Computer Science
#
# Student_ID: FA15-BCS-03
# Program: BS(CE)
# Degree: Bachelors in Computer Science
#
# Student_ID: FA15-BCS-05
# Program: BS(CS)
# Degree: Bachelors in Computer Science

# %% [markdown]
# #### **Operation 5**

# %%
''' Purpose of Program 
The main purpose of the program is to remove elements from a nested dictionary ''' 
# Initializing a Nested Dictionary i.e., student_courses

try:
    student_courses = { 'FA15-BCS-01': 
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-03':
                   {'Program':'BS(CE)','Degree':'Bachelors in Computer Science'},
                   'FA15-BCS-05':
                   {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}}

# Approach I – Remove a Key from a Nested Dictionary 
    print("---Approach I – Remove an Key from a Nested Dictionary---")
    print("")
    
# Display Original Dictionary 
    print("---Original Nested Dictionary---")
    print("")
    print(student_courses) 
    
# Remove Key at Index 2 
    del student_courses['FA15-BCS-05']['Degree'] 
    print("")
    print("---New Dictionary after Removing a Key from a Nested Dictionary---") 
    print("")
    print(student_courses)

# Approach II – Remove a Nested Dictionary
    print("")
    print("---Approach II – Remove a Nested Dictionary---")
    print("")
    
# Display Original Dictionary 
    print("---Original Nested Dictionary---")
    print("")
    print(student_courses) 
    
# Remove a Dictionary
    del student_courses
    print("")
    print("---New Dictionary after Removing a Nested Dictionary---") 
    print("")
    print(student_courses)
    
except Exception as ex:
    print(ex)
# Out:
# ---Approach I – Remove an Key from a Nested Dictionary---
#
# ---Original Nested Dictionary---
#
# {'FA15-BCS-01': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-03': {'Program': 'BS(CE)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-05': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}}
#
# ---New Dictionary after Removing a Key from a Nested Dictionary---
#
# {'FA15-BCS-01': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-03': {'Program': 'BS(CE)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-05': {'Program': 'BS(CS)'}}
#
# ---Approach II – Remove a Nested Dictionary---
#
# ---Original Nested Dictionary---
#
# {'FA15-BCS-01': {'Program': 'BS(CS)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-03': {'Program': 'BS(CE)', 'Degree': 'Bachelors in Computer Science'}, 'FA15-BCS-05': {'Program': 'BS(CS)'}}
#
# ---New Dictionary after Removing a Nested Dictionary---
#
# ...

# %% [markdown]
# ### **TODO Task 12**

# %% [markdown]
# ●  Consider the following Nested Dictionary and answer the questions given below
#
#     student_courses = { 'FA15-BCS-01':
#                    [{'Program':'BS(CS)'}, {'Degree':'Bachelors in Computer Science'}],
#                    'FA15-BCS-03':
#                    [{'Program':'BS(CE)'}, {'Degree':'Bachelors in Computer Science'}],
#                    'FA15-BCS-05': [{'Program':'BS(CS)'}, {'Degree':'Bachelors in Computer Science'}]}
#
# ●  Questions
#
#         o Create a Dictionary within a List (as shown in this Chapter)?

# %%
''' Purpose of Program 
The main purpose of the program is to create a dictionary within a list '''
# Initializing a Nested Dictionary i.e., student_courses

try:

    student_courses = {
    'Learn How to Achieve Excellence in Love and Obedience of Allah':
    [{ 'FA15-BCS-01': 
                   [{'Program':'BS(CS)'}, {'Degree':'Bachelors in Computer Science'}],
                   'FA15-BCS-03': 
                   [{'Program':'BS(CE)'}, {'Degree':'Bachelors in Computer Science'}],
                   'FA15-BCS-05': [{'Program':'BS(CS)'}, {'Degree':'Bachelors in Computer Science'}]}
],
}
    print("Creating a Nested Dictionary within a List:\n\n",student_courses)
except Exception as ex:
    print(ex)
# Out:
# Creating a Nested Dictionary within a List:
#
#  {'Learn How to Achieve Excellence in Love and Obedience of Allah': [{'FA15-BCS-01': [{'Program': 'BS(CS)'}, {'Degree': 'Bachelors in Computer Science'}], 'FA15-BCS-03': [{'Program': 'BS(CE)'}, {'Degree': 'Bachelors in Computer Science'}], 'FA15-BCS-05': [{'Program': 'BS(CS)'}, {'Degree': 'Bachelors in Computer Science'}]}]}

# %% [markdown]
# ### **TODO Task 13**

# %% [markdown]
# ●  Consider the following Nested Dictionary and answer the questions given below
#
#     student_courses = { 'FA15-BCS-01':
#                        {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'},
#                        'FA15-BCS-03':
#                        {'Program':'BS(CE)','Degree':'Bachelors in Computer Science'},
#                        'FA15-BCS-05':
#                        {'Program':'BS(CS)','Degree':'Bachelors in Computer Science'}}
#
# ●  Questions
#
#     o Pass Nested Dictionary to a Function (as shown in this Chapter)?

# %%
''' Purpose of Program 
The main purpose of the program is to Pass Nested Dictionary to a Function  '''
# Initializing a Nested Dictionary i.e., student_courses

try:

    student_courses = { 'FA15-BCS-01': 
                   [{'Program':'BS(CS)'}, {'Degree':'Bachelors in Computer Science'}],
                   'FA15-BCS-03': 
                   [{'Program':'BS(CE)'}, {'Degree':'Bachelors in Computer Science'}],
                   'FA15-BCS-05': [{'Program':'BS(CS)'}, {'Degree':'Bachelors in Computer Science'}]}

    def nested_dict_pairs_iterator(dict_obj): 
        # This function accepts a nested dictionary as argument and iterate over all values of nested dictionaries  
        # Iterate over all key-value pairs of dict argument 
        for key, value in dict_obj.items(): 
            print(key,value)
    if __name__ == '__main__':
        nested_dict_pairs_iterator(student_courses)
except Exception as ex:
    print(ex)
# Out:
# FA15-BCS-01 [{'Program': 'BS(CS)'}, {'Degree': 'Bachelors in Computer Science'}]
# FA15-BCS-03 [{'Program': 'BS(CE)'}, {'Degree': 'Bachelors in Computer Science'}]
# FA15-BCS-05 [{'Program': 'BS(CS)'}, {'Degree': 'Bachelors in Computer Science'}]

# %% [markdown]
# # **Task 2:**

# %% [markdown]
# Write programs for
#
#     • Your Trun Tasks

# %% [markdown]
# ## **Lecture 16**

# %% [markdown]
# ### **Your Turn Task 1**

# %% [markdown]
# ● Search and write down Linear and Non-linear Data Structures for the following Programming Languages?
#
#     o C
#     o Java
#     o React JS
#     o Ruby on Rail

# %% [markdown]
# #### **Answer:**

# %% [markdown]
# > C
#
# Linear Data Structures
#
#     o Array
#     o Linked List (Singly Linked List, Doubly Linked List)
#     o Queue
#     o Deque (Double-ended Queue)
#     o String (as a sequence of characters)
#
# Non-Linear Data Structures
#
#     o Binary Tree
#     o Binary Search Tree (BST)
#     o Graph (using adjacency list or matrix)
#     o Heap
#     o Trie
#
# > Java
#
# Linear Data Structures
#
#     o Array
#     o Linked List (Singly Linked List, Doubly Linked List)
#     o Stack
#     o Queue (Priority Queue, Deque)
#     o Vector
#
# Non-Linear Data Structures
#
#     o TreeSet (Red-Black Tree)
#     o HashMap (Hash Table)
#     o TreeMap (Red-Black Tree)
#     o Binary Tree
#     o Trie
#
# > React JS
#
# Linear Data Structures (JavaScript in React JS)
#
#     o Array
#     o Linked List (can be implemented in JavaScript)
#     o Stack (can be implemented using arrays)
#     o Queue (can be implemented using arrays)
#     o String (as a sequence of characters)
#
# Non-Linear Data Structures (JavaScript in React JS)
#
#     o Object (similar to Hash Table)
#     o Map (ES6 Map)
#     o Set (ES6 Set)
#     o Tree (can be implemented in JavaScript)
#     o Graph (can be implemented in JavaScript)
#
# > Ruby on Rails
#
# Linear Data Structures (Ruby)
#     o Array
#     o Linked List (can be implemented in Ruby)
#     o Stack (can be implemented using arrays)
#     o Queue (can be implemented using arrays)
#     o String (as a sequence of characters)
#
# Non-Linear Data Structures (Ruby)
#
#     o Hash (Hash Table)
#     o Set
#     o Tree (can be implemented in Ruby)
#     o Graph (can be implemented in Ruby)
#     o Heap (can be implemented in Ruby)

# %% [markdown]
# ### **Your Turn Task 2**

# %% [markdown]
# ● Consider an array (similar to the one given in TODO Task) and perform all the tasks (shown in this Lecture) to access array elements and store values in an array?
#
#     o marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# %%
# author = Abdullah

# The main purpose of this program is to Initialize an Array
marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# Accessing Array Elements

# Accessing First Array Element
print ("Accessing First Array Element: ",marks[0])

# Accessing Second Array Element
print ("Accessing Second Array Element: ",marks[1])

# Accessing Third Array Element
print ("Accessing Third Array Element: ",marks[2])

# Accessing Fourth Array Element
print ("Accessing Fourth Array Element: ",marks[3])

# Accessing Fifth Array Element
print ("Accessing Fifth Array Element: ",marks[4])

# Storing Values 

marks1 = [0] * 5
marks1 [0] = 88.5
marks1 [1] = 60.2
marks1 [2] = 70.8
marks1 [3] = 90.3
marks1 [4] = 20.6

print("\n")
print(marks1)


# Dry Run
# Execute marks = [0] * 5

# Index            0                1                2               3               4
# Value           0                0                0               0               0
# Address        DD20            DD28              DD36            DD44            DD52



#  Execute marks[0] = 88.5

# Index            0                1                2               3               4
# Value          88.5              0                0               0               0
# Address        DD20            DD28              DD36            DD44            DD52



#  Execute marks[1] = 60.2

# Index            0                1                2               3               4
# Value           88.5            60.2               0              10              0
# Address        DD20            DD28              DD36            DD44            DD52




#  Execute marks[2] = 70.8

# Index            0                1                2               3               4
# Value           88.5            60.2             70.8             10              0
# Address        DD20            DD28              DD36            DD44            DD52




#  Execute marks[3] = 90.3


# Index            0                1                2               3               4
# Value           88.5            60.2             70.8            90.3              0
# Address        DD20            DD28              DD36            DD44            DD52



#  Execute marks[4] = 20.6

# Index            0                1                2               3               4
# Value           88.5            60.2             70.8            90.3            20.6
# Address        DD20            DD28              DD36            DD44            DD52

# %% [markdown]
# ### **Your Turn Task 3**

# %% [markdown]
# ● Consider an array (similar to the one given in TODO Task) and perform all the tasks (shown in this Lecture) to print array elements on the Output Screen?
#
#     o marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# %%
# author = Abdullah

# The main purpose of this program is to Initialize an Array
marks = [88.5, 60.2, 70.8, 90.3, 20.6]

# Printing Array Elements

# Printing First Array Element
print ("Accessing First Array Element: ",marks[0])

# Printing Second Array Element
print ("Accessing Second Array Element: ",marks[1])

# Printing Third Array Element
print ("Accessing Third Array Element: ",marks[2])

# Printing Fourth Array Element
print ("Accessing Fourth Array Element: ",marks[3])

# Printing Fifth Array Element
print ("Accessing Fifth Array Element: ",marks[4])

# %% [markdown]
# ## **Lecture 17**

# %% [markdown]
# ### **Your Turn Task 1**

# %% [markdown]
# ● Consider three Strings (similar to the ones given in the TODO Task 1 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Print String 1 using Single Quotes, String 2 using Double Quotes and String 3 using Triple Quotes
#
#     o Print lengths of String 1, String 2, and String 3 using len() Function

# %%
'''
Purpose of Program
The main purpose of the program is to create a string using single, double, and triple quotes and measure their lengths
'''

# Input + Processing + Output

try:
    
# Using Single Quotes
    print('---Message with Single Quotes---') 
    print('My name is Abdullah.')

# Using Double Quotes
    print("")
    print('---Message with Double Quotes---')
    print("My name is Abdullah. I study in Comsats University Lahore Campus.")

# Using Triple Quotes
    print("")
    print('---Message with Triple Quotes---') 
    print('''My name is Abdullah. 
    I study in Comsats University Lahore Campus.
    It is my Second Semester''')
    print("")

# Calculating Length of String with Single Quotes using len() Function
    print('---Length of String with Single Quotes---')
    print('Length of "My name is Abdullah." is: ', len("My name is Abdullah."))
    print("")

# Calculating Length of String with Double Quotes using len() Function
    print('---Length of String with Double Quotes---')
    print("My name is Abdullah. I study in Comsats University Lahore Campus.' is: ", len("My name is Abdullah. I study in Comsats University Lahore Campus."))
    print("")
                                                                                   
# Calculating Length of String with Triple Quotes using len() Function
    print('---Length of String with Triple Quotes---') 
    print('''Length of 'My name is Abdullah. 
    I study in Comsats University Lahore Campus.
    It is my Second Semester' is: ''', len("My name is Abdullah. I study in Comsats University Lahore Campus. It is my Second Semester"))
                                                                                   
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 2**

# %% [markdown]
# ● Consider three Strings (similar to the ones given in the TODO Task 2 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Create String 1 using Single Quotes, String 2 using Double Quotes and String 3 using Triple Quotes
#     o Print length and types of String 1, String 2, and String 3 using len() Function

# %%
'''
Purpose of Program
The main purpose of the program is to create a string using single, double, and triple quotes and measure their lengths
'''

# Input + Processing + Output

try:
    
# Using Single Quotes
    print('---Message with Single Quotes---') 
    message_1 = 'My name is Abdullah.'
    print("message_1 = "+ message_1) 
    print("Length of message_1 =", len(message_1)) 
    print("Data Type of message_1 =", type(message_1)) 
    print("")

# Using Double Quotes
    print('---Message with Double Quotes---')
    message_2 = "My name is Abdullah. I study in Comsats University Lahore Campus."
    print("message_2 = "+ message_2) 
    print("Length of message_2 =", len(message_2)) 
    print("Data Type of message_2 =", type(message_2)) 
    print("")

# Using Triple Quotes
    print('---Message with Triple Quotes---') 
    message_3 = '''My name is Abdullah. 
    I study in Comsats University Lahore Campus.
    It is my Second Semester'''
    print("message_3 = "+ message_3) 
    print("Length of message_3 =", len(message_3)) 
    print("Data Type of message_3 =", type(message_3)) 
    print("")

except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 3**

# %% [markdown]
# ● Consider a String (similar to the one given in the TODO Task 3 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply following functions on String 1 and print the original and new string on the Output Screen?
#         ▪ title()
#         ▪ capitalize()
#         ▪ upper()
#         ▪ lower()
#         ▪ center()

# %%
'''
Purpose of Program
The main purpose of the program is to format string using following built-in Functions i.e., 
title(), capitalize(), upper(), lower() and center()
'''

# Input + Processing + Output
try:

# Initialize a Message
    message = 'My name is Abdullah.'

# Using title() Function
    print('---Original String before using title() Function---')
    print(message)
    print("")

    print('---New String after using title() Function---')
    print(message.title())

# Using capitalize() Function
    print("")
    print('---Original String before using capitalize() Function---') 
    print(message)
    print("")

    print('---New String after using capitalize() Function---') 
    print(message.capitalize())

# Using upper() Function
    print("")
    print('---Original String before using upper() Function---') 
    print(message)
    print("")

    print('---New String after using upper() Function---') 
    print(message.upper())

# Using lower() Function
    print("")
    print('---Original String before using lower() Function---') 
    print(message)
    print("")

    print('---New String after using lower() Function---') 
    print(message.lower())

# Using center() Function
    print("")
    print('---Original String before using center() Function---') 
    print("Original Message: "+ message)
    print("")

    print('---New String after using center() Function---') 
    print(message.center(100))

except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 4**

# %% [markdown]
# ● Consider a String (similar to the one given in the TODO Task 4 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply following techniques to access elements of a String (as shown in this Chapter) on selected String and print the original and new string on the Output Screen?
#         ▪ Indexing
#         ▪ Slicing
#         ▪ Splitting

# %%
''' Purpose of Program
The main purpose of the program is to access elements from a string using indexing,
slicing and split() function '''

# Input + Processing + Output

try:
    
# Initialize a Message
    message = 'My name is Abdullah.'

# Accessing Elements of a String using Indexing
    print("")
    print('---Original String before Indexing---') 
    print(message)
    print("")
    print('---New String after Indexing---')

# Access First Element of String
    print("Access Element at First Index i.e., message[0] is: "+ message[0])

# Access 14th Element of String
    print("Access Element at 14th Index i.e., message[14] is: "+ message[14])

# Access Last Element of String
    print("Access Element at last Index i.e., message[-1] is: "+ message[-1])

# Using Slicing
    print("")
    print('---Original String before Slicing---') 
    print(message)
    print("")
    print('---New String after Slicing---')

# Access First Sentence of String with stop value only i.e., [:13]
    print("Access First Sentence of String with stop value only i.e., [:13]: "+ message[:13])

# Access First Sentence of String with both start and stop value i.e., [0:13] 
    print("Access First Sentence of String with both start and stop value i.e.,[0:13]: "+ message[0:13])

# Access Middle Sentence of String
    print("Access Element from Middle Sentence i.e., message[14:53]: "+ message[14:53])

# Access Last Sentence of String with start value only i.e., message[55:]
    print("Access Last Sentence of String with start value only i.e., message[55:]: "+ message[55:])
    
# Access Last Sentence of String with both start and stop value i.e., [55:91] 
    print("Access Element from Last Sentence i.e.,message[55:91]: "+ message[55:91])

# Split String on basis of full stop (.) using split() Function
    print("")
    print('---Original String before using split() Function---') 
    print(message)
    print("")
    print('---New String after using split() Function---')
    print(message.split('.'))

# Split String on basis of spaces using split() Function 
    print("")
    print('---Original String before using split() Function---') 
    print(message)
    print("")
    print('---New String after using split() Function---') 
    print(message.split(' '))

except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 5**

# %% [markdown]
# ● Consider a String (similar to the one given in the TODO Task 5 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply following functions on String 1 and print the original and new string on the Output Screen?
#         ▪strip()
#         ▪ rstrip()
#         ▪ lstrip()

# %%
'''
Purpose of Program
The main purpose of the program is to remove Whitespaces from a String using strip(), rstrip(), lstrip() Functions
'''

# Input + Processing + Output 
try:

# Initialize a Message
    message = ' My name is Abdullah. '

# Using strip() Function on message 
    print("")
    print('---Original String before using strip() Function---') 
    print(message)
    print("Length of Original String i.e., message: ",len(message))
    
    print("")
    print('---New String after using strip() Function---')
    print(message.strip())
    print("Length of New String i.e., message: ",len(message.strip()))
    
# Using rstrip() Function on message 
    print("") 
    print('---Original String i.e., message_1 before using rstrip() Function---') 
    print(message) 
    print("Length of Original Message i.e., message_1: ",len(message)) 
    
    print("") 
    print('---New String i.e., message_1 after using rstrip() Function---') 
    print(message.rstrip()) 
    print("Length of New Message: ",len(message.rstrip()))
    
# Using lstrip() Function on message_1
    print("")
    print('---Original String i.e., message_1 before using lstrip() Function---') 
    print(message)
    print("Length of Original Message i.e., message_1: ",len(message))
    
    print("") 
    print('---New String i.e., message_1 after using lrip() Function---') 
    print(message.lstrip())
    print("Length of New Message: ",len(message.lstrip()))

except: 
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 6**

# %% [markdown]
# ● Consider an Integer and String (similar to the ones given in the TODO Task 6 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply str() function on Integer 1 and print the original Integer and new String on the Output Screen?
#
#     o Apply int() function on String 1 and print the original String and new Integer on the Output Screen?

# %%
'''
Purpose of Program
The main purpose of the program is to convert a string from data type string to numbers and from 
numbers to string
'''

# Input + Processing + Output
try:
    
# Initialize Variable
    number = 534
    string_number = '654'
    
# Using str() Function
    print("")
    print('---Original Number before Conversion into String---') 
    print(number)
    print('Data Type of Number before Converting into String:') 
    print(type(number))
    print("")
    
    print('---New Number after Conversion into String---') 
    print(str(number))
    print('Data Type of Number after Converting into String') 
    print(type(str(number)))
    print("")
    
# Using int() Function
    print("")
    print('---Original String before Conversion into Number---') 
    print(string_number)
    print('Data Type of String before Converting into Number:')
    print(type(string_number))
    print("")
    
    print('---New String after Conversion into Number---')
    print(int(string_number))
    print('Data Type of String after Converting into Number:')
    print(type(int(string_number)))
    print("")
except: 
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 7**

# %% [markdown]
# ● Consider a String (similar to the one given in the TODO Task 7 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply following operators and functions to insert characters at: (1) start, (2) specific position, and (3) end of String 1 (as shown in this Chapter) and print the original and new string on the Output Screen?
#
#         ▪ Concatenation Operator (+)
#         ▪ join() Function
#         ▪ Formatting Operator (%)
#         ▪ format() Function
#         ▪ F-String Prefix
#         ▪ find() Function

# %% [markdown]
# #### **1. Start**

# %%
''' Purpose of Program
The main purpose of the program is to insert character at start of a string and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'My name is Abdullah.'
    print('---Original String before using + Operator---')
    print(message)
    print("")

# Using + Operator to insert Element at First Index of a String 
    new_message = "*" + message[0:]
    print('---New String after using + Operator ---') 
    print(new_message)
    print("")

# Using join() Function to insert Element at First Index of a String
    print('---Original String before using join() Function---') 
    print(message)
    print("")
    newmessage = ''.join(("*",message))
    print('---New String after using join() Function---') 
    print(newmessage)
    print("")
    
# Using % Operator to insert Element at First Index of a String
    print('---Original String before using % Operator---') 
    print(message)
    print("")
    new_message = "%sMy name is Abdullah." %'*'
    print('---New String after using % Operator---')
    print(new_message)
    print("")
    
# Using format() Function to insert Element at First Index of a String
    print('---Original String before using format() Function---') 
    print(message)
    print("")
    new_message = "{}My name is Abdullah.".format('*')
    print('---New String after using format() Function---')
    print(new_message)
    print("")
    
# Using f Prefix to insert Element at First Index of a String
    print('---Original String before using f Prefix---') 
    print(message)
    print("")
    new_message = f"{'*'}My name is Abdullah."
    print('---New String after using f Prefix---') 
    print(new_message)
    print("")
    
# Using find() Function to insert Element at First Index of a String
    print('---Original String before using find() Function---') 
    print(message)
    print("")
    index = message.find('My')
    final_string = '*' + message[index:]
    print('---New String after using find() Function---') 
    print(final_string)
    print("")
# Using split(), join() and insert() Functions to insert Element at First Index of a String 
    print('---Original String before using split() Function---') 
    print(message)
    split_strings = message.split()
    split_strings.insert(0, '*') 
    updated_string = ' '.join(split_strings)
    print('---New String after using split() Function---') 
    print(updated_string)
except:
    print('Error Occurred')
# Out:
# ---Original String before using + Operator---
# My name is Abdullah.
#
# ---New String after using + Operator ---
# *My name is Abdullah.
#
# ---Original String before using join() Function---
# My name is Abdullah.
#
# ---New String after using join() Function---
# *My name is Abdullah.
#
# ---Original String before using % Operator---
# My name is Abdullah.
#
# ---New String after using % Operator---
# *My name is Abdullah.
#
# ---Original String before using format() Function---
# My name is Abdullah.
#
# ---New String after using format() Function---
# *My name is Abdullah.
#
# ---Original String before using f Prefix---
# My name is Abdullah.
#
# ---New String after using f Prefix---
# *My name is Abdullah.
#
# ---Original String before using find() Function---
# My name is Abdullah.
#
# ---New String after using find() Function---
# *My name is Abdullah.
#
# ---Original String before using split() Function---
# My name is Abdullah.
# ...

# %% [markdown]
# #### **2. Specific Position**

# %%
''' Purpose of Program
The main purpose of the program is to insert character at a specific position in a string and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'My name is Abdullah.'
    print('---Original String before using + Operator---')
    print(message)
    print("")

# Using + Operator to insert Element at Last Index of a String 
    new_message = message[:0] + "*"
    print('---New String after using + Operator ---') 
    print(new_message)
    print("")
    
# Using join() Function to insert Element at Last Index of a String
    print("")
    print('---Original String before using join() Function---') 
    print(message)
    newmessage = ''.join((message,"*"))
    print('---New String after using join() Function---') 
    print(newmessage)
    print("")
    
# Using % Operator to insert Element at Last Index of a String
    print("")
    print('---Original String before using % Operator---') 
    print(message)
    new_message = "My name is Abdullah.%s" %'*'
    print('---New String after using % Operator---') 
    print(new_message)
    print("")
    
# Using format() Function to insert Element at Last Index of a String
    print("")
    print('---Original String before using format() Function---')
    print(message)
    new_message = "My name is Abdullah.{}".format('*')
    print('---New String after using format() Function---') 
    print(new_message)
    print("")
    
# Using f Prefix to insert Element at Last Index of a String
    print("")
    print('---Original String before using f Prefix---') 
    print(message)
    new_message = f"My name is Abdullah.{'*'}"
    print('---New String after using f Prefix---') 
    print(new_message)
    print("")
    
# Using find() Function to insert Element at Last Index of a String
    print("")
    print('---Original String before using find() Function---')
    print(message)
    index = message.find('.')
    final_string = message[:index+1] + '*'
    print('---New String after using find() Function---') 
    print(final_string)
    print("")
    
# Using split(), join() and insert() Functions to insert Element at Last Index of a String 
    print('---Original String before using split() Function---') 
    print(message)
    split_strings = message.split()
    split_strings.insert((len(message) + 1), '*') 
    updated_string = ' '.join(split_strings)
    print('---New String after using split() Function---')
    print(updated_string)
    
except:
    print('Error Occurred')
# Out:
# ---Original String before using + Operator---
# My name is Abdullah.
#
# ---New String after using + Operator ---
# *
#
#
# ---Original String before using join() Function---
# My name is Abdullah.
# ---New String after using join() Function---
# My name is Abdullah.*
#
#
# ---Original String before using % Operator---
# My name is Abdullah.
# ---New String after using % Operator---
# My name is Abdullah.*
#
#
# ---Original String before using format() Function---
# My name is Abdullah.
# ---New String after using format() Function---
# My name is Abdullah.*
#
#
# ---Original String before using f Prefix---
# My name is Abdullah.
# ---New String after using f Prefix---
# My name is Abdullah.*
#
#
# ---Original String before using find() Function---
# My name is Abdullah.
# ---New String after using find() Function---
# My name is Abdullah.*
#
# ---Original String before using split() Function---
# My name is Abdullah.
# ---New String after using split() Function---
# ...

# %% [markdown]
# #### **3. End**

# %%
'''
Purpose of Program
The main purpose of the program is to insert character at end of a string and display the result on 
the Output Screen
'''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'My name is Abdullah.'
    print('---Original String before using + Operator---')
    print(message)
    print("")

# Using + Operator to insert Element at Last Index of a String 
    new_message = message[:0] + "*"
    print('---New String after using + Operator---') 
    print(new_message)
    print("")
    
# Using join() Function to insert Element at Last Index of a String
    print('---Original String before using join() Function---') 
    print(message)
    new_message = ''.join((message,"*"))
    print('---New String after using join() Function---') 
    print(new_message)
    print("")
    
# Using % Operator to insert Element at Last Index of a String
    print('---Original String before using % Operator---') 
    print(message)
    print("")
    new_message = "My name is Abdullah.%s" %'*'
    print('---New String after using % Operator---') 
    print(new_message)
    print("")
# Using format() Function to insert Element at Last Index of a String 
    print('---Original String before using format() Function---') 
    print(message) 
    print("")
    new_message = "My name is Abdullah.{}".format('*') 
    print('---New String after using format() Function---') 
    print(new_message) 
    print("") 
    
# Using f Prefix to insert Element at Last Index of a String 
    print('---Original String before using f Prefix---') 
    print(message)
    print("")
    new_message = f"My name is Abdullah.{'*'}" 
    print('---New String after using f Prefix---') 
    print(new_message) 
    print("") 
    
# Using find() Function to insert Element at Last Index of a String 
    
    print('---Original String before using find() Function---') 
    print(message) 
    print("")
    index = message.find('.') 
    final_string = message[:index+1] + '*' 
    print('---New String after using find() Function---') 
    print(final_string) 
    print("") 
    
# Using split(), join() and insert() Functions to insert Element at Last Index of a String 
    print('---Original String before using split() Function---') 
    print(message) 
    print("")
    split_strings = message.split() 
    split_strings.insert((len(message) + 1), '*') 
    updated_string = ' '.join(split_strings) 
    print('---New String after using split() Function---')
    print(updated_string) 
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 8**

# %% [markdown]
# ● Consider a String (similar to the one given in the TODO Task 8 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Traverse the selected String using the methods presented in this Chapter?

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to traverse an entire string and display the result on the Output Screen '''

# Input + Processing + Output
try: 
# Initialize Variable 
    message = 'Abdullah' 
# Traverse an entire String
    print(message) 
except: 
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse a string (element by element) and display the result 
on the Output Screen
'''

# Input + Processing + Output
try:
    
# ---Approach I - Iterate over a string (element by element) using for loop---
# Initialize Variable 
    message_1 = 'Abdullah'
# Iterate over a string (element by element) using for loop
    print(" ---Approach I - Iterate over a string (element by element) using for loop---")
    print("---Traverse a String (Element by Element) using for Loop---")
    for character in message_1:
        print(character)
# ---Approach II - Iterate over a string (element by element) using Indexing---

# Initialize Variable 
    message_2 = 'Abdullah'

# Iterate over a string (element by element) using for loop with Indexing
    print(" ---Approach II - Iterate over a string (element by element) using Indexing---")
    print("---Traverse a String (Element by Element) using for Loop with Indexing---")
    for element in range(0, len(message_2)):
        print("message_2[",element,"]: " + message_2[element])
        
# ---Approach III - Iterate over a string (element by element) using Slicing---
# Initialize Variable
    message_3 = 'Abdullah' 
    counter = 0
    print("---Approach III - Iterate over a string (element by element) using Slicing---")

# Iterate over a string (element by element) using for loop with Slicing
    print("---Traverse a String (Element by Element) using for Loop with Slicing--- ")
    
# Slicing Operator => string[starting index : ending index : step value] 
    for element in message_3[0 : len(message_3): 1]:
        counter = counter + 1 
        print("message_3[",counter,"]: " + element)
except:
    print('Error Occurred')
# Out:
#  ---Approach I - Iterate over a string (element by element) using for loop---
# ---Traverse a String (Element by Element) using for Loop---
# A
# b
# d
# u
# l
# l
# a
# h
#  ---Approach II - Iterate over a string (element by element) using Indexing---
# ---Traverse a String (Element by Element) using for Loop with Indexing---
# message_2[ 0 ]: A
# message_2[ 1 ]: b
# message_2[ 2 ]: d
# message_2[ 3 ]: u
# message_2[ 4 ]: l
# message_2[ 5 ]: l
# message_2[ 6 ]: a
# message_2[ 7 ]: h
# ---Approach III - Iterate over a string (element by element) using Slicing---
# ---Traverse a String (Element by Element) using for Loop with Slicing---
# message_3[ 1 ]: A
# message_3[ 2 ]: b
# message_3[ 3 ]: d
# message_3[ 4 ]: u
# message_3[ 5 ]: l
# message_3[ 6 ]: l
# message_3[ 7 ]: a
# message_3[ 8 ]: h

# %% [markdown]
# ### **Your Turn Task 9**

# %% [markdown]
# ● Consider a String (similar to the one given in the TODO Task 9 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply methods presented in this Chapter to search the following elements in String 1
#         ● name
#         ● A

# %%
'''
Purpose of Program
The main purpose of the program is to search specific character from a string and display the 
result on the Output Screen
'''

# Input + Processing + Output
try:
    
# Initialize Variable
    message = 'My name is Abdullah' 
    print('---Original String before using find() Function---') 
    print(message)
    print("")
    
# Using find() Function to Search a Word from a String 
    index_of_character = message.find('name') 
    print('---Index of Searched Term (name) returned by Search Function---') 
    print(index_of_character) 
    print("") 

# Using find() Function to Search a Character from a String 
    print('---Original String before using find() Function---') 
    print(message) 
    print("")
    index_of_character = message.find('A') 
    print('Searching all instances of a Search Term (A)') 
    print(index_of_character) 
    print("") 

# Using split() and find() Function to Search a String using for Loop 
    split_message = message.split() 
    for elem in split_message: 
        index = elem.find("Abdullah") 
        if index != -1: 
            print(elem) 
except: 
    print('Error Occurred')
# Out:
# ---Original String before using find() Function---
# My name is Abdullah
#
# ---Index of Searched Term (name) returned by Search Function---
# 3
#
# ---Original String before using find() Function---
# My name is Abdullah
#
# Searching all instances of a Search Term (A)
# 11
#
# Abdullah

# %% [markdown]
# ### **Your Turn Task 10**

# %% [markdown]
# ● Consider a String (similar to the one given in the TODO Task 10 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply methods presented in this Chapter to sort the selected String?

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to sort the string in ascending order and display the result on 
the Output Screen
'''

# Input + Processing + Output
try:
    
# Approach I - sorted() Function to arrange string in Ascending Order
    
# Initialize Variable 
    message = 'My name is Abdullah'
    print('---Approach I - sorted() Function to arrange string in Ascending Order---') 
    print('')
    print('---Original String before using sorted() Function---')
    print(message)
    print('')
    
# Using sorted() Function to arrange string in Ascending Order
    messages = sorted(message, reverse=False)
    print('---New String after using sorted() Function---') 
    print(messages)
    print('')
# Approach II – sorted() and split() Function to arrange string in Ascending Order
    print('---Approach II - sorted() and split() Function to arrange string in Ascending Order---')
    print('')
# Using sorted() and split() Function to arrange string in Ascending Order messages = 
    sorted(message.split(' '),reverse = False)
    print('---New String after using sorted() Function---') 
    print(messages)
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to sort the string in descending order and display the result on 
the Output Screen
'''
# Input + Processing + Output
try:
    
# Approach I - sorted() Function to arrange string in Descending Order
    
# Initialize Variable 
    message = 'My name is Abdullah'
    print('---Approach I - sorted() Function to arrange string in Descending Order---')
    print('')
    print('---Original String before using sorted() Function---') 
    print(message)
    print('')
# Using sorted() Function to arrange string in Descending Order
    messages = sorted(message, reverse=True)
    print('---New String after using sorted() Function---')
    print('')
    print(messages)
    print('')

# Approach II – sorted() and split() Function to arrange string in Descending Order 
    print('---Approach II - sorted() and split() Function to arrange string in Descending Order---')
    print('')
    
# Using sorted() and split() Function to arrange string in Descending Order
    messages = sorted(message.split(' '),reverse = True)
    print('---New String after using sorted() Function---')
    print('')
    print(messages)
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to sort the string in alphabetically and display the result on the Output Screen '''

# Input + Processing + Output 
try: 
# Initialize Variable 
    message = 'My name is Abdullah.'
    print('---Original String before using sorted() Function---')
    print ("")
    print(message)
    print ("")
    
# Using join() and sorted() Function to sort the String Alphabetically 
    message = ' '.join(sorted(message))
    print('---New String after using sorted() Function---') 
    print ("")
    print(message)
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 11**

# %% [markdown]
# ● Consider two Strings (similar to the ones given in the TODO Task 11 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Apply methods presented in this Chapter to merge the two selected Strings?

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program
The main purpose of the program is to concatenate a string using + operator and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable 
    message_1 = 'My name is Abdullah.'
    message_2 = 'I study in Comsats University Lahore.'
    print('---Original Message i.e., message_1---') 
    print("")
    print(message_1)
    print("")
    print('---Original Message i.e., message_2---') 
    print("")
    print(message_2)
    print("")
    
# Using + Operator Concatenate Two Strings 
    join_message = message_1 + message_2
    print('---New String after using + Operator---') 
    print("")
    print(join_message)
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to merge a string and display the result on the Output Screen '''

# Input + Processing + Output
try:
    
# Initialize Variable
    message_1 = 'My name is Abdullah.'
    message_2 = 'I study in Comsats University Lahore.'
    print('---Original Message i.e., message_1---') 
    print("")
    print(message_1)
    print("")
    print('---Original Message i.e., message_2 ---')
    print("")
    print(message_2)
    print("")
    
# Using join() Function to Concatenate Two Strings 
    join_message = ' '.join([message_1,message_2]) 
    print('---New String after using join() Function---') 
    print("")
    print(join_message)
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 12**

# %% [markdown]
# ● Consider three attributes (similar to the ones given in the TODO Task 12 of Lecture 17) and answer the questions given below.
#
# ● Questions
#
#     o Take Input from Student his / her Reg. Number, Name and Degree Program. Pass these three attributes to a Function and print the values on the Output Screen.

# %%
'''
Purpose of Program
The main purpose of the program is to pass strings to a function and display the result on the 
Output Screen
'''

def displayUserInformation(reg_no, name, degree): 
    print("Registration NO.: ", reg_no)
    print("Name: ",name)
    print("Degree: ",degree) 

if __name__ == "__main__": # main() Function
    try:
# Input
        reg_no = input("Enter your Registration NO.:") 
        name = input("Enter your Name: ")
        degree = input("Enter your Degree:")
        print("")
    
# Processing + Output
        displayUserInformation(reg_no, name, degree) 

    except ValueError:
        print("Error! Enter Valid Values")
# Out:
# KeyboardInterrupt

# %% [markdown]
# ## **Lecture 18**

# %% [markdown]
# ### **Your Turn Task 1**

# %% [markdown]
# ● Declare and Initialize a List (similar to the one given in TODO Task 1 of Lecture 18) using the [] and list() Function?

# %%
'''
Purpose of Program
The main purpose of the program is to initialize a list and display its content (data values) on 
the Output Screen
'''
# List Declaration and Initialization - Method 1: Use []
try:
    print("---List Initialization - Use []---")
    print ("")
    
# List Initialization
    fruits = ['Mango','Orange','Banana','Apple','Grapes','Peach','Guava','Pineapple','Appricot']
    
# Display Data Values of a List
    print("Data Values of fruits List:", fruits) 
    print ("")
    
# Display Length of a List using len() Function 
    print("Length of fruits List:", len(fruits))
    print ("")
    
# Display Type of a List using type() Function 
    print("Data-Type of fruits List:", type(fruits)) 
    print ("")
except: 
    print("Error Occurred")

print("---------------------------------------------------------") 


# List Declaration and Initialization - Method 2: Use list() Function

try:
    print("---List Initialization - Use list() Function---")
    print ("")
    
# List Initialization
    fruits_1 = ['Mango','Orange','Banana','Apple','Grapes','Peach','Guava','Pineapple','Appricot']

# Display Data Values of a List
    print("Data Values of fruits_1 List:", fruits_1)
    print ("")

# Display Length of a List using len() Function
    print("Length of fruits_1 List:", len(fruits_1))
    print ("")
    
# Display Type of a List using type() Function
    print("Data-Type of fruits_1 List:", type(fruits_1)) 
    print ("")
    
except:
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 2**

# %% [markdown]
# ● Consider two Lists (similar to the ones given in TODO Task 2 of Lecture 18) and answer the questions given below
#
# ● Questions
#
#     o Access Elements of the lists (as shown in this Chapter) using
#         ▪ Indexing
#         ▪ Negative Indexing
#         ▪ Slicing

# %% [markdown]
# #### **Indexing**

# %%
'''
Purpose of Program
The main purpose of the program is to access element(s) of a list using indexing and display the 
result on the output screen
'''
try:
# Initialize List 
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
                                                                                 
# Access Element(s) of First List using Indexing
    print("---Access Element(s) of First List using Indexing---")
    print("")
    print("fruits[0]:",fruits[0])
    print("fruits[1]:",fruits[1])
    print("fruits[2]:",fruits[2])
    print("fruits[3]:",fruits[3]) 
    print("fruits[4]:",fruits[4])
    print("") 
                                                                                 
# Access Element(s) of Second List using Indexing                                                                                 
    print("---Access Element(s) of Second List using Indexing---")
    print("")
    print("ages[0]:",ages[0])
    print("ages[1]:",ages[1])
    print("ages[2]:",ages[2])
    print("ages[3]:",ages[3]) 
    print("ages[4]:",ages[4])
    print("ages[5]:",ages[5])
    print("")                        
except:
    print("Error Occurred")

# %% [markdown]
# #### **Negative Indexing**

# %%
'''
Purpose of Program
The main purpose of the program is to access element(s) of a list using negative indexing and 
display the result on the output screen
'''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]

# Access Element(s) of First List using Negative Indexing
    print("---Access Element(s) of First List using Negative Indexing---")
    print("")
    print("fruits[-1]:",fruits[-1])
    print("fruits[-2]:",fruits[-2]) 
    print("fruits[-3]:",fruits[-3]) 
    print("fruits[-4]:",fruits[-4])
    print("fruits[-5]:",fruits[-5])
    print("") 
                                                                                 
# Access Element(s) of Second List using Negative Indexing                                                                                 
    print("---Access Element(s) of Second List using Negative Indexing---")
    print("")
    print("ages[-1]:",ages[-1])
    print("ages[-2]:",ages[-2]) 
    print("ages[-3]:",ages[-3]) 
    print("ages[-4]:",ages[-4])
    print("ages[-5]:",ages[-5])
    print("ages[-6]:",ages[-6])
    print("") 
except:
    print("Error Occurred")

# %% [markdown]
# #### **Slicing**

# %%
'''
Purpose of Program
The main purpose of the program is to access element(s) of a list using slicing and display the 
result on the output screen
'''
try:
# Initialize List 
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
# Access Element(s) of First List using Slicing
    print("---Access Element(s) of First List using Slicing---")
    print("")
    print("fruits[2:4]:",fruits[2:4])
    print("")

# Access from 2nd element till 4th element
    print("fruits[1:4]:", fruits[1:4])
    print("")

# Access from start till 3rd element 
    print("fruits[:3]:", fruits[:3])
    print("")

# Access from 2nd element till end
    print("fruits[1:]:", fruits[1:])
    print("")

# Access from start till 3rd last element 
    print("fruits[:-2]:", fruits[:-2]) 
    print("")

# Access from 3rd last element till 1st last element 
    print("fruits[-3:-1]:", fruits[-3:-1]) 
    print("")

# Access from 2nd element till 2nd last element
    print("fruits[1:-1]:", fruits[1:-1])
    print("")

# Access all elements 
    print("fruits[:]:",fruits[:]) 
    print("")
    
# Access Element(s) of Second List using Slicing
    print("---Access Element(s) of Second List using Slicing---")
    print("")
    print("ages[2:4]:",ages[2:4])
    print("")

# Access from 2nd element till 4th element
    print("ages[1:4]:", ages[1:4])
    print("")

# Access from start till 3rd element 
    print("ages[:3]:", ages[:3])
    print("")

# Access from 2nd element till end
    print("ages[1:]:", ages[1:])
    print("")

# Access from start till 3rd last element 
    print("ages[:-2]:", ages[:-2]) 
    print("")

# Access from 3rd last element till 1st last element 
    print("ages[-3:-1]:", ages[-3:-1]) 
    print("")

# Access from 2nd element till 2nd last element
    print("ages[1:-1]:", ages[1:-1])
    print("")

# Access all elements 
    print("ages[:]:",ages[:]) 
    print("")

except: 
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 3**

# %% [markdown]
# ● Consider two Lists (similar to the ones given in TODO Task 3 of Lecture 18) and answer the questions given below
#
# ● Questions
#
#     o Insert Elements to selected lists using following methods (as shown in this Chapter)
#         ▪ Method 1 - Add a New Element at the Start of a List
#         ▪ Method 2 - Add a New Element at the End of a List
#         ▪ Method 3 - Add a New Element at a Desired Location of a List

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to add a new element at the start of a list '''

try:
    print("---Add a Single Element at Start of First List---")

# List Initialization
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    print("---Original List before Adding Element at Start of First List---") 
    print("")
    print(fruits)
    print("")
# Add Data Value at Start of a List using insert() Function
    fruits.insert(0,"Plum")
    print("")
                                                                                                      
# Display Updated List after Adding Element at Start of First List
    print("---Updated List after Adding Element at Start of First List---") 
    print("")
    print(fruits)
    print("")
except:
    print("Error Occurred")

print("-------------------------------------------------------------")



try:
    print("---Add a Single Element at Start of Second List---")

# List Initialization
    ages = [25, 30, 15, 20, 22, 33]
    print("---Original List before Adding Element at Start of Second List---") 
    print("")
    print(ages)
    print("")
# Add Data Value at Start of a List using insert() Function
    ages.insert(0,18)
    print("")
                                                                                                      
# Display Updated List after Adding Element at Start of a List
    print("---Updated List after Adding Element at Start of a List---") 
    print("")
    print(ages)
    print("")
except:
    print("Error Occurred")

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program The main purpose of the program is to add a new element at the end of a list '''

try:
    print("---Add a Single Element at End of First List---")

# List Initialization
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    print("---Original List before Adding Element at End of First List---") 
    print("")
    print(fruits)
    print("")
# Add Data Value at End of a List using insert() Function
    fruits.append("Plum")
    print("")
                                                                                                      
# Display Updated List after Adding Element at End of First List
    print("---Updated List after Adding Element at End of First List---") 
    print("")
    print(fruits)
    print("")
except:
    print("Error Occurred")

print("-------------------------------------------------------------")



try:
    print("---Add a Single Element at End of Second List---")

# List Initialization
    ages = [25, 30, 15, 20, 22, 33]
    print("---Original List before Adding Element at End of Second List---") 
    print("")
    print(ages)
    print("")
# Add Data Value at End of a List using insert() Function
    ages.append(18)
    print("")
                                                                                                      
# Display Updated List after Adding Element at End of a List
    print("---Updated List after Adding Element at Start of a List---") 
    print("")
    print(ages)
    print("")
except:
    print("Error Occurred")

# %% [markdown]
# #### **Method 3**

# %%
'''
Purpose of Program
The main purpose of the program is to add new element(s) at a desired location of a list'''

try:
    print("---Add a Single Element at Desired Location of First List---")

# List Initialization
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    print("---Original List before Adding Element at Desired Location of First List---") 
    print("")
    print(fruits)
    print("")
# Add Data Value at Desired Location of a List using insert() Function
    fruits.insert(1,"Plum")
    print("")
                                                                                                      
# Display Updated List after Adding Element at Desired Location of First List
    print("---Updated List after Adding Element at Desired Location of First List---") 
    print("")
    print(fruits)
    print("")
except:
    print("Error Occurred")

print("-------------------------------------------------------------")



try:
    print("---Add a Single Element at Desired Location of Second List---")

# List Initialization
    ages = [25, 30, 15, 20, 22, 33]
    print("---Original List before Adding Element at Desired Location of Second List---") 
    print("")
    print(ages)
    print("")
# Add Data Value at Desired Location of a List using insert() Function
    ages.insert(2,18)
    print("")
                                                                                                      
# Display Updated List after Adding Element at Desired Location of a List
    print("---Updated List after Adding Element at Desired Location of a List---") 
    print("")
    print(ages)
    print("")
except:
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 4**

# %% [markdown]
# ● Consider two Lists (similar to the ones given in TODO Task 4 of Lecture 18) and answer the questions given below
#
# ● Questions
#
#     o Traverse selected lists using following methods (as shown in this Chapter)
#         ▪ Method 1: Traversing an Entire List
#         ▪ Method 2: Traversing a List (Element by Element)

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse an entire list and display the result on the Output 
Screen
'''

try:
    
# List Initialization
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]

# Traverse an entire list
    print(fruits) 
    print("")
    print(ages)
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse a list (element by element) and display the result 
on the Output Screen
'''

try:
# Iterate over First List (element by element) using for loop---

# List Initialization
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]

# Iterate over First List (element by element) using for loop
    print("Iterate over First List (element by element) using for loop---")
    print("")
    print("---Traverse First List (Element by Element) using for Loop---")
    print("")
    for element in fruits:
        print (element)
    print("")
    
# Iterate over Second List (element by element) using for loop
    print("Iterate over Second List (element by element) using for loop---")
    print("")
    print("---Traverse Second List (Element by Element) using for Loop---")
    print("")
    for element in ages:
        print (element)
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 5**

# %% [markdown]
# ●  Consider two Lists (similar to the ones given in TODO Task 5 of Lecture 18) and answer
# the questions given below
#
# ●  Questions
#
#     o Search from selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Search Specific Character from a List

# %%
'''
Purpose of Program
the main purpose of the program is to search a specific element from a list '''

# Approach I – Using in Operator to Search Element in First List

try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]

    print("Using in Operator to Search Element in First List")
    print("")
    element = 'Orange'

# Using in operator to Search Element in First List 
    if element in fruits:
        print(element + " is in List") 
        print("")
    else:
        print(element + " is not in List")
        print("")
        
    print("Using in Operator to Search Element in Second List")
    print("")
    element = 15

# Using in operator to Search Element in Second List 
    if element in ages:
        print(element, "is in List") 
        print("")
    else:
        print(element, "is not in List")
        print("")
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 6**

# %% [markdown]
# ●  Consider two Lists (similar to the ones given in TODO Task 6 of Lecture 18) and answer
# the questions given below
#
# ●  Questions
#
#     o Sort Elements of the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Sort a List Alphabetically
#         ▪   Method 2: Sort a List in Ascending Order
#         ▪   Method 3: Sort a List in Descending Order

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to sort a list alphabetically '''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original First List before using sort() Function---')
    print("")
    print(fruits)
    print("")
    
# Using sort() Function to sort First List Alphabetically 
    fruits.sort()
    print('---New First List after using sort() Function---') 
    print("")
    print(fruits)
    print("")
    
    print('---Original Second List before using sort() Function---')
    print("")
    print(ages)
    print("")
    
# Using sort() Function to sort Second List Alphabetically 
    ages.sort()
    print('---New Second List after using sort() Function---') 
    print("")
    print(ages)
    print("")    
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to sort a list alphabetically '''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original First List before using sort() Function---')
    print("")
    print(fruits)
    print("")
    
# Using sort() Function to sort First List Alphabetically 
    fruits.sort(reverse = False)
    print('---New First List after using sort() Function---') 
    print("")
    print(fruits)
    print("")
    
    print('---Original Second List before using sort() Function---')
    print("")
    print(ages)
    print("")
    
# Using sort() Function to sort Second List Alphabetically 
    ages.sort(reverse = False)
    print('---New Second List after using sort() Function---') 
    print("")
    print(ages)
    print("")    
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 3**

# %%
'''
Purpose of Program
The main purpose of the program is to sort a list alphabetically '''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original First List before using sort() Function---')
    print("")
    print(fruits)
    print("")
    
# Using sort() Function to sort First List Alphabetically 
    fruits.sort(reverse = True)
    print('---New First List after using sort() Function---') 
    print("")
    print(fruits)
    print("")
    
    print('---Original Second List before using sort() Function---')
    print("")
    print(ages)
    print("")
    
# Using sort() Function to sort Second List Alphabetically 
    ages.sort(reverse = True)
    print('---New Second List after using sort() Function---') 
    print("")
    print(ages)
    print("")    
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 7**

# %% [markdown]
# ● Consider two Lists (similar to the ones given in TODO Task 7 of Lecture 18) and answer the questions given below
#
# ●  Questions
#
#     o Merge Elements of the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Concatenate Lists using + Operator
#         ▪   Method 2: Concatenate Lists using * Operator
#         ▪   Method 3: Merge Lists using append() Function
#         ▪   Method 4: Merge Lists using extend() Function

# %% [markdown]
# #### **Method 1**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using + operator '''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Merging---')
    print("")
    print(fruits)
    print("")
    print(ages)
    print("")
    
# Using + Operator to Concatenate Lists 
    print('---New List after Merging---') 
    for count in range(len(fruits)):
        Merge_fruits_ages = fruits[count] + " - " + str(ages[count]) 
        print(Merge_fruits_ages)    

except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using * operator '''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']    
    ages = [25, 30, 15, 20, 22, 33]   
    print('---Original Lists before Merging---')
    print("")
    print(fruits)
    print("")
    print(ages)
    print("")
    
# Using * Operator to Concatenate Lists 
    print('---New List after Merging---') 
    for count in range(len(fruits)):
        Merge_fruits_ages = [*(fruits[count],ages[count] )] 
        print(Merge_fruits_ages)    

except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 3**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using append () Function '''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Merging---')
    print("")
    print(fruits)
    print("")
    print(ages)
    print("")
    
# Using append () Function to Concatenate Lists 
    print('---New List after Merging---') 
    for element in ages:
        fruits.append(element) 
    print(fruits)    

except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 4**

# %%
'''
Purpose of Program
The main purpose of the program is to concatenate lists using extend () Function '''
try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Merging---')
    print("")
    print(fruits)
    print("")
    print(ages)
    print("")
    
# Using extend () Function to Concatenate Lists 
    print('---New List after Merging---') 
    print("")
    fruits.extend(ages)
    print(fruits)    

except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 8**

# %% [markdown]
# ●  Consider two Lists (similar to the ones given in TODO Task 8 of Lecture 18) and answer
# the questions given below
#
# ●  Questions
#
#     o Update Elements of the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Update Entire List using Slicing
#         ▪   Method 2: Update List Element by Element using Indexing

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to update entire list using Slicing '''

try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Updating---')
    print("")
    print(fruits)
    print("")
    print(ages)
    print("")
    
# Update Entire List using Slicing
    print('---New List after Updating---') 
    print("")
    fruits[0:5] = ['Mango – 25','Orange - 30','Banana - 15','Apple - 20','Grapes - 22'] 
    print(fruits)    

except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to update entire list using Indexing '''

try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    
    print('---Original Lists before Updating---')
    print("")
    print(fruits)
    print("")
    print(ages)
    print("")
    
# Update List Element by Element using Indexing
    print('---New List after Updating---') 
    print("")
    fruits[2] = 'Plum'
    print(fruits)    

except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 9**

# %% [markdown]
# ● Consider two Lists (similar to the ones given in TODO Task 9 of Lecture 18) and answer the questions given below
#
# ● Questions
#
# o Remove Elements from the selected lists using following methods (as shown in this Chapter)
#         ▪   Method 1: Remove Entire / Element(s) from List using del
#         ▪   Method 2: Remove Entire List using clear() Function
#         ▪   Method 3: Remove Specific Element from a List using remove() Function
#         ▪   Method 4:  Remove  Last  Element  from  a  List  using  pop() Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using del '''

# Approach I – Delete an Entire List using del Function

try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']  
    print('---Original List before Updating---')
    print("")
    print(fruits)
    print("")
    
# Delete Entire List using del Function 
    print('---New List after using del Function---') 
    print("")
    del fruits 
    print(fruits) 
    
except Exception as ex: 
    print(ex)    
    
# Approach II – Delete a Single Element from a List using del Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using del Function 
    print('---New List after using del Function---') 
    print("")
    del ages[1]
    print(ages) 
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using clear() Function '''

# Approach I – Delete an Entire List using clear() Function

try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']  
    print('---Original List before Updating---')
    print("")
    print(fruits)
    print("")
    
# Delete Entire List using clear() Function 
    print('---New List after using clear() Function---') 
    print("")
    fruits.clear() 
    print(fruits) 
    
except:
    print('Error Occurred')   
    
# Approach II – Delete a Single Element from a List using clear() Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using clear() Function 
    print('---New List after using clear() Function---') 
    print("")
    ages.clear()
    print(ages) 
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using remove() Function '''

# Approach I – Delete an Entire List using remove() Function

try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']  
    print('---Original List before Updating---')
    print("")
    print(fruits)
    print("")
    
# Delete Entire List using remove() Function 
    print('---New List after using remove() Function---') 
    print("")
    fruits.remove('Banana') 
    print(fruits) 
    
except:
    print('Error Occurred')   
    
# Approach II – Delete a Single Element from a List using remove() Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using remove() Function 
    print('---New List after using remove() Function---') 
    print("")
    ages.remove(33)
    print(ages) 
except:
    print('Error Occurred')

# %% [markdown]
# #### **Method 4**

# %%
''' Purpose of Program 
The main purpose of the program is to delete entire list using pop() Function '''

# Approach I – Delete an Entire List using pop() Function

try:
# Initialize List
    fruits = ['Mango','Orange','Banana','Apple','Grapes']  
    print('---Original List before Updating---')
    print("")
    print(fruits)
    print("")
    
# Delete Entire List using pop() Function 
    print('---New List after using pop() Function---') 
    print("")
    fruits.pop(4) 
    print(fruits) 
    
except:
    print('Error Occurred')   
    
# Approach II – Delete a Single Element from a List using pop() Function

try:
# Initialize List
    ages = [25, 30, 15, 20, 22, 33]
    print("")
    print('---Original List before Updating---')
    print("")
    print(ages)
    print("")
    
# Delete Entire List using pop() Function 
    print('---New List after using pop() Function---') 
    print("")
    ages.pop(3)
    print(ages) 
except:
    print('Error Occurred')

# %% [markdown]
# ### **Your Turn Task 10**

# %% [markdown]
# ●  Consider two Lists (similar to the ones given in TODO Task 10 of Lecture 18) and answer the questions given below
#
# ●  Questions
#
#     o Use the concept of List Comprehension to create a new list based onthe selected Lists?

# %%
''' Purpose of Program 
The main purpose of the program is to create a new list based on values of an existing list ''' 
try: 
# List Initialization 
    fruits = ['Mango','Guava','Grapefruit','Apple','Grapes']
# Create a new list with element of previous List i.e., qul_shareef 
    list_comprehension = [element for element in fruits if "G" in element]
    print("New List containing Fruits with alphabet 'G':",list_comprehension)
    print("")
except:
    print("Error Occurred")

try: 
# List Initialization 
    ages = [25, 18, 15, 20, 22, 33]
# Create a new list with element of previous List i.e., qul_shareef 
    list_comprehension = [element for element in ages if (element < 20)]
    print("New List containing ages less than 20:",list_comprehension) 
except:
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 11**

# %% [markdown]
# ●  Consider a Nested List (similar to the ones given in TODO Task 11 of Lecture 18) and answer the questions given below
#
# ●  Questions
#
#     o Apply following operations on selected Nested List (as shown in this Chapter)?
#         ▪   Operation 1: Create a Nested List
#         ▪   Operation 2: Access Elements of a Nested List
#         ▪   Operation 3: Add New Element in a Nested List
#         ▪   Operation 4: Traverse a Nested List
#         ▪   Operation 5: Update Elements of a Nested List
#         ▪   Operation 6: Remove Elements of a Nested List

# %% [markdown]
# #### **Operation 1**

# %%
''' Purpose of Program 
The main purpose of the program is to create a nested list '''
# Initializing a Nested List i.e., Student 
try: 
    library_books = [
    ['Book ID', 'Title', 'Author', 'Genre'],
    1, ['BK001', 'To Kill a Mockingbird', 'Harper Lee', 'Fiction'],
    2, ['BK002', '1984', 'George Orwell', 'Dystopian', 'Political Fiction'],
    3, ['BK003', 'Moby Dick', 'Herman Melville', 'Adventure'],
    4, ['BK004', 'The Great Gatsby', 'F. Scott Fitzgerald', 'Fiction'],
    5, ['BK005', 'War and Peace', 'Leo Tolstoy', 'Historical Fiction', 'Epic']
]
    print("List of Library Books:")
    print("")
    print(library_books) 
    
# Data-Type of List i.e., students 
    print("")
    print("Data-Type of library books:", type(library_books)) 
    
# Length of List i.e., students 
    print("")
    print("Length of library books:", len(library_books)) 
except:
    print("Error Occurred")

# %% [markdown]
# #### **Operation 2**

# %%
''' Purpose of Program 
The main purpose of the program is to access elements of a nested list using indexing '''
try: 
    library_books = [
    ['Book ID', 'Title', 'Author', 'Genre'],
    1, ['BK001', 'To Kill a Mockingbird', 'Harper Lee', 'Fiction'],
    2, ['BK002', '1984', 'George Orwell', 'Dystopian', 'Political Fiction'],
    3, ['BK003', 'Moby Dick', 'Herman Melville', 'Adventure'],
    4, ['BK004', 'The Great Gatsby', 'F. Scott Fitzgerald', 'Fiction'],
    5, ['BK005', 'War and Peace', 'Leo Tolstoy', 'Historical Fiction', 'Epic']
]
# Access Elements of Nested List using Indexing 
    print("Element at index library_books[0]:",library_books[0])
    print("Element at index library_books[1]:",library_books[1])
    print("Element at index library_books[2]:",library_books[2])
    print("Element at index library_books[3]:",library_books[3])
    print("Element at index library_books[4]:",library_books[4]) 
    print("Element at index library_books[5]:",library_books[5])
    print("Element at index library_books[6]:",library_books[6]) 
    print("Element at index library_books[7]:",library_books[7])
    print("Element at index library_books[8]:",library_books[8])
    print("Element at index library_books[9]:",library_books[9])
    print("Element at index library_books[10]:",library_books[10])
except:
    print("Error Occurred")

# %% [markdown]
# #### **Operation 3**

# %%
'''
Purpose of Program
The main purpose of the program is to add elements in a nested list
'''
try: 
    library_books = [
    ['Book ID', 'Title', 'Author', 'Genre'],
    1, ['BK001', 'To Kill a Mockingbird', 'Harper Lee', 'Fiction'],
    2, ['BK002', '1984', 'George Orwell', 'Dystopian', 'Political Fiction'],
    3, ['BK003', 'Moby Dick', 'Herman Melville', 'Adventure'],
    4, ['BK004', 'The Great Gatsby', 'F. Scott Fitzgerald', 'Fiction'],
    5, ['BK005', 'War and Peace', 'Leo Tolstoy', 'Historical Fiction', 'Epic']
]
# Display Original List 
    print("---Original Nested List---") 
    print("")
    print(library_books) 
    print("------------------------------------------------") 
    
# Display List after Adding a New Element at the Start of a List 
    print("")
    print("---New List after using insert() Function---") 
    print("")
    
# Adding Element at the Start of a List using insert() Function 
    library_books.insert(0,'List of Library Books') 
    print(library_books)
except:
    print("Error Occurred")

# %% [markdown]
# #### **Operation 4**

# %%
'''
Purpose of Program
The main purpose of the program is to traverse a nested list
'''
try: 
    library_books = [
    ['Book ID', 'Title', 'Author', 'Genre'],
    1, ['BK001', 'To Kill a Mockingbird', 'Harper Lee', 'Fiction'],
    2, ['BK002', '1984', 'George Orwell', 'Dystopian', 'Political Fiction'],
    3, ['BK003', 'Moby Dick', 'Herman Melville', 'Adventure'],
    4, ['BK004', 'The Great Gatsby', 'F. Scott Fitzgerald', 'Fiction'],
    5, ['BK005', 'War and Peace', 'Leo Tolstoy', 'Historical Fiction', 'Epic']
]
    
# Traverse an Entire List 
    print(library_books)

except Exception as ex: 
    print(ex)

# %% [markdown]
# #### **Operation 5**

# %%
''' Purpose of Program 
The main purpose of the program is to update elements of a nested list '''
'''
Purpose of Program
The main purpose of the program is to add elements in a nested list
'''
try: 
    library_books = [
    ['Book ID', 'Title', 'Author', 'Genre'],
    1, ['BK001', 'To Kill a Mockingbird', 'Harper Lee', 'Fiction'],
    2, ['BK002', '1984', 'George Orwell', 'Dystopian', 'Political Fiction'],
    3, ['BK003', 'Moby Dick', 'Herman Melville', 'Adventure'],
    4, ['BK004', 'The Great Gatsby', 'F. Scott Fitzgerald', 'Fiction'],
    5, ['BK005', 'War and Peace', 'Leo Tolstoy', 'Historical Fiction', 'Epic']
]
    
# Display Original List 
    print("---Original Nested List---") 
    print("")
    print(library_books) 
    print("------------------------------------------------") 
    
# Display List after Updating Elements 
    print("")
    print("---New List after Updating Elements ---") 
    print("")
    
# Adding Element at the Start of a List using insert() Function 
    library_books[1] = 0 
    library_books[2][0] = 'BK002' 
    library_books[2][1] = 'Harry Potter And Half Blood Prince' 
    library_books[2][2] = 'J.K. Rowling' 
    library_books[3] = 1 
    library_books[4][0] = 'BK001' 
    library_books[4][1] = 'Brave New World' 
    library_books[4][2] = 'Aldous Huxley' 
    print(library_books)
except:
    print("Error Occurred")

# %% [markdown]
# #### **Operation 6**

# %%
''' Purpose of Program 
The main purpose of the program is to remove elements from a nested list '''

try: 
    library_books = [
    ['Book ID', 'Title', 'Author', 'Genre'],
    1, ['BK001', 'To Kill a Mockingbird', 'Harper Lee', 'Fiction'],
    2, ['BK002', '1984', 'George Orwell', 'Dystopian', 'Political Fiction'],
    3, ['BK003', 'Moby Dick', 'Herman Melville', 'Adventure'],
    4, ['BK004', 'The Great Gatsby', 'F. Scott Fitzgerald', 'Fiction'],
    5, ['BK005', 'War and Peace', 'Leo Tolstoy', 'Historical Fiction', 'Epic']
] 
    
# Display Original List 
    print("---Original Nested List---") 
    print("")
    print(library_books) 
    print("") 
    
# Display List after Removing an Element from the Start of a List
    print("---New List after Removing Element from Start using pop() Function---")
    print("")


# Removing Element from the Start of a List using pop() Function 
    library_books.pop(2)
    print(library_books)
except Exception as ex: 
    print(ex)

# %% [markdown]
# ### **Your Turn Task 12**

# %% [markdown]
# ●  Consider two Lists (similar to the ones given in TODO Task 12 of Lecture 18) and answer
# the questions given below
#
# ●  Questions
#
#     o Implement  the  concept  of  Lambda Function  using  the  following methos dicussed in this Chapter
#         ▪   Method 1: Use filter() Function
#         ▪   Method 2: Use map() Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of program is to filter only the cars with 'M' letter from the List and prime numbers less than 10'''

try: 
# List Initiazation 
    fruits = ['Mango','Guava','Grapefruit','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    print("---Origninal Lists before using filter() Function---")
    print("")
    print(fruits)
    print("")
    print(ages)
    
# Lists after using filter() Function 
    print("")
    fruits_with_G = list(filter(lambda fruit: 'G' in fruit, fruits))
    print("---New Lists after using filter() Function---") 
    print('')
    print(fruits_with_G)
    print('')
    
    updated_ages = list(filter(lambda number: number < 25, ages))
    print("---New List after using filter() Function---") 
    print('')
    print(updated_ages)
except: 
    print("Error Occurred")
# Out:
# ---Origninal Lists before using filter() Function---
#
# ['Mango', 'Guava', 'Grapefruit', 'Apple', 'Grapes']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New Lists after using filter() Function---
#
# ['Guava', 'Grapefruit', 'Grapes']
#
# ---New List after using filter() Function---
#
# [15, 20, 22]

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of program is to add a specific number each item in a list using map() '''

try: 
# List Initiazation 
    fruits = ['Mango','Orange','Banana','Apple','Grapes']
    ages = [25, 30, 15, 20, 22, 33]
    print("---Origninal Lists before using map() Function---")
    print("")
    print(fruits)
    print("")
    print(ages)
    
# Lists after using filter() Function 
    print("")
    updated_fruits = list(map(lambda fruit: fruit.upper(), fruits))
    print("---New Lists after using map() Function---") 
    print('')
    print(updated_fruits)
    print('')
    
    updated_ages = list(map(lambda number: number + 10, ages))
    print("---New List after using map() Function---") 
    print('')
    print(updated_ages)
except: 
    print("Error Occurred")
# Out:
# ---Origninal Lists before using map() Function---
#
# ['Mango', 'Orange', 'Banana', 'Apple', 'Grapes']
#
# [25, 30, 15, 20, 22, 33]
#
# ---New Lists after using map() Function---
#
# ['MANGO', 'ORANGE', 'BANANA', 'APPLE', 'GRAPES']
#
# ---New List after using map() Function---
#
# [35, 40, 25, 30, 32, 43]

# %% [markdown]
# ### **Your Turn Task 13**

# %% [markdown]
# ●  Consider a Nested List (similar to the ones given in TODO Task 13 of Lecture 18) and
# answer the questions given below
#
# ●  Questions
#
#     o Pass a List / Nested List to the Function, Iterate through the Nested List and Display all the elements on the Output Screen (as shown in this Chapter)?

# %%
''' Purpose of Program 
The main purpose of the program is to pass lists to a function and display the result on the Output Screen '''
def list_function(list): 
    for element in list:
        print(element) 
        
if __name__ == "__main__": # main() Function 
    try: # Initializing a List 
        fruits = ['Mango','Orange','Banana','Apple','Grapes'] # Function Call 
        print("---Available Cars are---")
        print("")
        list_function(fruits) 
        print("")
        
# Initializing a Nested List 
        library_books = [
    ['Book ID', 'Title', 'Author', 'Genre'],
    1, ['BK001', 'To Kill a Mockingbird', 'Harper Lee', 'Fiction'],
    2, ['BK002', '1984', 'George Orwell', 'Dystopian', 'Political Fiction'],
    3, ['BK003', 'Moby Dick', 'Herman Melville', 'Adventure'],
    4, ['BK004', 'The Great Gatsby', 'F. Scott Fitzgerald', 'Fiction'],
    5, ['BK005', 'War and Peace', 'Leo Tolstoy', 'Historical Fiction', 'Epic']
]
        print("---Studends Enrolled---")
        list_function(library_books) 
    
    except ValueError: 
        print("Error! Enter Valid Values")
# Out:
# ---Available Cars are---
#
# Mehran
# Mercedes
# Cultus
# WagonR
#
# ---Studends Enrolled---
# ['Registration No.', 'Name', 'Degree Program', 'Course']
# 1
# ['FA15-BSE-101', 'Ms. Samavi', 'BSE', 'Introduction to Python']
# 2
# ['FA15-BSE-103', 'Ms. Ayesha', 'BSE', '23', 'Machine Learning']
# 3
# ['FA15-BSE-105', 'Mr. Irfan', 'BSE', '20', 'Deep Learning']
# 4
# ['FA15-BSE-107', 'Ms. Fatima', 'BSE', '21', 'NLP']
# 5
# ['FA15-BSE-109', 'Mr. Mustafa', 'BSE', '22', 'Artificial Intelligence']

# %% [markdown]
# ## **Lecture 19**

# %% [markdown]
# ### **Your Turn Task 1**

# %% [markdown]
# ● Declare and Initialize a Dictionary (similar to the one given in TODO Task 1 of Lecture 19) using the {} and dict() Function?

# %%
''' Purpose of Program 
The main purpose of the program is to initialize a complete dictionary and display its content (data values) on the Output Screen '''
try:
# Dictionary Initialization - Method 1: Use {} 
    print("---Dictionary Initialization - Use {}---")
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Display Data Values of a Dictionary
    print ("")
    print("Data Values of phone_directory:", employee_directory)
    
# Display Length of a Dictionary using len() Function
    print ("")
    print("Length of phone_directory:", len(employee_directory))
    
# Display Type of a Dictionary using type() Function
    print ("")
    print("Data-Type of phone_directory:", type(employee_directory)) 


# Dictionary Initialization - Method 2: Use dict() Function 
    print ("")
    print("---Dictionary Initialization – Use dict() Function---")
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
    'Biology': ['Alice', 'David', 'Eve', 'Grace'],
    'Computer Science': ['Bob', 'Charlie', 'Frank', 'Grace']
}
    
# Display Data Values of a Dictionary
    print ("")
    print("Data Values of courses:", student_enrollments)

# Display Length of a Dictionary using len() Function
    print ("")
    print("Length of tomb_of_sahaba_2:",len(student_enrollments))

# Display Type of a Dictionary using type() Function 
    print ("")
    print("Data-Type of tomb_of_sahaba_2:",type(student_enrollments))


except: 
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 2**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 2 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Access Elements of the phone_dir and courses Dictionaries suing
#
#         ▪   Access value of an Individual Dictionary Item
#             ●  Method 1 - Access Element(s) of a Dictionary using key Name inside []
#             ●  Method 2 - Access Element(s) of a Dictionary using get() built-in Functions
#
#         ▪   Access List of keys in a Dictionary using key() built-in Function
#             ●  Access List of keys in a Dictionary using key() built-in Function
#
#         ▪   Access List of values in a Dictionary
#             ●  Access List of values in a Dictionary using values() built-in Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to access element(s) of a dictionary using key name '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Access Element(s) of a Dictionary using Keys 
    print("---Access Element(s) of a Dictionary using Keys---") 
    print("employee_directory['E001']:",employee_directory['E001']) 
    print("employee_directory['E002']:",employee_directory['E002']) 
    print("employee_directory['E003']:",employee_directory['E003']) 
    print("employee_directory['E004']:",employee_directory['E004']) 
    print("employee_directory['E005']:",employee_directory['E005']) 
    print("employee_directory['E006']:",employee_directory['E006']) 


# Dictionary Initialization
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
# Access Element(s) of a Dictionary using Keys 
    print("---Access Element(s) of a Dictionary using Keys---") 
    print("student_enrollments['Mathematics']:",student_enrollments['Mathematics']) 
    print("student_enrollments['Physics']:",student_enrollments['Physics']) 
    print("student_enrollments['Chemistry']:",student_enrollments['Chemistry']) 

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to access element(s) of a dictionary using get() Function '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Access Element(s) of a Dictionary using get() Function 
    print("---Access Element(s) of a Dictionary using get() Function---") 
    print(employee_directory.get('E001')) 
    print(employee_directory.get('E002')) 
    print(employee_directory.get('E003')) 
    print(employee_directory.get('E004')) 
    print(employee_directory.get('E005')) 
    print(employee_directory.get('E006'))

# Dictionary Initialization
    print ("")
   student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank']}
    
# Access Element(s) of a Dictionary using get() Function 
    print("---Access Element(s) of a Dictionary using get() Function---") 
    print(student_enrollments.get('Mathematics')) 
    print(student_enrollments.get('Physics')) 
    print(student_enrollments.get('Chemistry')) 

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to access list of keys in a dictionary using key() function '''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(employee_directory.keys())

# Dictionary Initialization
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(student_enrollments.keys())

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 4**

# %%
''' Purpose of Program 
The main purpose of the program is to access element(s) of a dictionary using values() function'''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(employee_directory.values())

# Dictionary Initialization
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
# Access Element(s) of a Dictionary using key() Function 
    print("---Access Element(s) of a Dictionary using key() Function---") 
    print(student_enrollments.values())

except: 
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 3**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 3 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Insert Elements to selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1 - Add a New Element at the Start of a Dictionary
#         ▪   Method 2 - Add a New Element at the End of a Dictionary
#         ▪    Method 3 - Add a New Element at a Desired Location of a Dictionary

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to add a new element at the start of a Dictionary on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Adding Element at Start of a Dictionary---") 
    print("")
    print(employee_directory)
    
# Data Type of i.e., phone_directory before converting to List
    print("")
    print("---Data Type of i.e., phone_directory before converting to List---") 
    print("")
    print(type(employee_directory)) 
    
# Converting a Dictionary into a List and store list in "list_phone_directory" 
    print("")
    list_employee_directory = list(employee_directory.items()) 
    
# Data Type of i.e., phone_directory after converting to List 
    print("")
    print("---Data Type of i.e., phone_directory after converting to List---") 
    print("")
    print(type(list_employee_directory))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_employee_directory.insert(0, ('E007','Robert Brown')) 

# Display Updated Dictionary after Adding Element at Start of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Start of a Dictionary---") 
    print("")
    print(list_employee_directory) 

    
# Dictionary Initialization
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Adding Element at Start of a Dictionary---") 
    print("")
    print(student_enrollments)
    
# Data Type of i.e., courses before converting to List
    print("")
    print("---Data Type of i.e., courses before converting to List---") 
    print("")
    print(type(student_enrollments)) 
    
# Converting a Dictionary into a List and store list in "list_courses" 
    print("")
    list_student_enrollments = list(student_enrollments.items()) 
    
# Data Type of i.e., courses after converting to List 
    print("")
    print("---Data Type of i.e., courses after converting to List---") 
    print("")
    print(type(list_student_enrollments))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_student_enrollments.insert(0, ('Biology',['Alice', 'David', 'Eve', 'Grace'])) 

# Display Updated Dictionary after Adding Element at Start of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Start of a Dictionary---") 
    print("")
    print(list_student_enrollments)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Adding Element at Start of a Dictionary---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---Data Type of i.e., phone_directory before converting to List---
#
# <class 'dict'>
#
#
# ---Data Type of i.e., phone_directory after converting to List---
#
# <class 'list'>
#
#
# ---Updated Dictionary after Adding Element at Start of a Dictionary---
#
# [('E007', 'Robert Brown'), ('E001', 'John Doe'), ('E002', 'Jane Smith'), ('E003', 'Emily Davis'), ('E004', 'Michael Brown'), ('E005', 'Laura Wilson'), ('E006', 'David Johnson')]
#
# ---Original Dictionary before Adding Element at Start of a Dictionary---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---Data Type of i.e., courses before converting to List---
#
# <class 'dict'>
#
#
# ...

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to add a new element at the end of a dictionary '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Adding Element at End of a Dictionary---") 
    print("")
    print(employee_directory)
    
# Data Type of i.e., phone_directory before converting to List
    print("")
    print("---Data Type of i.e., phone_directory before converting to List---") 
    print("")
    print(type(employee_directory)) 
    
# Converting a Dictionary into a List and store list in "list_phone_directory" 
    print("")
    list_employee_directory = list(employee_directory.items()) 
    
# Data Type of i.e., phone_directory after converting to List 
    print("")
    print("---Data Type of i.e., phone_directory after converting to List---") 
    print("")
    print(type(list_employee_directory))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_employee_directory.append(('E007','Robert Brown')) 

# Display Updated Dictionary after Adding Element at End of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at End of a Dictionary---") 
    print("")
    print(list_employee_directory) 

    
# Dictionary Initialization
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Adding Element at End of a Dictionary---") 
    print("")
    print(student_enrollments)
    
# Data Type of i.e., courses before converting to List
    print("")
    print("---Data Type of i.e., courses before converting to List---") 
    print("")
    print(type(student_enrollments)) 
    
# Converting a Dictionary into a List and store list in "list_courses" 
    print("")
    list_student_enrollments = list(student_enrollments.items()) 
    
# Data Type of i.e., courses after converting to List 
    print("")
    print("---Data Type of i.e., courses after converting to List---") 
    print("")
    print(type(list_student_enrollments))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_student_enrollments.append(('Biology',['Alice', 'David', 'Eve', 'Grace']))

# Display Updated Dictionary after Adding Element at End of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at End of a Dictionary---") 
    print("")
    print(list_student_enrollments)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Adding Element at End of a Dictionary---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---Data Type of i.e., phone_directory before converting to List---
#
# <class 'dict'>
#
#
# ---Data Type of i.e., phone_directory after converting to List---
#
# <class 'list'>
#
#
# ---Updated Dictionary after Adding Element at End of a Dictionary---
#
# [('E001', 'John Doe'), ('E002', 'Jane Smith'), ('E003', 'Emily Davis'), ('E004', 'Michael Brown'), ('E005', 'Laura Wilson'), ('E006', 'David Johnson'), ('E007', 'Robert Brown')]
#
# ---Original Dictionary before Adding Element at End of a Dictionary---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---Data Type of i.e., courses before converting to List---
#
# <class 'dict'>
#
#
# ...

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to add a new element at a desired location of a Dictionary on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(employee_directory)
    
# Data Type of i.e., phone_directory before converting to List
    print("")
    print("---Data Type of i.e., phone_directory before converting to List---") 
    print("")
    print(type(employee_directory)) 
    
# Converting a Dictionary into a List and store list in "list_phone_directory" 
    print("")
    list_employee_directory = list(employee_directory.items()) 
    
# Data Type of i.e., phone_directory after converting to List 
    print("")
    print("---Data Type of i.e., phone_directory after converting to List---") 
    print("")
    print(type(list_employee_directory))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_employee_directory.insert(3,('E007','Robert Brown')) 

# Display Updated Dictionary after Adding Element at Desired Location of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(list_employee_directory) 

    
# Dictionary Initialization
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(student_enrollments)
    
# Data Type of i.e., courses before converting to List
    print("")
    print("---Data Type of i.e., courses before converting to List---") 
    print("")
    print(type(student_enrollments)) 
    
# Converting a Dictionary into a List and store list in "list_courses" 
    print("")
    list_student_enrollments = list(student_enrollments.items()) 
    
# Data Type of i.e., courses after converting to List 
    print("")
    print("---Data Type of i.e., courses after converting to List---") 
    print("")
    print(type(list_student_enrollments))
    
# Add Data Value at Start of a Dictionary using insert() Function 
    print("")
    list_student_enrollments.insert(2,('Biology',['Alice', 'David', 'Eve', 'Grace']))

# Display Updated Dictionary after Adding Element at Desired Location of a Dictionary 
    print("")
    print("---Updated Dictionary after Adding Element at Desired Location of a Dictionary---") 
    print("")
    print(list_student_enrollments)

except: 
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 4**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 4 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Traverse selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Traversing an Entire Dictionary
#         ▪   Method 2: Traversing a Dictionary (Element by Element)

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to traverse through an entire dictionary and display the result on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Traverse through all key, value pairs 
    print("---Traverse through all key, value pairs---") 
    print ("")
    for elements in employee_directory.items(): 
        print(elements)
        
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}

    
# Traverse through all key, value pairs 
    print("---Traverse through all key, value pairs---") 
    print ("")
    for elements in student_enrollments.items(): 
        print(elements)        
except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to traverse through a dictionary and display the result on the output screen '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Traverse through all key, value pairs 
    print("---Traverse through all keys of First Dictionary---") 
    print ("")
    for elements in employee_directory.keys(): 
        print(elements)
    print ("")
    print("---Traverse through all values of First Dictionary---") 
    print ("")
    for elements in employee_directory.values(): 
        print(elements)    
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
# Traverse through all key, value pairs 
    print("---Traverse through all keys of Second Dictionary---") 
    print ("")
    for elements in student_enrollments.keys(): 
        print(elements)
    print ("") 
    print("---Traverse through all values of Second Dictionary---") 
    print ("")
    for elements in student_enrollments.values(): 
        print(elements) 
except: 
    print("Error Occurred")

# %% [markdown]
# ### **Your Turn Task 5**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 5 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Search from selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Search Element(s) from a Dictionary using key
#         ▪   Method 2: Search Element(s) from a Dictionary using value

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to search element(s) using key '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Search Value using Key from a Dictionary 
    print ("Value against 'E001' : "+ employee_directory.get('E001'))
        
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
# Search Value using Key from a Dictionary 
    print ("Value against 'Physics' : " , student_enrollments.get('Physics'))
except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to search element(s) using value '''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    

    print("---Using Keys(), Values() and index()---")
    print("")

# Store all Keys from the Dictionary in the Variable i.e., key_list 
    key_list = list(employee_directory.keys())
    print("Keys in the Dictionary:", key_list)
    print("")

# Store all Values from the Dictionary in the Variable i.e., val_list 
    val_list = list(employee_directory.values())
    print("Values in the Dictionary:", val_list)
    print("")

    print("---------------------------------------------------------")
    print("")
# Store Index of Value 'Kamaal' in a Variable i.e., position 
    position_John_Doe = val_list.index('John Doe')
# Display the Key with Value 'John Doe'
    print("Key against Value 'John Doe':",key_list[position_John_Doe])
    print("")

# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Using Keys(), Values() and index()---")
    print("")

# Store all Keys from the Dictionary in the Variable i.e., key_list 
    key_list = list(student_enrollments.keys())
    print("Keys in the Dictionary:", key_list)
    print("")

# Store all Values from the Dictionary in the Variable i.e., val_list 
    val_list = list(student_enrollments.values())
    print("Values in the Dictionary:", val_list)
    print("")

    print("---------------------------------------------------------")
    print("")
# Store Index of Value ['Alice', 'Bob', 'Eve'] in a Variable i.e., position 
    position = val_list.index(['Alice', 'Bob', 'Eve'])
# Display the Key with Value ['Alice', 'Bob', 'Eve']
    print("Key against Value ['Alice', 'Bob', 'Eve']:",key_list[position])
    print("")
except: 
    print("Error Occurred")
# Out:
# ---Using Keys(), Values() and index()---
#
# Keys in the Dictionary: ['E001', 'E002', 'E003', 'E004', 'E005', 'E006']
#
# Values in the Dictionary: ['John Doe', 'Jane Smith', 'Emily Davis', 'Michael Brown', 'Laura Wilson', 'David Johnson']
#
# ---------------------------------------------------------
#
# Key against Value 'Kamaal': E001
#
#
# ---Using Keys(), Values() and index()---
#
# Keys in the Dictionary: ['Mathematics', 'Physics', 'Chemistry']
#
# Values in the Dictionary: [['Alice', 'Bob', 'Charlie', 'David', 'Eve'], ['Alice', 'Bob', 'Eve'], ['Charlie', 'David', 'Frank']]
#
# ---------------------------------------------------------
#
# Key against Value ['Alice', 'Bob', 'Eve']: Physics

# %% [markdown]
# ### **Your Turn Task 6**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 6 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Sort the selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Sorting a Dictionary by key-value pair
#         ▪   Method 2: Sorting a Dictionary by key
#             ●  Method 2.1: Sorting a Dictionary by key in Ascending Order
#             ●  Method 2.2: Sorting a Dictionary by key in Descending Order
#         ▪   Method 3: Sorting a Dictionary by value
#             ●  Method 3.1: Sorting a Dictionary by value in Ascending Order
#             ●  Method 3.2: Sorting a Dictionary by value in Descending Order

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to sort a dictionary by key-value pair '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(employee_directory)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_employee_directory" 
    dict_employee_directory = employee_directory.items()
    
# Sort Dictionary based on keys using sorted() Function
    sorted_dictionary_1 = sorted(dict_employee_directory) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_1)

        
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(student_enrollments)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_student_enrollments" 
    dict_student_enrollments = student_enrollments.items()
    
# Sort Dictionary based on keys using sorted() Function
    sorted_dictionary_2 = sorted(dict_student_enrollments) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_2)

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 2.1**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by key in ascending order '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(employee_directory)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_employee_directory" 
    dict_employee_directory = employee_directory.items()
    
# Sort Dictionary in ascending order using sorted() Function
    sorted_dictionary_1 = sorted(dict_employee_directory,reverse = False) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_1)

        
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(student_enrollments)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_student_enrollments" 
    dict_student_enrollments = student_enrollments.items()
    
# Sort Dictionary in ascending order using sorted() Function
    sorted_dictionary_2 = sorted(dict_student_enrollments,reverse = False) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_2)

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 2.2**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by key in descending order '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Sorting---")
    print ("")
    print(employee_directory)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_employee_directory" 
    dict_employee_directory = employee_directory.items()
    
# Sort Dictionary in descending order using sorted() Function
    sorted_dictionary_1 = sorted(dict_employee_directory,reverse = True) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_1)

        
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    print("---Original Dictionary before Sorting---")
    print ("")
    print(student_enrollments)
    print ("")
    
#Store key-value pair of a Dictionary using items() in Variable "dict_student_enrollments" 
    dict_student_enrollments = student_enrollments.items()
    
# Sort Dictionary in descending order using sorted() Function
    sorted_dictionary_2 = sorted(dict_student_enrollments,reverse = True) 
    print("---New Dictionary after Sorting---") 
    print ("")
    print(sorted_dictionary_2)

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 3.1**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by value in descending order '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(employee_directory)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(employee_directory, key = employee_directory.get, reverse = False):
        print(elements, employee_directory[elements])
     
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(student_enrollments)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(student_enrollments, key = student_enrollments.get, reverse = False):
        print(elements, student_enrollments[elements])

except: 
    print("Error Occurred")
# Out:
# ---Sort Dictionary using 'get'---
#
# ---Original Dictionary before Sorting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Sorting---
#
# E006 David Johnson
# E003 Emily Davis
# E002 Jane Smith
# E001 John Doe
# E005 Laura Wilson
# E004 Michael Brown
#
# ---Sort Dictionary using 'get'---
#
# ---Original Dictionary before Sorting---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Sorting---
#
# Mathematics ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
# Physics ['Alice', 'Bob', 'Eve']
# Chemistry ['Charlie', 'David', 'Frank']

# %% [markdown]
# #### **Method 3.2**

# %%
''' Purpose of Program 
The main purpose of the program is to sorting a dictionary by value in descending order '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(employee_directory)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(employee_directory, key = employee_directory.get, reverse = True):
        print(elements, employee_directory[elements])
     
# Dictionary Initialization 
    print ("")
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
# Sort Dictionary using 'get'
    print("---Sort Dictionary using 'get'---") 
    print ("")
    print("---Original Dictionary before Sorting---")
    print ("")
    print(student_enrollments)
    print ("")
    print("---New Dictionary after Sorting---")
    print ("")
    for elements in sorted(student_enrollments, key = student_enrollments.get, reverse = True):
        print(elements, student_enrollments[elements])

except: 
    print("Error Occurred")
# Out:
# ---Sort Dictionary using 'get'---
#
# ---Original Dictionary before Sorting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Sorting---
#
# E004 Michael Brown
# E005 Laura Wilson
# E001 John Doe
# E002 Jane Smith
# E003 Emily Davis
# E006 David Johnson
#
# ---Sort Dictionary using 'get'---
#
# ---Original Dictionary before Sorting---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Sorting---
#
# Chemistry ['Charlie', 'David', 'Frank']
# Physics ['Alice', 'Bob', 'Eve']
# Mathematics ['Alice', 'Bob', 'Charlie', 'David', 'Eve']

# %% [markdown]
# ### **Your Turn Task 7**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 7 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Merge the selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Concatenate Dictionaries using update() Function
#         ▪   Method 2: Concatenate Dictionaries using ** Operators

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to concatenate dictionaries using update() function '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Merge---")
    print ("\nDictionary 1\n")
    print(employee_directory)
    print ("\nDictionary 2\n")
    print(student_enrollments)
    print ("")

# Use update() Function to merge two Dictionaries
    employee_directory.update(student_enrollments) 
    print("---New Dictionary after Merge---") 
    print ("")
    print(employee_directory)

except: 
    print("Error Occurred")

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to concatenate dictionaries using ** operator '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Merge---")
    print ("\nDictionary 1\n")
    print(employee_directory)
    print ("\nDictionary 2\n")
    print(student_enrollments)
    print ("")

# Use ** operator to merge two Dictionaries
    dict3_employee_directory = dict(employee_directory,** student_enrollments) 
    print("---New Dictionary after Merge---") 
    print ("")
    print(dict3_employee_directory)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Merge---
#
# Dictionary 1
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# Dictionary 2
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Merge---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson', 'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}

# %% [markdown]
# ### **Your Turn Task 8**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 8 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Update the selected Dictionaries using following methods (as shown in this Chapter)
#         ▪   Method 1: Update the key of a Dictionary using pop() Function
#         ▪   Method 2: Update the value of a Dictionary
#         ▪   Method 3: Update the value of a Dictionary using update() Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to update the key of a dictionary using pop() function '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Updatation---")
    print ("")
    print(employee_directory)
    print ("")
    
# Use pop() Function to update old_key_value with new_key_value 
    new_key = "E009" 
    old_key = "E001" 
    employee_directory[new_key] = employee_directory.pop(old_key)
    print("---New Dictionary after Updatation---") 
    print(employee_directory)

    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    
    print("---Original Dictionary before Updatation---")
    print ("")
    print(student_enrollments)
    print ("")
    
# Use pop() Function to update old_key_value with new_key_value 
    new_key = "Biology" 
    old_key = "Physics" 
    student_enrollments[new_key] = student_enrollments.pop(old_key)
    print("---New Dictionary after Updatation---") 
    print(student_enrollments)

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Updatation---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Updatation---
# {'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson', 'E009': 'John Doe'}
# ---Original Dictionary before Updatation---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Updatation---
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank'], 'Biology': ['Alice', 'Bob', 'Eve']}

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to update the value of a dictionary '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Updatation---")
    print ("")
    print(employee_directory)
    print ("")
    
# Use key for updating value in a Dictionary 
    employee_directory["E001"] = "Robert Brown"
    print("---New Dictionary after Updatation---") 
    print ("")
    print(employee_directory)
    print ("")
    
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}

    print("---Original Dictionary before Updatation---")
    print ("")
    print(student_enrollments)
    print ("")
    
# Use key for updating value in a Dictionary 
    student_enrollments["Physics"] = "['Alice', 'Bob', 'Eve','Morgan','Tony']"
    print("---New Dictionary after Updatation---") 
    print ("")
    print(student_enrollments)
    print ("")

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Updatation---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Updatation---
#
# {'E001': 'Robert Brown', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---Original Dictionary before Updatation---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Updatation---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': "['Alice', 'Bob', 'Eve','Morgan','Tony']", 'Chemistry': ['Charlie', 'David', 'Frank']}

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program
The main purpose of the program is to update the value of a dictionary using update() function '''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Updatation---")
    print ("")
    print(employee_directory)
    print ("")
    
# Use update() Function for updating value of a Dictionay
    employee_directory.update({'E003': 'Robert Brown'})
    print("---New Dictionary after Updatation---") 
    print ("")
    print(employee_directory)
    print ("")
    
    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}
    print("---Original Dictionary before Updatation---")
    print ("")
    print(student_enrollments)
    print ("")
    
# Use update() Function for updating value of a Dictionay
    student_enrollments.update({'Chemistry': ['Alice', 'David', 'Eve', 'Grace']})
    print("---New Dictionary after Updatation---") 
    print ("")
    print(student_enrollments)
    print ("")

except: 
    print("Error Occurred")
# Out:
# ---Original Dictionary before Updatation---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Updatation---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Robert Brown', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---Original Dictionary before Updatation---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Updatation---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Alice', 'David', 'Eve', 'Grace']}

# %% [markdown]
# ### **Your Turn Task 9**

# %% [markdown]
# ●  Consider two Dictionaries (similar to the ones given in TODO Task 9 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Remove  from  selected  Dictionaries  using  following  methods  (as shown in this Chapter)
#         ▪   Method 1: Delete Entire / Element(s) from a Dictionary using del
#         ▪   Method 2: Remove Element(s) of a Dictionary using clear() Function
#         ▪   Method 3: Remove Specific Element(s) from a Dictionary using pop() Function
#         ▪   Method 4: Remove Last Element(s) from a Dictionary using popitem() Function

# %% [markdown]
# #### **Method 1**

# %%
''' Purpose of Program 
The main purpose of the program is to Delete Entire / Element(s) from a Dictionary using del '''
try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
# Approach I - Delete Specific Element from Dictionary 
    print("---Approach I - Delete Specific Element from Dictionary---") 
    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(employee_directory) 

# Use del to delete specific key-value pair from a Dictionary 
    del employee_directory['E004'] 
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(employee_directory)

    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}

# Approach II - Delete Entire Dictionary 
    print ("")
    print("---Approach II - Delete Entire Dictionary---") 
    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(student_enrollments) 

# Use del to delete specific key-value pair from a Dictionary
    del student_enrollments 
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(student_enrollments)

except Exception as ex:
    print(ex)
# Out:
# ---Approach I - Delete Specific Element from Dictionary---
#
# ---Original Dictionary before Deleting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Deleting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---Approach II - Delete Entire Dictionary---
#
# ---Original Dictionary before Deleting---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Deleting---
#
# name 'student_enrollments' is not defined

# %% [markdown]
# #### **Method 2**

# %%
''' Purpose of Program 
The main purpose of the program is to remove elements of a dictionary using clear() function '''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Deleting---")
    print ("")
    print(employee_directory) 

# Use clear() Function to delete all elements of a Dictionary
    employee_directory.clear()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(employee_directory)

    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}

    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(student_enrollments) 

# Use clear() Function to delete all elements of a Dictionary
    student_enrollments.clear()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(student_enrollments)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Deleting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Deleting---
#
# {}
#
# ---Original Dictionary before Deleting---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Deleting---
#
# {}

# %% [markdown]
# #### **Method 3**

# %%
''' Purpose of Program 
The main purpose of the program is to remove specific element(s) of a dictionary using pop() function '''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Deleting---")
    print ("")
    print(employee_directory) 

# Use pop() Function to remove specific element(s) of a Dictionary
    employee_directory.pop('E005')
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(employee_directory)

    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}

    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(student_enrollments) 

# Use pop() Function to remove specific element(s) of a Dictionary
    student_enrollments.pop('Mathematics')
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(student_enrollments)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Deleting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Deleting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E006': 'David Johnson'}
#
# ---Original Dictionary before Deleting---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Deleting---
#
# {'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}

# %% [markdown]
# #### **Method 4**

# %%
''' Purpose of Program 
The main purpose of the program is to remove last element(s) of a dictionary using popitem() function '''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}
    
    print("---Original Dictionary before Deleting---")
    print ("")
    print(employee_directory) 

# Use popitem() Function to remove last element(s) of a Dictionary
    employee_directory.popitem()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(employee_directory)

    student_enrollments = {
    'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank'],
}

    print ("")
    print("---Original Dictionary before Deleting---")
    print ("")
    print(student_enrollments) 

# Use pop() Function to remove specific element(s) of a Dictionary
    student_enrollments.popitem()
    print ("")
    print("---New Dictionary after Deleting---") 
    print ("")
    print(student_enrollments)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Deleting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary after Deleting---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson'}
#
# ---Original Dictionary before Deleting---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}
#
# ---New Dictionary after Deleting---
#
# {'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve']}

# %% [markdown]
# ### **Your Turn Task 10**

# %% [markdown]
# ●  Consider a Dictionary (similar to the one given in TODO Task 10 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Use  the  concept  of  Dictionary  Comprehension  to  create  a  new Dictionary based on the selected Dictionary?

# %%
''' Purpose of Program 
The main purpose of the program is to create a new dictionary based on key-value pairs of an existing dictionary '''

try:
# Dictionary Initialization 
    print ("")
    employee_directory = {
    'E001': 'John Doe',
    'E002': 'Jane Smith',
    'E003': 'Emily Davis',
    'E004': 'Michael Brown',
    'E005': 'Laura Wilson',
    'E006': 'David Johnson'
}

    print("---Original Dictionary before Comprehension---")
    print ("")
    print(employee_directory) 

# Create a new dictionary with element of previous dictionary
    print ("")
    print("---New Dictionary After Comprehension---")
    print ("")
    new_employee_directory = {number: name for number, name in employee_directory.items() if name.startswith('J')} 
    print(new_employee_directory)

except Exception as ex:
    print(ex)
# Out:
# ---Original Dictionary before Comprehension---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith', 'E003': 'Emily Davis', 'E004': 'Michael Brown', 'E005': 'Laura Wilson', 'E006': 'David Johnson'}
#
# ---New Dictionary After Comprehension---
#
# {'E001': 'John Doe', 'E002': 'Jane Smith'}

# %% [markdown]
# ### **Your Turn Task 11**

# %% [markdown]
# ●  Consider a Nested Dictionary (similar to the one given in TODO Task 11 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Apply following operations on the selected Nested Dictionary (as shown in this Chapter)?
#         ▪   Operation 1: Create a Nested Dictionary
#         ▪   Operation 2: Access Elements of a Nested Dictionary
#         ▪   Operation 3: Add New Element in a Nested Dictionary
#         ▪   Operation 4: Traverse a Nested Dictionary
#         ▪   Operation 5: Remove Elements of a Nested Dictionary

# %% [markdown]
# #### **Operation 1**

# %%
''' Purpose of Program 
The main purpose of the program is to create a nested dictionary '''
# Initializing a Nested Dictionary i.e., student_courses

try:
    vehicle_information = {
    'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020},
    'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018},
    'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}
}
    print("Dictionary of Registration of Vehicles:\n\n", vehicle_information)
    print("")

# Data-Type of Dictionary i.e., student_courses
    print("Data-Type of students:", type(vehicle_information))
    print("")
    
# Length of Dictionary i.e., student_courses 
    print("Length of students:", len(vehicle_information))
    print("")
    
except:
    print("Error Occurred")

# %% [markdown]
# #### **Operation 2**

# %%
''' Purpose of Program 
The main purpose of the program is to access elements of a nested dictionary '''
# Initializing a Nested Dictionary i.e., students

try:
    vehicle_information = {
    'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020},
    'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018},
    'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}
}

# Access Elements of Nested Dictionary using Indexing 
    print("Element at index vehicle_information[VEH001] with Key 'Make':", vehicle_information['VEH001']['Make'])
    print("")
    print("Element at index vehicle_information[VEH001] with Key 'Model':", vehicle_information['VEH001']['Model']) 
    print("")
    print("Element at index vehicle_information[VEH001] with Key 'Year':", vehicle_information['VEH001']['Year']) 
    print("")
       
except:
    print("Error Occurred")
# Out:
# Element at index vehicle_information[VEH001] with Key 'Make': Toyota
#
# Element at index vehicle_information[VEH001] with Key 'Model': Corolla
#
# Element at index vehicle_information[VEH001] with Key 'Year': 2020

# %% [markdown]
# #### **Operation 3**

# %%
''' Purpose of Program 
The main purpose of the program is to add elements in a nested dictionary ''' 
# Initializing a Nested Dictionary i.e., students

try:
    vehicle_information = {
    'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020},
    'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018},
    'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}
}

# Display Original Dictionary
    print("---Original Nested Dictionary---")
    print("")
    print(vehicle_information)
    print("")

# Display Dictionary after Adding a New Dictionary inside a Nested Dictionary
    print("---New Dictionary adding a Dictionary---")
    print("")
    
# Create a Key-Value Pair i.e., another Dictionary inside a Dictionary
    vehicle_information['VEH004'] = {'Make':'Wagon R','Model':'Suzuki', 'Year': 2021}
    print(vehicle_information)
    print("")
    
except:
    print("Error Occurred")
# Out:
# ---Original Nested Dictionary---
#
# {'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020}, 'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018}, 'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}}
#
# ---New Dictionary adding a Dictionary---
#
# {'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020}, 'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018}, 'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}, 'VEH004': {'Make': 'Wagon R', 'Model': 'Suzuki', 'Year': 2021}}

# %% [markdown]
# #### **Operation 4**

# %%
''' Purpose of Program 
The main purpose of the program is to traversing a dictionary ''' 
# Initializing a Nested Dictionary i.e., vehicle_information

try:
    vehicle_information = {
    'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020},
    'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018},
    'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}
}

# Traverse a Dictionary 
    for vehicle_id, vehicle_details in vehicle_information.items(): 
        print("\nVehicle ID:", vehicle_id) 
        for key in vehicle_details: 
            print(key + ':', vehicle_details[key])

except:
    print("Error Occurred")
# Out:
# Vehicle ID: VEH001
# Make: Toyota
# Model: Corolla
# Year: 2020
#
# Vehicle ID: VEH002
# Make: Honda
# Model: Civic
# Year: 2018
#
# Vehicle ID: VEH003
# Make: Ford
# Model: Mustang
# Year: 2021

# %% [markdown]
# #### **Operation 5**

# %%
''' Purpose of Program 
The main purpose of the program is to remove elements from a nested dictionary ''' 
# Initializing a Nested Dictionary i.e., vehicle_information

try:
    vehicle_information = {
    'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020},
    'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018},
    'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}
}

# Approach I – Remove a Key from a Nested Dictionary 
    print("---Approach I – Remove an Key from a Nested Dictionary---")
    print("")
    
# Display Original Dictionary 
    print("---Original Nested Dictionary---")
    print("")
    print(vehicle_information) 
    
# Remove Key at Index 2 
    del vehicle_information['VEH003']['Year'] 
    print("")
    print("---New Dictionary after Removing a Key from a Nested Dictionary---") 
    print("")
    print(vehicle_information)

# Approach II – Remove a Nested Dictionary
    print("")
    print("---Approach II – Remove a Nested Dictionary---")
    print("")
    
# Display Original Dictionary 
    print("---Original Nested Dictionary---")
    print("")
    print(vehicle_information) 
    
# Remove a Dictionary
    del vehicle_information
    print("")
    print("---New Dictionary after Removing a Nested Dictionary---") 
    print("")
    print(vehicle_information)
    
except Exception as ex:
    print(ex)
# Out:
# ---Approach I – Remove an Key from a Nested Dictionary---
#
# ---Original Nested Dictionary---
#
# {'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020}, 'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018}, 'VEH003': {'Make': 'Ford', 'Model': 'Mustang', 'Year': 2021}}
#
# ---New Dictionary after Removing a Key from a Nested Dictionary---
#
# {'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020}, 'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018}, 'VEH003': {'Make': 'Ford', 'Model': 'Mustang'}}
#
# ---Approach II – Remove a Nested Dictionary---
#
# ---Original Nested Dictionary---
#
# {'VEH001': {'Make': 'Toyota', 'Model': 'Corolla', 'Year': 2020}, 'VEH002': {'Make': 'Honda', 'Model': 'Civic', 'Year': 2018}, 'VEH003': {'Make': 'Ford', 'Model': 'Mustang'}}
#
# ---New Dictionary after Removing a Nested Dictionary---
#
# name 'vehicle_information' is not defined

# %% [markdown]
# ### **Your Turn Task 12**

# %% [markdown]
# ●  Consider a Nested Dictionary (similar to the one given in TODO Task 12 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Create a Dictionary within a List (as shown in this Chapter)?

# %%
''' Purpose of Program 
The main purpose of the program is to create a dictionary within a list '''
# Initializing a Nested Dictionary i.e., student_courses

try:

    student_enrollments  = {
    'Learn How to Achieve Excellence in Love and Obedience of Allah':
    [{ 'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Physics': ['Alice', 'Bob', 'Eve'],
    'Chemistry': ['Charlie', 'David', 'Frank']}
],
}
    print("Creating a Nested Dictionary within a List:\n\n",student_enrollments )
except Exception as ex:
    print(ex)
# Out:
# Creating a Nested Dictionary within a List:
#
#  {'Learn How to Achieve Excellence in Love and Obedience of Allah': [{'Mathematics': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Physics': ['Alice', 'Bob', 'Eve'], 'Chemistry': ['Charlie', 'David', 'Frank']}]}

# %% [markdown]
# ### **Your Turn Task 13**

# %% [markdown]
# ●  Consider a Nested Dictionary (similar to the one given in TODO Task 1 of Lecture 19) and answer the questions given below
#
# ●  Questions
#
#     o Pass Nested Dictionary to a Function (as shown in this Chapter)?

# %%
''' Purpose of Program 
The main purpose of the program is to Pass Nested Dictionary to a Function  '''
# Initializing a Nested Dictionary i.e., student_courses

try:

vehicle_registration = {
    'VEH-1234': [{'Make': 'Toyota'}, {'Model': 'Corolla'}, {'Year': '2020'}, {'Color': 'White'}],
    'VEH-5678': [{'Make': 'Honda'}, {'Model': 'Civic'}, {'Year': '2018'}, {'Color': 'Black'}],
    'VEH-9101': [{'Make': 'Ford'}, {'Model': 'Mustang'}, {'Year': '2021'}, {'Color': 'Red'}],
    'VEH-1121': [{'Make': 'Chevrolet'}, {'Model': 'Camaro'}, {'Year': '2019'}, {'Color': 'Blue'}],
    'VEH-3141': [{'Make': 'Tesla'}, {'Model': 'Model 3'}, {'Year': '2022'}, {'Color': 'Silver'}]
}
    def nested_dict_pairs_iterator(dict_obj): 
        # This function accepts a nested dictionary as argument and iterate over all values of nested dictionaries  
        # Iterate over all key-value pairs of dict argument 
        for key, value in dict_obj.items(): 
            print(key,value)
    if __name__ == '__main__':
        nested_dict_pairs_iterator(vehicle_registration)
except Exception as ex:
    print(ex)
